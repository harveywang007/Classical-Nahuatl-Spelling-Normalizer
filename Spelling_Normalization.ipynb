# %% [markdown]
# # Training the Spelling Normalizer

# %% [markdown]
# ## Preprocessing

# %%
import translator.preprocessing as pre

import string
from collections import Counter

import pandas as pd

# %% [markdown]
# ### Expanding the Corpuses

# %% [markdown]
# #### Expanding the Monolingual Data

# %%
to_backtranslate = pre.prepare_data("Monolingual Data")

# %%
to_backtranslate
# Out:
#                                        To Backtranslate
# 0     auh ca cencah miyac inic motolinihticah, inic ...
# 1                        nochi tlacatl tlayiya, tocaya.
# 2     aocmo quitlayiznequih in incuen, za quitlatzih...
# 3     itztapalapan chiyennecuiloh in itequiuh ome to...
# 4                                in huel xicmottilican.
# ...                                                 ...
# 1621  miguel ixquen omomacac tlaltzontli apantentli,...
# 1622  in caxtiltepitzin oquichtli caxtoltetl cacahua...
# 1623  auh intlacamo nel oniquittani in amamatzin, ca...
# 1624  nehhuatl, pedro de paz, regidor, oniquintlahtl...
# 1625  ahzo quitemacaz eyi, nahui fanegas, ahno zan o...
#
# [1626 rows x 1 columns]

# %%
pre.expand_monolingual_corpus(to_backtranslate, "To Backtranslate")

# %% [markdown]
# #### Expanding the Training Data

# %%
corpus = pre.prepare_data("Unnormalized")

# %%
corpus
# Out:
#                                            Unregularized  \
# 0                   ma oc xicchie, ximotlali, ximosehui.
# 1         auh çā choloque, çan ic vmpolivito in iauiotl.
# 2       amo motequiuh yn tleyn ipanpa yn tlatzacuiltilo.
# 3      cuix amo no titlamaxtil y nicann oquihualhuica...
# 4                          ma yo yc yn amix, yn amoyolo.
# ...                                                  ...
# 13518                             nima tlatos ytla pila.
# 13519  notequimasehualoni naytia yn amotlatocayxpātzi...
# 13520                   auh ca huel ilhuil yn miquistli.
# 13521  ca tehuanti topan mochihuas yn ixquich tetli, ...
# 13522                                semicac tlatlasque.
#
#                                              Regularized
# 0                  ma oc xicchiya, ximotlali, ximocehui.
# 1      auh zan cholohqueh, zan ic ompolihuitoh in yao...
# 2      ahmo motequiuh in tlein ipampa in tlatzacuiltilo.
# 3      cuix ahmo no titlamachtil in nican oquihualhui...
# 4                        ma iuh ic in amix, in amoyollo.
# ...                                                  ...
# 13518                         niman tlahtoz itlan pilah.
# 13519  nontequimahcehualoni nayitia in amotlahtohcaix...
# 13520                   auh ca huel ilhuil in miquiztli.
# 13521  ca tehhuantin topan mochihuaz in ixquich tetl,...
# 13522                              cemihcac tlatlazqueh.
#
# [13523 rows x 2 columns]

# %%
pre.expand_bilingual_corpus(corpus, "Expanded Corpus")

# %%
expanded_corpus = pre.load_data("./data/CSVs/", "Expanded Corpus")

# %%
expanded_corpus
# Out:
#                                           Unregularized  \
# 0          ma xinechmotlapopolhuili i nitlatlacuanipol.
# 1                                  cuix tipiltzin dios?
# 2            monetlamachtil mochihuas ynn ōpa ylhuicac.
# 3                                         auhhuin axcan
# 4      ma oc no amehuantzintzinti ximotlantlauhtilican.
# ...                                                 ...
# 26520                               oc quiticinochilito
# 26521                                     oc ipan tlato
# 26522                                 yece aocmo inman;
# 26523                         ca nican can yn s.ta crus
# 26524                            notlasotemachticatzin.
#
#                                             Regularized
# 0       ma xinechmotlapohpolhuili in nitlahtlacoanipol.
# 1                                  cuix tipiltzin dios?
# 2            monetlamachtil mochihuaz in ompa ilhuicac.
# 3                                          auh in axcan
# 4      ma oc no amehhuantzitzintin ximotlatlauhtilican.
# ...                                                 ...
# 26520                               oc quiticinochilito
# 26521                                   oc ipan tlahtoh
# 26522                                yeceh aocmo imman;
# 26523                        ca nican cah in santa cruz
# 26524                          notlazohtemachtihcatzin.
#
# [26525 rows x 2 columns]

# %% [markdown]
# ### Splitting the Data

# %%
pre.create_raw_data_path()

# %% [markdown]
# #### Splitting the Main Data

# %%
train, val, test = pre.create_data_split(expanded_corpus, False)

# %%
train
# Out:
#                                           Unregularized  \
# 0          ma xinechmotlapopolhuili i nitlatlacuanipol.
# 1                                  cuix tipiltzin dios?
# 2            monetlamachtil mochihuas ynn ōpa ylhuicac.
# 3                                         auhhuin axcan
# 4      ma oc no amehuantzintzinti ximotlantlauhtilican.
# ...                                                 ...
# 18562           nima hualmonextis caltenpa juan marcos.
# 18563                 auh catle ma oncā nicnixnextilia.
# 18564                                 quin yayatinemis.
# 18565                               onehuas yn fariseo.
# 18566                          ma xicmotlatzotequilili.
#
#                                             Regularized
# 0       ma xinechmotlapohpolhuili in nitlahtlacoanipol.
# 1                                  cuix tipiltzin dios?
# 2            monetlamachtil mochihuaz in ompa ilhuicac.
# 3                                          auh in axcan
# 4      ma oc no amehhuantzitzintin ximotlatlauhtilican.
# ...                                                 ...
# 18562         niman hualmonextiz caltempan juan marcos.
# 18563              auh ca ahtleh mah oncan nicnextilia.
# 18564                               quin yahyahtinemiz.
# 18565                              onehuaz in fariseoh.
# 18566                         ma xicmotlatzontequilili.
#
# [18567 rows x 2 columns]

# %%
val
# Out:
#                                            Unregularized  \
# 18567                     ca sa no yuhqui in tlamachtili
# 18568                                         in tlacatl
# 18569           camo huel quipanahuis in ithemachticauh.
# 18570                             nican ca yn cuanpanoli
# 18571                                              crus.
# ...                                                  ...
# 25193                                        telpochtli.
# 25194                                 yn ica anquitasque
# 25195                 tenilpitica anquihualmohuiquilisq.
# 25196  ceppa çe caxtiltecatl ixpantzinco motlanquaque...
# 25197                           totlaçonantzin guadalupe
#
#                                              Regularized
# 18567                   ca zan no iuhqui in tlamachtilli
# 18568                                         in tlacatl
# 18569        ca ahmo huel quipanahuiz in itemachtihcauh.
# 18570                        nican cah in cuauhnepanolli
# 18571                                              cruz.
# ...                                                  ...
# 25193                                        telpochtli.
# 25194                            in ihcuac anquittazqueh
# 25195             tenilpihtica anquihualmohuiquilizqueh.
# 25196  ceppa ce caxtiltecatl ixpantzinco motlancuaque...
# 25197                          totlazohnantzin guadalupe
#
# [6631 rows x 2 columns]

# %%
test
# Out:
#                                      Unregularized  \
# 25198                    quimotlatlauhtiliticatca.
# 25199  masoyhui yn iqui nicali anechxixitinisnequi
# 25200        auh ca amo huecauhtica yn ninoquetzas
# 25201                               y ninnoscalis.
# 25202                            aocomo iuic onui;
# ...                                            ...
# 26520                          oc quiticinochilito
# 26521                                oc ipan tlato
# 26522                            yece aocmo inman;
# 26523                    ca nican can yn s.ta crus
# 26524                       notlasotemachticatzin.
#
#                                            Regularized
# 25198                       quimotlatlauhtilihticatca.
# 25199  mazoihui in iuhqui nicalli anechxixitiniznequih
# 25200          auh ca ahmo huehcauhtica in ninoquetzaz
# 25201                                   in ninozcaliz.
# 25202                              aocmo ihuic onhuih;
# ...                                                ...
# 26520                              oc quiticinochilito
# 26521                                  oc ipan tlahtoh
# 26522                               yeceh aocmo imman;
# 26523                       ca nican cah in santa cruz
# 26524                         notlazohtemachtihcatzin.
#
# [1327 rows x 2 columns]

# %% [markdown]
# #### Splitting the Backtranslation Data

# %%
backtranslate_train, backtranslate_val = pre.create_data_split(expanded_corpus, True)

# %%
backtranslate_train
# Out:
#                                             Regularized  \
# 0       ma xinechmotlapohpolhuili in nitlahtlacoanipol.
# 1                                  cuix tipiltzin dios?
# 2            monetlamachtil mochihuaz in ompa ilhuicac.
# 3                                          auh in axcan
# 4      ma oc no amehhuantzitzintin ximotlatlauhtilican.
# ...                                                 ...
# 19888                               in mochihchiuhqueh;
# 19889                      ca iuh onicchiuh nonohmatcah
# 19890                             iuh anquichihuazqueh.
# 19891                              ca cencah oniciahui.
# 19892                            oanquimociahuiltihqueh
#
#                                           Unregularized
# 0          ma xinechmotlapopolhuili i nitlatlacuanipol.
# 1                                  cuix tipiltzin dios?
# 2            monetlamachtil mochihuas ynn ōpa ylhuicac.
# 3                                         auhhuin axcan
# 4      ma oc no amehuantzintzinti ximotlantlauhtilican.
# ...                                                 ...
# 19888                                 in mochichiuhque;
# 19889                         ca yuh onicchiuh nômatica
# 19890                              yuh anquichihuazque.
# 19891                                  ca senca onisia.
# 19892                               oanquimociaviltique
#
# [19893 rows x 2 columns]

# %%
backtranslate_val
# Out:
#                                              Regularized  \
# 19893                                      oammahxiticoh
# 19894                            o tlaltech ammahxiticoh
# 19895                                   in amochantzinco
# 19896                                  cuauhtlaxcallan.”
# 19897  ca in ihcuac in otechcuilizquia in togobernado...
# ...                                                  ...
# 26520                                oc quiticinochilito
# 26521                                    oc ipan tlahtoh
# 26522                                 yeceh aocmo imman;
# 26523                         ca nican cah in santa cruz
# 26524                           notlazohtemachtihcatzin.
#
#                                            Unregularized
# 19893                                        oanmaxitico
# 19894                               otlaltech anmaxitico
# 19895                                   in amochantzinco
# 19896                                   quauhtlaxcalla.”
# 19897  ca yn iquac yn otechcuilisquia y togobernador ...
# ...                                                  ...
# 26520                                oc quiticinochilito
# 26521                                      oc ipan tlato
# 26522                                  yece aocmo inman;
# 26523                          ca nican can yn s.ta crus
# 26524                             notlasotemachticatzin.
#
# [6632 rows x 2 columns]

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### Finding the Most Common Pairs of Letters for Unnormalized Sentences

# %%
unreg_non_test = pd.concat([train["Unregularized"], val["Unregularized"]])

# %%
unreg_non_test
# Out:
# 0             ma xinechmotlapopolhuili i nitlatlacuanipol.
# 1                                     cuix tipiltzin dios?
# 2               monetlamachtil mochihuas ynn ōpa ylhuicac.
# 3                                            auhhuin axcan
# 4         ma oc no amehuantzintzinti ximotlantlauhtilican.
#                                ...
# 25193                                          telpochtli.
# 25194                                   yn ica anquitasque
# 25195                   tenilpitica anquihualmohuiquilisq.
# 25196    ceppa çe caxtiltecatl ixpantzinco motlanquaque...
# 25197                             totlaçonantzin guadalupe
# Name: Unregularized, Length: 25198, dtype: object

# %%
unreg_set = unreg_non_test.copy()

unreg_set = unreg_set.to_list()
unreg_set = " ".join(unreg_set)
unreg_set = unreg_set.translate(str.maketrans("", "", string.punctuation))
unreg_set = unreg_set.split()

# %%
unreg_set
# Out:
# ['ma',
#  'xinechmotlapopolhuili',
#  'i',
#  'nitlatlacuanipol',
#  'cuix',
#  'tipiltzin',
#  'dios',
#  'monetlamachtil',
#  'mochihuas',
#  'ynn',
#  'ōpa',
#  'ylhuicac',
#  'auhhuin',
#  'axcan',
#  'ma',
#  'oc',
#  'no',
#  'amehuantzintzinti',
#  'ximotlantlauhtilican',
#  'oanquiiyohuique',
#  'xolototon',
#  'auh',
#  'yn',
#  'axca',
#  'ca',
#  'yo',
#  'nictlalcahui',
#  'yc',
#  'quisaz',
#  'yn',
#  'candellas',
#  'ca',
#  'honamechnotitili',
#  'y',
#  'notetlasotlalitzin',
#  'yn',
#  'notetlacolilitzi',
#  'notlasomahuisconetzin',
#  'ca',
#  'yoqui',
#  'quimonequitia',
#  'yn',
#  'senca',
#  'yehuatzin',
#  'yn',
#  'ticmotlacamachiltitzinnos',
#  'yn',
#  'motlasotatzin',
#  'dios',
#  'ca',
#  'mopaquiltitica',
#  'in',
#  'mohuepoltzin',
#  'ihuan',
#  'in',
#  'mocnotlacahuan',
#  'pipiltotontin',
#  'ca',
#  'pactinemi',
#  'yehuāti',
#  'quitosque',
#  'yn',
#  'tlen',
#  'onitemachtiaya',
#  'ca',
#  'neli',
#  'namechilhuia',
#  'ca',
#  'in',
#  'tlacatecolotl',
#  'ca',
#  'oamechmintlani',
#  'inyc',
#  'amechsesemanas',
#  'in',
#  'iuhqui',
#  'trigo',
#  'mosesemana',
#  'mochayahua',
#  'cuix',
#  'amo',
#  'san',
#  'onepoli',
#  'yn',
#  'canpa',
#  'mocalaquitiuh',
#  'nomatica',
#  'onpa',
#  'anmocalaquizque',
#  'yese',
#  'namechilhuia',
#  'in',
#  'ipiltzin',
#  'dios',
#  'ca',
#  'yecancopantzinco',
#  'mehuiltities',
#  'in',
#  'dios',
#  'yn',
#  'āhuel',
#  'onmicuanis',
#  'yn',
#  'cmc',
#  'auh',
#  'ye',
#  'in',
#  'iquac',
#  'o',
#  'yuh',
#  'ninottac',
#  'in',
#  'huel',
#  'oninoohuicanaqui',
#  'in',
#  'aoccã',
#  'huel',
#  'nimaquiçaz',
#  'ca',
#  'yeppa',
#  'nimiquiz',
#  'nipopolihuiz',
#  'in',
#  'niman',
#  'aoctle',
#  'oncatca',
#  'nopalehuiloca',
#  'çã',
#  'nimã',
#  'iquac',
#  'çenmoch',
#  'ica',
#  'in',
#  'noyollo',
#  'nicnotza',
#  'tzilili',
#  'izçenquizcaichpochtzintli',
#  'ilhuicac',
#  'çihuapilli',
#  'totlaçonantzin',
#  'guadalupe',
#  'inic',
#  'ma',
#  'nechmocnoittili',
#  'ma',
#  'nechmopalehuili',
#  'cruztitech',
#  'quimamasohualtisque',
#  'auh',
#  'yn',
#  'axcan',
#  'opa',
#  'namechnohuiquilitiuh',
#  'yntla',
#  'san',
#  'monamacani',
#  'āmo',
#  'san',
#  'caxtolpohuali',
#  'pesos',
#  'ypatiuh',
#  'oyesquia',
#  'auh',
#  'camo',
#  'yehuatl',
#  'mochihuas',
#  'in',
#  'tlen',
#  'nicnequi',
#  'ca',
#  'san',
#  'yehuatl',
#  'mochihuas',
#  'in',
#  'motlanequilitzin',
#  'monenemitis',
#  'in',
#  'san',
#  'juo',
#  'hualmoquixtis',
#  'xpo',
#  'yhuān',
#  'apostoles',
#  'yhuā',
#  'judios',
#  'quen',
#  'ticmomachiltia',
#  'in',
#  'monacayotzin',
#  'yn',
#  'oquicuique',
#  'amatlan',
#  'ynic',
#  'viac',
#  'chicopohuanlli',
#  'yc',
#  'patlahuac',
#  'onpohualli',
#  'axcan',
#  'xictlapaltili',
#  'yn',
#  'moma',
#  'oc',
#  'achi',
#  'quali',
#  'yn',
#  'āmohuicasque',
#  'y',
#  'nochantzinco',
#  'yn',
#  'ilhuicatl',
#  'ytec',
#  'notlasopilhuane',
#  'ca',
#  'ye',
#  'anquimomachistia',
#  'ca',
#  'sa',
#  'huiptla',
#  'yn',
#  'ilhuitl',
#  'yes',
#  'yn',
#  'pascua',
#  'nopiltzitzine',
#  'cahuel',
#  'timistostlacahuilisque',
#  'nima',
#  'temocxipaquilis',
#  'xinechmelauhcaylhui',
#  'tleyn',
#  'oticchiuh',
#  'tleyn',
#  'otiquitlaco',
#  'ynic',
#  'titeyxpanhuilo',
#  'tteen',
#  'cuix',
#  'titehuitequisq',
#  'nima',
#  'quimonochilis',
#  'y',
#  'magdalena',
#  'y',
#  'santa',
#  'maria',
#  'aço',
#  'tocnopil',
#  'aço',
#  'tomacehual',
#  'mochihuaz',
#  'auh',
#  'ca',
#  'haxcan',
#  'mochi',
#  'nicā',
#  'anquimotilisq',
#  'tlatoani',
#  'temachtiani',
#  'ca',
#  'ye',
#  'oyaque',
#  'yn',
#  'huel',
#  'mahuistic',
#  'yes',
#  'huelapanahuia',
#  'ynic',
#  'cuali',
#  'yes',
#  'auh',
#  'in',
#  'imitzcuinoan',
#  'iacattivitze',
#  'yyoyahue',
#  'omochiuh',
#  'onotlahueliltic',
#  'xicmacacā',
#  'yn',
#  'atl',
#  'quitlani',
#  'quimonahuatequilis',
#  'yn',
#  'crus',
#  'ma',
#  'xinechilhui',
#  'amo',
#  'yc',
#  'amosotlahuasque',
#  'cacoquis',
#  'ytzontecon',
#  'conmotilis',
#  'yn',
#  'xpo',
#  'cuix',
#  'otimitzanato',
#  'xiquisacan',
#  'xihuiya',
#  'quiyahuac',
#  'xiccahacan',
#  'yn',
#  'icaltzi',
#  'y',
#  'notlasotatzi',
#  'ds',
#  'ma',
#  'xicmomachltican',
#  'ca',
#  'uhhuala',
#  'ynin',
#  'altepetli',
#  'omentin',
#  'itlamachtilhuan',
#  'huel',
#  'oticcaquilique',
#  'quitotinemi',
#  'tla',
#  'ximehuiltitiecan',
#  'nocihuapiltzin',
#  'ca',
#  'çan',
#  'nican',
#  'amopantzinco',
#  'niquiztehua',
#  'amocatzinco',
#  'nitlatlantiquiça',
#  'aço',
#  'tepitzin',
#  'anquimomacehuitzinoa',
#  'in',
#  'itechicahualiztzin',
#  'in',
#  'tlacatl',
#  'in',
#  'totecuiyo',
#  'ca',
#  'ye',
#  'ixquich',
#  'cahuitl',
#  'in',
#  'in',
#  'aoquic',
#  'amixtzinco',
#  'amocpactzinco',
#  'nitlachia',
#  'huel',
#  'cenca',
#  'miac',
#  'inic',
#  'quinmotlaçotili',
#  'inic',
#  'quinmopalehuili',
#  'inic',
#  'quinmomanahuili',
#  'in',
#  'ilhuicac',
#  'çihuapilli',
#  'çenquizcaichpochtli',
#  'santa',
#  'maria',
#  'in',
#  'nican',
#  'tlaca',
#  'inic',
#  'huel',
#  'quimomacazque',
#  'in',
#  'itech',
#  'hualmopachozque',
#  'in',
#  'tlaneltoquiliztli',
#  'auh',
#  'ynhūa',
#  'quihuicasque',
#  'yn',
#  'jesus',
#  'yn',
#  'opan',
#  'tepeticpac',
#  'yn',
#  'onpa',
#  'techihuililoyan',
#  'jostisia',
#  'yntocayocan',
#  'calvario',
#  'ma',
#  'xicmocaquilti',
#  'tlatohuanien',
#  'yscatqui',
#  'yn',
#  'ticmachilia',
#  'yn',
#  'nican',
#  'ylpiticac',
#  'teyxcuepani',
#  'ça',
#  'iuhq̓n',
#  'tequani',
#  'vnca',
#  'tel',
#  'iuh',
#  'mochiuh',
#  'auh',
#  'in',
#  'iuan',
#  'diego',
#  'niman',
#  'ic',
#  'huallamelauh',
#  'quitocac',
#  'in',
#  'cuepotli',
#  'auh',
#  'in',
#  'quihualtepotztocaya',
#  'oncan',
#  'atlauhtli',
#  'quiça',
#  'inahuac',
#  'tepeyacac',
#  'quauhpantitlan',
#  'quipoloco',
#  'ca',
#  'quimitalhuia',
#  'yn',
#  'tlatoque',
#  'ca',
#  'mitzmomaquilia',
#  'yn',
#  'senpohūali',
#  'tlatematli',
#  'teoquitlatl',
#  'cuix',
#  'noce',
#  'itla',
#  'mopantzinco',
#  'quihualmihualia',
#  'in',
#  'itemoxtzin',
#  'in',
#  'ieecatzin',
#  'yn',
#  'mimique',
#  'omoscalique',
#  'otlachiyaco',
#  'yn',
#  'tlalticpac',
#  'tlananquilisque',
#  'mochintin',
#  'yn',
#  'judiosme',
#  'ca',
#  'za',
#  'noçeltzin',
#  'yn',
#  'ānechcauhtiquizazque',
#  'amo',
#  'anquilcahuasque',
#  'yn',
#  'notlatoltzin',
#  'yc',
#  'namechilpitehua',
#  'namechtetzinlotehua',
#  'cuix',
#  'noso',
#  'san',
#  'oqui',
#  'yes',
#  'ca',
#  'huel',
#  'nechmauhtia',
#  'oncan',
#  'quimotlalhuitequilisque',
#  'otlica',
#  'yn',
#  'xpo',
#  'quiquetz',
#  'in',
#  'iteocaltzin',
#  'in',
#  'itlaçoixiptlatzin',
#  'in',
#  'ilhuicac',
#  'çihuapilli',
#  'moteneuhtzinoa',
#  'remedios',
#  'in',
#  'oncan',
#  'axcan',
#  'moyetztica',
#  'ay',
#  'ma',
#  'huel',
#  'xiquitacan',
#  'aquin',
#  'onechhualnacastlas',
#  'tiacahuane',
#  'ic',
#  'ontlamantli',
#  'nitlanahuantia',
#  'inin',
#  'caltzintli',
#  'nicmacatiuh',
#  'nopiltzin',
#  'salvador',
#  'de',
#  'los',
#  'reyes',
#  'ihuan',
#  'nochpoch',
#  'bernardina',
#  'de',
#  'los',
#  'reyes',
#  'onca',
#  'yezque',
#  'ynehuan',
#  'auh',
#  'senca',
#  'amehuantin',
#  'anquimati',
#  'intla',
#  'anquichololtitin',
#  'ca',
#  'aocmo',
#  'nehuatl',
#  'notlatlacol',
#  'y¯',
#  'nocal',
#  'yxquich',
#  'yc',
#  'mani',
#  'ca',
#  'huel',
#  'nixcoya¯',
#  'ye',
#  'tinechmocahuilia',
#  'i',
#  'nimonantzin',
#  'mocauhtzinos',
#  'xpo',
#  'mochiti',
#  'apostoles',
#  'ca',
#  'yehuatl',
#  'iyn',
#  'atlacatzintli',
#  'yn',
#  'otechmonahuatili',
#  'yn',
#  'totemachticatzin',
#  'ca',
#  'yehuatl',
#  'in',
#  'nomiquis',
#  'yaoyotl',
#  'ic',
#  'nicpanahuis',
#  'in',
#  'teyauh',
#  'ic',
#  'nictlanis',
#  'in',
#  'inemaquixtilis',
#  'y',
#  'notlachihualhuan',
#  'xinechilhui',
#  'yn',
#  'ac',
#  'tehuatl',
#  'tlatoanie',
#  'ocçepa',
#  'mixpantzinco',
#  'oticualhuicaque',
#  'ynin',
#  'tetlapololtianiani',
#  'moquetzinnos',
#  'xpo',
#  'auh',
#  'ca',
#  'san',
#  'yehuatli',
#  'ynic',
#  'otechhualmotitlani',
#  'y',
#  'tomextin',
#  'ca',
#  'ye',
#  'qualitzin',
#  'nopiltzintzin',
#  'notlatohuanie',
#  'y',
#  'quitotinemi',
#  'y',
#  'quiteylhuia',
#  'ynic',
#  'yehuatli',
#  'yn',
#  'mesiyas',
#  'ca',
#  'ye',
#  'oasico',
#  'in',
#  'cahuitl',
#  'inic',
#  'anquimotilisque',
#  'in',
#  'amotemachticauh',
#  'inmac',
#  'cahualos',
#  'in',
#  'tlatlacuanime',
#  'ma',
#  'xicmonochilican',
#  'in',
#  'telpochtli',
#  'yhuan',
#  'titemacalo',
#  'maquili',
#  'peso',
#  'ypampa',
#  'cilyo',
#  'pasqual',
#  '5',
#  'pso',
#  'senca',
#  'nictlasocamati',
#  'yn',
#  'motetlasotlalitzin',
#  'yn',
#  'tigamalier',
#  'ma',
#  'ximoyolchicauhtzino',
#  'ca',
#  'amo',
#  'huecauh',
#  'in',
#  'onquistihuitzis',
#  'in',
#  'motlayohuilitzin',
#  'izçan',
#  'huel',
#  'iyo',
#  'conmotzacuiltitia',
#  'inic',
#  'quimocuicapiquilili',
#  'in',
#  'tollan',
#  'cihuapilli',
#  'in',
#  'ichahuanantzin',
#  'izcihuahuan',
#  'tlacatl',
#  'auh',
#  'ca',
#  'huel',
#  'nixpa',
#  'yn',
#  'omochiuh',
#  'yn',
#  'tlamahuisoli',
#  'yhuan',
#  'yn',
#  'yehuatzin',
#  'cuix',
#  'amo',
#  'nochi',
#  'tlacatli',
#  'y',
#  'quimotlasotilia',
#  'yn',
#  'ica',
#  'yn',
#  'inecnomachilitzin',
#  'ma',
#  'yehuatzin',
#  'quimitalhui',
#  'yn',
#  'tleyn',
#  'ipan',
#  'mochihuas',
#  'yn',
#  'xpo',
#  'ma',
#  'xicmotili',
#  'ma',
#  'niman',
#  'yçiuhca',
#  'xicmonequiltican',
#  'nimā',
#  'ic',
#  'conanq̄',
#  'ce',
#  'vei',
#  'tiacauh',
#  'itoca',
#  'tlapaltecatl',
#  'opuchtzin',
#  'coatlan',
#  'ichā',
#  'niman',
#  'ie',
#  'ic',
#  'quichichioa',
#  'conaquique',
#  'in',
#  'quetzalteculotl',
#  'yn',
#  'amehuanti',
#  'ynn',
#  'ātestigos',
#  'macamo',
#  'ystlacatilistli',
#  'ytla',
#  'xiquitocan',
#  'yzcatqui',
#  'y',
#  'namechmonahuatilia',
#  'totech',
#  'omonequis',
#  'nima',
#  'miquistlatzōtequililos',
#  'ynic',
#  'huel',
#  'neltis',
#  'mochihuas',
#  'yn',
#  'tlatocanahuatili',
#  '“aço',
#  'aca',
#  'quiquixti',
#  'in',
#  'macevalli',
#  'atel',
#  'motlatemoliz',
#  'ahuin',
#  'senca',
#  'yehuanti',
#  'y',
#  'mohueytlacanequini',
#  'y',
#  'mopoanime',
#  'oytlahuelilti',
#  'ma',
#  'ximonemiliscuepaca',
#  'auh',
#  'ca',
#  'tel',
#  'camo',
#  'nosel',
#  'ca',
#  'oncan',
#  'notlan',
#  'mehuiltities',
#  'y',
#  'nonotlasotatzin',
#  'dios',
#  'aso',
#  'camo',
#  'yiolo',
#  'ic',
#  'pachihuis',
#  'ahu',
#  'in',
#  'amehuantin',
#  'yn',
#  'āchristianosme',
#  'tleyca',
#  'yn',
#  'san',
#  'iseltzin',
#  'aquimocahuiliyan',
#  'yn',
#  'inatzi',
#  'ds',
#  'yn',
#  'amo',
#  'achinton',
#  'cahuitl',
#  'axcan',
#  'miércoles',
#  '9',
#  'de',
#  'diciembre',
#  'xiuhtlapuali',
#  '1795',
#  'años',
#  'ninomachiotia',
#  'yca',
#  'ytlasomahuistocatzin',
#  'dios',
#  'tetahtzin',
#  'yhuan',
#  'dios',
#  'tepiltzin',
#  'yhuan',
#  'dios',
#  'espíritu',
#  'santo',
#  'onechmocnelilitzino',
#  'yn',
#  'tlatohūani',
#  'ponsio',
#  'pilato',
#  'quen',
#  'quinemiltia',
#  'yn',
#  'temac',
#  'onictlas',
#  'ma',
#  'nican',
#  'hualneçican',
#  'yn',
#  'tlaneltiliani',
#  'testigos',
#  'yn',
#  'jodas',
#  'san',
#  'caltenco',
#  'mocuepatin',
#  'tlato',
#  'quimohuiquilisque',
#  'telpiloya',
#  'çatepa',
#  'calacohuas',
#  'mochinti',
#  'yn',
#  'apostoles',
#  'yhūa',
#  'no',
#  'nicnequi',
#  'quinhuicasque',
#  'omentin',
#  'ichteque',
#  'teychtacamictiyani',
#  'niman',
#  'ie',
#  'ic',
#  'oalquiça',
#  'in',
#  'tlalhoacapā',
#  'in',
#  'tlalhoacpan',
#  'ca',
#  'mehuiltiticate',
#  'yn',
#  'teopixcatlatoque',
#  'yhuan',
#  'mehuiltitica',
#  'yn',
#  'huey',
#  'tlatoani',
#  'presidente',
#  'yhuan',
#  'ye',
#  'oquinnonotzque',
#  'in',
#  'inicnihuã',
#  'in',
#  'quipoloto',
#  'in',
#  'iquac',
#  'quitepotztocaque',
#  'tla',
#  'xiccaqui',
#  'noxocoyouh',
#  'motlacuaquetzas',
#  'yxpa',
#  'xpo',
#  'yn',
#  'tehuanti',
#  'san',
#  'toconchixticate',
#  'yn',
#  'amoteopixcatlanahuatiltzin',
#  'auh',
#  'nimā',
#  'vel',
#  'iquac',
#  'in',
#  'o',
#  'tlatlavizcalli',
#  'ieoac',
#  'in',
#  'otlatlalchipaoac',
#  'in',
#  'teçacoc',
#  'sn',
#  'pedro',
#  'yhua',
#  's',
#  'jn',
#  'sn',
#  'felipe',
#  'quimotemamaquilis',
#  'yn',
#  'tehuatl',
#  'amo',
#  'ticmmiimacaxilia',
#  'yn',
#  'dios',
#  'ca',
#  'ye',
#  'quali',
#  'tlatohuanie',
#  'ma',
#  'nicnotza',
#  'yn',
#  'telpochtli',
#  'ynic',
#  'nican',
#  'hualcalaquis',
#  'xinechnanquili',
#  'çetl',
#  'ocatca',
#  'nochpotzin',
#  'ytoca',
#  'doña',
#  'ana',
#  'cortés',
#  'xiloyectzin',
#  'çan',
#  'niçel',
#  'nopiltzin',
#  'ocatca',
#  'omach',
#  'cocotztlaloaq̄',
#  'auh',
#  'in',
#  'ie',
#  'ixquich',
#  'telputzintli',
#  'in',
#  'cuexpaltzine',
#  'in',
#  'cuexpaltzitzineque',
#  'yoan',
#  'in',
#  'tzotzocoleque',
#  'in',
#  'tepallamani',
#  'in',
#  'yiaque',
#  'in',
#  'moteneoa',
#  'in',
#  'telpuchiaque',
#  'in',
#  'ce',
#  'ic',
#  'nemi',
#  'in',
#  'ce',
#  'cacitinemi',
#  'in',
#  'anoço',
#  'vme',
#  'cacitinemi',
#  'no',
#  'quintzaquaia',
#  'quimilhuiaia',
#  'auh',
#  'sabado',
#  'catca',
#  'huel',
#  'oc',
#  'yohuatzinco',
#  'quihualtepotztocaya',
#  'in',
#  'teoyotl',
#  'yhuan',
#  'in',
#  'inetititlaniz',
#  'yn',
#  'tetennamiquilistican',
#  'ynic',
#  'temac',
#  'tictlasas',
#  'ynn',
#  'ichpochtli',
#  'ynconetzin',
#  'tlatohuaniyen',
#  'ca',
#  'ye',
#  'moyollotzin',
#  'opachiuh',
#  'auh',
#  'y',
#  'robeno',
#  'tlapechtenco',
#  'ycas',
#  'notlasomahuisnantzinne',
#  'ma',
#  'ximoyolalitzinno',
#  'ma',
#  'ximochicauhtzinno',
#  'ca',
#  'san',
#  'neli',
#  'nimitznolhuilitzinnohua',
#  ...]

# %%
unreg_pairs = [word[i:i+2] for word in unreg_set for i in range(len(word) - 1)]

# %%
unreg_pairs
# Out:
# ['ma',
#  'xi',
#  'in',
#  'ne',
#  'ec',
#  'ch',
#  'hm',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'ap',
#  'po',
#  'op',
#  'po',
#  'ol',
#  'lh',
#  'hu',
#  'ui',
#  'il',
#  'li',
#  'ni',
#  'it',
#  'tl',
#  'la',
#  'at',
#  'tl',
#  'la',
#  'ac',
#  'cu',
#  'ua',
#  'an',
#  'ni',
#  'ip',
#  'po',
#  'ol',
#  'cu',
#  'ui',
#  'ix',
#  'ti',
#  'ip',
#  'pi',
#  'il',
#  'lt',
#  'tz',
#  'zi',
#  'in',
#  'di',
#  'io',
#  'os',
#  'mo',
#  'on',
#  'ne',
#  'et',
#  'tl',
#  'la',
#  'am',
#  'ma',
#  'ac',
#  'ch',
#  'ht',
#  'ti',
#  'il',
#  'mo',
#  'oc',
#  'ch',
#  'hi',
#  'ih',
#  'hu',
#  'ua',
#  'as',
#  'yn',
#  'nn',
#  'ōp',
#  'pa',
#  'yl',
#  'lh',
#  'hu',
#  'ui',
#  'ic',
#  'ca',
#  'ac',
#  'au',
#  'uh',
#  'hh',
#  'hu',
#  'ui',
#  'in',
#  'ax',
#  'xc',
#  'ca',
#  'an',
#  'ma',
#  'oc',
#  'no',
#  'am',
#  'me',
#  'eh',
#  'hu',
#  'ua',
#  'an',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'nt',
#  'ti',
#  'xi',
#  'im',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'an',
#  'nt',
#  'tl',
#  'la',
#  'au',
#  'uh',
#  'ht',
#  'ti',
#  'il',
#  'li',
#  'ic',
#  'ca',
#  'an',
#  'oa',
#  'an',
#  'nq',
#  'qu',
#  'ui',
#  'ii',
#  'iy',
#  'yo',
#  'oh',
#  'hu',
#  'ui',
#  'iq',
#  'qu',
#  'ue',
#  'xo',
#  'ol',
#  'lo',
#  'ot',
#  'to',
#  'ot',
#  'to',
#  'on',
#  'au',
#  'uh',
#  'yn',
#  'ax',
#  'xc',
#  'ca',
#  'ca',
#  'yo',
#  'ni',
#  'ic',
#  'ct',
#  'tl',
#  'la',
#  'al',
#  'lc',
#  'ca',
#  'ah',
#  'hu',
#  'ui',
#  'yc',
#  'qu',
#  'ui',
#  'is',
#  'sa',
#  'az',
#  'yn',
#  'ca',
#  'an',
#  'nd',
#  'de',
#  'el',
#  'll',
#  'la',
#  'as',
#  'ca',
#  'ho',
#  'on',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hn',
#  'no',
#  'ot',
#  'ti',
#  'it',
#  'ti',
#  'il',
#  'li',
#  'no',
#  'ot',
#  'te',
#  'et',
#  'tl',
#  'la',
#  'as',
#  'so',
#  'ot',
#  'tl',
#  'la',
#  'al',
#  'li',
#  'it',
#  'tz',
#  'zi',
#  'in',
#  'yn',
#  'no',
#  'ot',
#  'te',
#  'et',
#  'tl',
#  'la',
#  'ac',
#  'co',
#  'ol',
#  'li',
#  'il',
#  'li',
#  'it',
#  'tz',
#  'zi',
#  'no',
#  'ot',
#  'tl',
#  'la',
#  'as',
#  'so',
#  'om',
#  'ma',
#  'ah',
#  'hu',
#  'ui',
#  'is',
#  'sc',
#  'co',
#  'on',
#  'ne',
#  'et',
#  'tz',
#  'zi',
#  'in',
#  'ca',
#  'yo',
#  'oq',
#  'qu',
#  'ui',
#  'qu',
#  'ui',
#  'im',
#  'mo',
#  'on',
#  'ne',
#  'eq',
#  'qu',
#  'ui',
#  'it',
#  'ti',
#  'ia',
#  'yn',
#  'se',
#  'en',
#  'nc',
#  'ca',
#  'ye',
#  'eh',
#  'hu',
#  'ua',
#  'at',
#  'tz',
#  'zi',
#  'in',
#  'yn',
#  'ti',
#  'ic',
#  'cm',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'ac',
#  'ca',
#  'am',
#  'ma',
#  'ac',
#  'ch',
#  'hi',
#  'il',
#  'lt',
#  'ti',
#  'it',
#  'tz',
#  'zi',
#  'in',
#  'nn',
#  'no',
#  'os',
#  'yn',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'as',
#  'so',
#  'ot',
#  'ta',
#  'at',
#  'tz',
#  'zi',
#  'in',
#  'di',
#  'io',
#  'os',
#  'ca',
#  'mo',
#  'op',
#  'pa',
#  'aq',
#  'qu',
#  'ui',
#  'il',
#  'lt',
#  'ti',
#  'it',
#  'ti',
#  'ic',
#  'ca',
#  'in',
#  'mo',
#  'oh',
#  'hu',
#  'ue',
#  'ep',
#  'po',
#  'ol',
#  'lt',
#  'tz',
#  'zi',
#  'in',
#  'ih',
#  'hu',
#  'ua',
#  'an',
#  'in',
#  'mo',
#  'oc',
#  'cn',
#  'no',
#  'ot',
#  'tl',
#  'la',
#  'ac',
#  'ca',
#  'ah',
#  'hu',
#  'ua',
#  'an',
#  'pi',
#  'ip',
#  'pi',
#  'il',
#  'lt',
#  'to',
#  'ot',
#  'to',
#  'on',
#  'nt',
#  'ti',
#  'in',
#  'ca',
#  'pa',
#  'ac',
#  'ct',
#  'ti',
#  'in',
#  'ne',
#  'em',
#  'mi',
#  'ye',
#  'eh',
#  'hu',
#  'uā',
#  'āt',
#  'ti',
#  'qu',
#  'ui',
#  'it',
#  'to',
#  'os',
#  'sq',
#  'qu',
#  'ue',
#  'yn',
#  'tl',
#  'le',
#  'en',
#  'on',
#  'ni',
#  'it',
#  'te',
#  'em',
#  'ma',
#  'ac',
#  'ch',
#  'ht',
#  'ti',
#  'ia',
#  'ay',
#  'ya',
#  'ca',
#  'ne',
#  'el',
#  'li',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hi',
#  'il',
#  'lh',
#  'hu',
#  'ui',
#  'ia',
#  'ca',
#  'in',
#  'tl',
#  'la',
#  'ac',
#  'ca',
#  'at',
#  'te',
#  'ec',
#  'co',
#  'ol',
#  'lo',
#  'ot',
#  'tl',
#  'ca',
#  'oa',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hm',
#  'mi',
#  'in',
#  'nt',
#  'tl',
#  'la',
#  'an',
#  'ni',
#  'in',
#  'ny',
#  'yc',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hs',
#  'se',
#  'es',
#  'se',
#  'em',
#  'ma',
#  'an',
#  'na',
#  'as',
#  'in',
#  'iu',
#  'uh',
#  'hq',
#  'qu',
#  'ui',
#  'tr',
#  'ri',
#  'ig',
#  'go',
#  'mo',
#  'os',
#  'se',
#  'es',
#  'se',
#  'em',
#  'ma',
#  'an',
#  'na',
#  'mo',
#  'oc',
#  'ch',
#  'ha',
#  'ay',
#  'ya',
#  'ah',
#  'hu',
#  'ua',
#  'cu',
#  'ui',
#  'ix',
#  'am',
#  'mo',
#  'sa',
#  'an',
#  'on',
#  'ne',
#  'ep',
#  'po',
#  'ol',
#  'li',
#  'yn',
#  'ca',
#  'an',
#  'np',
#  'pa',
#  'mo',
#  'oc',
#  'ca',
#  'al',
#  'la',
#  'aq',
#  'qu',
#  'ui',
#  'it',
#  'ti',
#  'iu',
#  'uh',
#  'no',
#  'om',
#  'ma',
#  'at',
#  'ti',
#  'ic',
#  'ca',
#  'on',
#  'np',
#  'pa',
#  'an',
#  'nm',
#  'mo',
#  'oc',
#  'ca',
#  'al',
#  'la',
#  'aq',
#  'qu',
#  'ui',
#  'iz',
#  'zq',
#  'qu',
#  'ue',
#  'ye',
#  'es',
#  'se',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hi',
#  'il',
#  'lh',
#  'hu',
#  'ui',
#  'ia',
#  'in',
#  'ip',
#  'pi',
#  'il',
#  'lt',
#  'tz',
#  'zi',
#  'in',
#  'di',
#  'io',
#  'os',
#  'ca',
#  'ye',
#  'ec',
#  'ca',
#  'an',
#  'nc',
#  'co',
#  'op',
#  'pa',
#  'an',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'nc',
#  'co',
#  'me',
#  'eh',
#  'hu',
#  'ui',
#  'il',
#  'lt',
#  'ti',
#  'it',
#  'ti',
#  'ie',
#  'es',
#  'in',
#  'di',
#  'io',
#  'os',
#  'yn',
#  'āh',
#  'hu',
#  'ue',
#  'el',
#  'on',
#  'nm',
#  'mi',
#  'ic',
#  'cu',
#  'ua',
#  'an',
#  'ni',
#  'is',
#  'yn',
#  'cm',
#  'mc',
#  'au',
#  'uh',
#  'ye',
#  'in',
#  'iq',
#  'qu',
#  'ua',
#  'ac',
#  'yu',
#  'uh',
#  'ni',
#  'in',
#  'no',
#  'ot',
#  'tt',
#  'ta',
#  'ac',
#  'in',
#  'hu',
#  'ue',
#  'el',
#  'on',
#  'ni',
#  'in',
#  'no',
#  'oo',
#  'oh',
#  'hu',
#  'ui',
#  'ic',
#  'ca',
#  'an',
#  'na',
#  'aq',
#  'qu',
#  'ui',
#  'in',
#  'ao',
#  'oc',
#  'cc',
#  'cã',
#  'hu',
#  'ue',
#  'el',
#  'ni',
#  'im',
#  'ma',
#  'aq',
#  'qu',
#  'ui',
#  'iç',
#  'ça',
#  'az',
#  'ca',
#  'ye',
#  'ep',
#  'pp',
#  'pa',
#  'ni',
#  'im',
#  'mi',
#  'iq',
#  'qu',
#  'ui',
#  'iz',
#  'ni',
#  'ip',
#  'po',
#  'op',
#  'po',
#  'ol',
#  'li',
#  'ih',
#  'hu',
#  'ui',
#  'iz',
#  'in',
#  'ni',
#  'im',
#  'ma',
#  'an',
#  'ao',
#  'oc',
#  'ct',
#  'tl',
#  'le',
#  'on',
#  'nc',
#  'ca',
#  'at',
#  'tc',
#  'ca',
#  'no',
#  'op',
#  'pa',
#  'al',
#  'le',
#  'eh',
#  'hu',
#  'ui',
#  'il',
#  'lo',
#  'oc',
#  'ca',
#  'çã',
#  'ni',
#  'im',
#  'mã',
#  'iq',
#  'qu',
#  'ua',
#  'ac',
#  'çe',
#  'en',
#  'nm',
#  'mo',
#  'oc',
#  'ch',
#  'ic',
#  'ca',
#  'in',
#  'no',
#  'oy',
#  'yo',
#  'ol',
#  'll',
#  'lo',
#  'ni',
#  'ic',
#  'cn',
#  'no',
#  'ot',
#  'tz',
#  'za',
#  'tz',
#  'zi',
#  'il',
#  'li',
#  'il',
#  'li',
#  'iz',
#  'zç',
#  'çe',
#  'en',
#  'nq',
#  'qu',
#  'ui',
#  'iz',
#  'zc',
#  'ca',
#  'ai',
#  'ic',
#  'ch',
#  'hp',
#  'po',
#  'oc',
#  'ch',
#  'ht',
#  'tz',
#  'zi',
#  'in',
#  'nt',
#  'tl',
#  'li',
#  'il',
#  'lh',
#  'hu',
#  'ui',
#  'ic',
#  'ca',
#  'ac',
#  'çi',
#  'ih',
#  'hu',
#  'ua',
#  'ap',
#  'pi',
#  'il',
#  'll',
#  'li',
#  'to',
#  'ot',
#  'tl',
#  'la',
#  'aç',
#  'ço',
#  'on',
#  'na',
#  'an',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'gu',
#  'ua',
#  'ad',
#  'da',
#  'al',
#  'lu',
#  'up',
#  'pe',
#  'in',
#  'ni',
#  'ic',
#  'ma',
#  'ne',
#  'ec',
#  'ch',
#  'hm',
#  'mo',
#  'oc',
#  'cn',
#  'no',
#  'oi',
#  'it',
#  'tt',
#  'ti',
#  'il',
#  'li',
#  'ma',
#  'ne',
#  'ec',
#  'ch',
#  'hm',
#  'mo',
#  'op',
#  'pa',
#  'al',
#  'le',
#  'eh',
#  'hu',
#  'ui',
#  'il',
#  'li',
#  'cr',
#  'ru',
#  'uz',
#  'zt',
#  'ti',
#  'it',
#  'te',
#  'ec',
#  'ch',
#  'qu',
#  'ui',
#  'im',
#  'ma',
#  'am',
#  'ma',
#  'as',
#  'so',
#  'oh',
#  'hu',
#  'ua',
#  'al',
#  'lt',
#  'ti',
#  'is',
#  'sq',
#  'qu',
#  'ue',
#  'au',
#  'uh',
#  'yn',
#  'ax',
#  'xc',
#  'ca',
#  'an',
#  'op',
#  'pa',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hn',
#  'no',
#  'oh',
#  'hu',
#  'ui',
#  'iq',
#  'qu',
#  'ui',
#  'il',
#  'li',
#  'it',
#  'ti',
#  'iu',
#  'uh',
#  'yn',
#  'nt',
#  'tl',
#  'la',
#  'sa',
#  'an',
#  'mo',
#  'on',
#  'na',
#  'am',
#  'ma',
#  'ac',
#  'ca',
#  'an',
#  'ni',
#  'ām',
#  'mo',
#  'sa',
#  'an',
#  'ca',
#  'ax',
#  'xt',
#  'to',
#  'ol',
#  'lp',
#  'po',
#  'oh',
#  'hu',
#  'ua',
#  'al',
#  'li',
#  'pe',
#  'es',
#  'so',
#  'os',
#  'yp',
#  'pa',
#  'at',
#  'ti',
#  'iu',
#  'uh',
#  'oy',
#  'ye',
#  'es',
#  'sq',
#  'qu',
#  'ui',
#  'ia',
#  'au',
#  'uh',
#  'ca',
#  'am',
#  'mo',
#  'ye',
#  'eh',
#  'hu',
#  'ua',
#  'at',
#  'tl',
#  'mo',
#  'oc',
#  'ch',
#  'hi',
#  'ih',
#  'hu',
#  'ua',
#  'as',
#  'in',
#  'tl',
#  'le',
#  'en',
#  'ni',
#  'ic',
#  'cn',
#  'ne',
#  ...]

# %% [markdown]
# #### The 100 Most Common Pairs

# %%
unreg_counts = Counter(unreg_pairs)

# %%
unreg_counts.most_common(100)
# Out:
# [('ui', 18441),
#  ('in', 17925),
#  ('qu', 17743),
#  ('tl', 17693),
#  ('ca', 17569),
#  ('hu', 14904),
#  ('an', 14623),
#  ('la', 13657),
#  ('ti', 13096),
#  ('ic', 12541),
#  ('mo', 10109),
#  ('li', 9962),
#  ('at', 9514),
#  ('ua', 9432),
#  ('yn', 9011),
#  ('ni', 8901),
#  ('il', 8729),
#  ('ma', 8683),
#  ('it', 8681),
#  ('ch', 8563),
#  ('ac', 8492),
#  ('tz', 8289),
#  ('ot', 7840),
#  ('te', 7705),
#  ('ue', 7466),
#  ('al', 6943),
#  ('oc', 6900),
#  ('to', 5980),
#  ('pa', 5898),
#  ('zi', 5814),
#  ('no', 5518),
#  ('uh', 5469),
#  ('ne', 5445),
#  ('on', 5193),
#  ('im', 4730),
#  ('co', 4567),
#  ('nt', 4484),
#  ('am', 4322),
#  ('ec', 4285),
#  ('ia', 4058),
#  ('is', 3861),
#  ('hi', 3817),
#  ('mi', 3791),
#  ('lt', 3701),
#  ('as', 3499),
#  ('el', 3480),
#  ('ol', 3437),
#  ('en', 3346),
#  ('au', 3336),
#  ('ah', 2922),
#  ('na', 2920),
#  ('iq', 2846),
#  ('ih', 2830),
#  ('nc', 2804),
#  ('xi', 2770),
#  ('cu', 2763),
#  ('ye', 2691),
#  ('ix', 2574),
#  ('om', 2519),
#  ('eh', 2453),
#  ('lo', 2304),
#  ('et', 2238),
#  ('ht', 2201),
#  ('oh', 2200),
#  ('aq', 2163),
#  ('po', 2136),
#  ('yo', 2133),
#  ('le', 2109),
#  ('pi', 2052),
#  ('oa', 1990),
#  ('os', 1963),
#  ('oq', 1916),
#  ('op', 1896),
#  ('iz', 1813),
#  ('iu', 1779),
#  ('me', 1761),
#  ('lh', 1704),
#  ('em', 1680),
#  ('ep', 1608),
#  ('eq', 1583),
#  ('se', 1551),
#  ('sa', 1524),
#  ('ap', 1516),
#  ('es', 1509),
#  ('io', 1508),
#  ('sq', 1467),
#  ('ct', 1444),
#  ('ll', 1435),
#  ('ta', 1328),
#  ('ie', 1328),
#  ('so', 1325),
#  ('ya', 1322),
#  ('ip', 1291),
#  ('ce', 1209),
#  ('ay', 1191),
#  ('cm', 1067),
#  ('st', 1056),
#  ('ey', 1052),
#  ('pe', 1023),
#  ('xc', 976)]

# %% [markdown]
# ### Finding the Most Common Pairs of Letters for Normalized Sentences

# %%
reg_non_test = pd.concat([train["Regularized"], val["Regularized"]])

# %%
reg_non_test
# Out:
# 0          ma xinechmotlapohpolhuili in nitlahtlacoanipol.
# 1                                     cuix tipiltzin dios?
# 2               monetlamachtil mochihuaz in ompa ilhuicac.
# 3                                             auh in axcan
# 4         ma oc no amehhuantzitzintin ximotlatlauhtilican.
#                                ...
# 25193                                          telpochtli.
# 25194                              in ihcuac anquittazqueh
# 25195               tenilpihtica anquihualmohuiquilizqueh.
# 25196    ceppa ce caxtiltecatl ixpantzinco motlancuaque...
# 25197                            totlazohnantzin guadalupe
# Name: Regularized, Length: 25198, dtype: object

# %%
reg_set = reg_non_test.copy()

reg_set = reg_set.to_list()
reg_set = " ".join(reg_set)
reg_set = reg_set.translate(str.maketrans("", "", string.punctuation))
reg_set = reg_set.split()

# %%
reg_set
# Out:
# ['ma',
#  'xinechmotlapohpolhuili',
#  'in',
#  'nitlahtlacoanipol',
#  'cuix',
#  'tipiltzin',
#  'dios',
#  'monetlamachtil',
#  'mochihuaz',
#  'in',
#  'ompa',
#  'ilhuicac',
#  'auh',
#  'in',
#  'axcan',
#  'ma',
#  'oc',
#  'no',
#  'amehhuantzitzintin',
#  'ximotlatlauhtilican',
#  'oanquihiyohuihqueh',
#  'xolototon',
#  'auh',
#  'in',
#  'axcan',
#  'ca',
#  'ye',
#  'onictlalcahuih',
#  'ic',
#  'quizaz',
#  'in',
#  'candelas',
#  'ca',
#  'onamechnottitilih',
#  'in',
#  'notetlazohtlaliztzin',
#  'in',
#  'notetlaocoliliztzin',
#  'notlazohmahuizconetzin',
#  'ca',
#  'iuhqui',
#  'quimonequitia',
#  'in',
#  'cencah',
#  'yehhuatzin',
#  'in',
#  'ticmotlacamachiltihtzinoz',
#  'in',
#  'motlazohtahtzin',
#  'dios',
#  'ca',
#  'mopaquiltihticah',
#  'in',
#  'mohuehpoltzin',
#  'ihuan',
#  'in',
#  'mocnotlacahuan',
#  'pipiltotontin',
#  'ca',
#  'pactinemih',
#  'yehhuantin',
#  'quihtozqueh',
#  'in',
#  'tlein',
#  'onitemachtiaya',
#  'ca',
#  'nelli',
#  'namechilhuia',
#  'ca',
#  'in',
#  'tlacatecolotl',
#  'ca',
#  'oamechmihtlanih',
#  'inic',
#  'amechcehcemmanaz',
#  'in',
#  'iuhqui',
#  'trigoh',
#  'mocehcemmana',
#  'mochayahua',
#  'cuix',
#  'ahmo',
#  'zan',
#  'onempoliuh',
#  'in',
#  'campa',
#  'mocalaquitiuh',
#  'nohmahtica',
#  'ompa',
#  'ammocalaquizqueh',
#  'yeceh',
#  'namechilhuia',
#  'in',
#  'ipiltzin',
#  'dios',
#  'ca',
#  'imayeccancopatzinco',
#  'mehuiltihtiyez',
#  'in',
#  'dios',
#  'in',
#  'ahhuel',
#  'ommihcuaniz',
#  'in',
#  'cemanahuac',
#  'auh',
#  'yeh',
#  'in',
#  'ihcuac',
#  'o',
#  'iuh',
#  'ninottac',
#  'in',
#  'huel',
#  'oninoohuihcanaquih',
#  'in',
#  'aoccan',
#  'huel',
#  'nimaquizaz',
#  'ca',
#  'yeppa',
#  'nimiquiz',
#  'nipohpolihuiz',
#  'in',
#  'niman',
#  'aoc',
#  'tleh',
#  'oncatca',
#  'nopalehuiloca',
#  'zan',
#  'niman',
#  'ihcuac',
#  'cemmoch',
#  'ica',
#  'in',
#  'noyolloh',
#  'nicnotzahtzililih',
#  'in',
#  'cenquizcaichpochtzintli',
#  'ilhuicac',
#  'cihuapilli',
#  'totlazohnantzin',
#  'guadalupe',
#  'inic',
#  'ma',
#  'nechmocnoittili',
#  'ma',
#  'nechmopalehuili',
#  'quimahmazohualtizqueh',
#  'auh',
#  'in',
#  'axcan',
#  'ompa',
#  'namechnohuiquilitiuh',
#  'in',
#  'tla',
#  'zan',
#  'monamacani',
#  'ahmo',
#  'zan',
#  'caxtolpohualli',
#  'pesos',
#  'ipatiuh',
#  'oyezquia',
#  'auh',
#  'ca',
#  'ahmo',
#  'yehhuatl',
#  'mochihuaz',
#  'in',
#  'tlein',
#  'nicnequi',
#  'ca',
#  'zan',
#  'yehhuatl',
#  'mochihuaz',
#  'in',
#  'motlanequiliztzin',
#  'monehnemitiz',
#  'in',
#  'san',
#  'juan',
#  'hualmoquixtiz',
#  'cristo',
#  'ihuan',
#  'apóstoles',
#  'ihuan',
#  'judíos',
#  'quen',
#  'ticmomachiltia',
#  'in',
#  'monacayotzin',
#  'in',
#  'oquicuiqueh',
#  'amatlan',
#  'inic',
#  'huiyac',
#  'chicompohualli',
#  'ic',
#  'patlahuac',
#  'ompohualli',
#  'axcan',
#  'xictlahpaltili',
#  'in',
#  'moma',
#  'oc',
#  'achi',
#  'cualli',
#  'in',
#  'amohuicazqueh',
#  'in',
#  'nochantzinco',
#  'in',
#  'ilhuicatl',
#  'ihtic',
#  'notlazohpilhuane',
#  'ca',
#  'ye',
#  'anquimomachiztiah',
#  'ca',
#  'zan',
#  'huiptla',
#  'in',
#  'ilhuitl',
#  'yez',
#  'in',
#  'pascuah',
#  'nopiltzintzine',
#  'ca',
#  'ahhuel',
#  'timitztoztlacahuilizqueh',
#  'niman',
#  'temocxipaquiliz',
#  'xinechmelauhcailhui',
#  'tlein',
#  'oticchiuh',
#  'tlein',
#  'otiquihtlacoh',
#  'inic',
#  'titeixpanhuilo',
#  'totecuiyoe',
#  'cuix',
#  'titehuitequizqueh',
#  'niman',
#  'quimonochiliz',
#  'in',
#  'magdalena',
#  'in',
#  'santa',
#  'maría',
#  'ahzo',
#  'tocnopil',
#  'ahzo',
#  'tomahcehual',
#  'mochihuaz',
#  'auh',
#  'ca',
#  'axcan',
#  'mochi',
#  'nican',
#  'anquimottilizqueh',
#  'tlahtoani',
#  'temachtiani',
#  'ca',
#  'ye',
#  'oyahqueh',
#  'in',
#  'huel',
#  'mahuiztic',
#  'yez',
#  'huellapanahuiaz',
#  'inic',
#  'cualli',
#  'yez',
#  'auh',
#  'in',
#  'imitzcuinhuan',
#  'yacattihuitzeh',
#  'iyohyahue',
#  'omochiuh',
#  'onotlahueliltic',
#  'xicmacacan',
#  'in',
#  'atl',
#  'quihtlani',
#  'quimonahuatequiliz',
#  'in',
#  'cruz',
#  'ma',
#  'xinechilhui',
#  'ahmo',
#  'ic',
#  'ammozotlahuazqueh',
#  'cacoquiz',
#  'itzontecon',
#  'commottiliz',
#  'in',
#  'cristo',
#  'cuix',
#  'otimitzanatoh',
#  'xiquizacan',
#  'xihuian',
#  'quiyahuac',
#  'xiccahuacan',
#  'in',
#  'icaltzin',
#  'in',
#  'notlazohtahtzin',
#  'dios',
#  'ma',
#  'xicmomachiltican',
#  'ca',
#  'huallahque',
#  'inin',
#  'altepetl',
#  'omentin',
#  'itlamachtilhuan',
#  'huel',
#  'oticcaquilihqueh',
#  'quihtohtinemi',
#  'tla',
#  'ximehuiltihtiyecan',
#  'nocihuapiltzin',
#  'namechonnomohcihuiliz',
#  'ca',
#  'zan',
#  'nican',
#  'amopantzinco',
#  'niquiztehua',
#  'amocatzinco',
#  'nitlahtlantiquiza',
#  'ahzo',
#  'tepitzin',
#  'anquimomahcehuihtzinoah',
#  'in',
#  'itechicahualiztzin',
#  'in',
#  'tlacatl',
#  'in',
#  'totecuiyo',
#  'ca',
#  'ye',
#  'ixquich',
#  'cahuitl',
#  'in',
#  'in',
#  'aoquic',
#  'amixtzinco',
#  'amocpactzinco',
#  'nitlachiya',
#  'huel',
#  'cencah',
#  'miyac',
#  'inic',
#  'quimmotlazohtilih',
#  'inic',
#  'quimmopalehuilih',
#  'inic',
#  'quimmomanahuilih',
#  'in',
#  'ilhuicac',
#  'cihuapilli',
#  'cenquizcaichpochtli',
#  'santa',
#  'maría',
#  'in',
#  'nican',
#  'tlacah',
#  'inic',
#  'huel',
#  'quimomacazqueh',
#  'in',
#  'itech',
#  'hualmopachozqueh',
#  'in',
#  'tlaneltoquiliztli',
#  'auh',
#  'inhuan',
#  'quihuicazqueh',
#  'in',
#  'jesús',
#  'in',
#  'ompa',
#  'tepeticpac',
#  'in',
#  'ompa',
#  'techihuililoyan',
#  'justiciah',
#  'itocayocan',
#  'calvario',
#  'ma',
#  'xicmocaquilti',
#  'tlahtoanie',
#  'izcatqui',
#  'in',
#  'ticmachiliah',
#  'in',
#  'nican',
#  'ilpihtihcac',
#  'teixcuepani',
#  'za',
#  'iuhquin',
#  'tecuani',
#  'oncan',
#  'tel',
#  'iuh',
#  'mochiuh',
#  'auh',
#  'in',
#  'juan',
#  'diego',
#  'niman',
#  'ic',
#  'huallamelauh',
#  'quitocac',
#  'in',
#  'cuepohtli',
#  'auh',
#  'in',
#  'quihualtepotztocayah',
#  'oncan',
#  'atlauhtli',
#  'quiza',
#  'inahuac',
#  'tepeyacac',
#  'cuauhpantitlan',
#  'quipoloco',
#  'ca',
#  'quimihtalhuiah',
#  'in',
#  'tlahtohqueh',
#  'ca',
#  'mitzmomaquiliah',
#  'in',
#  'cempohualli',
#  'tlatemantli',
#  'teocuitlatl',
#  'cuix',
#  'noceh',
#  'itlah',
#  'mopantzinco',
#  'quihualmihualia',
#  'in',
#  'itemoxtzin',
#  'in',
#  'iehecatzin',
#  'in',
#  'mimicqueh',
#  'omozcalihqueh',
#  'otlachiyacoh',
#  'in',
#  'tlalticpac',
#  'tlananquilizqueh',
#  'mochintin',
#  'in',
#  'judíosmeh',
#  'ca',
#  'zan',
#  'noceltzin',
#  'in',
#  'annechcauhtiquizazqueh',
#  'ahmo',
#  'anquilcahuazqueh',
#  'in',
#  'notlahtoltzin',
#  'ic',
#  'namechilpihtehua',
#  'namechtetzilohtehua',
#  'cuix',
#  'nozo',
#  'zan',
#  'iuhqui',
#  'yez',
#  'ca',
#  'huel',
#  'nechmauhtia',
#  'oncan',
#  'quimotlalhuitequilizqueh',
#  'ohtlica',
#  'in',
#  'cristo',
#  'quiquetz',
#  'in',
#  'iteohcaltzin',
#  'in',
#  'itlazohixiptlatzin',
#  'in',
#  'ilhuicac',
#  'cihuapilli',
#  'moteneuhtzinoa',
#  'remedios',
#  'in',
#  'oncan',
#  'axcan',
#  'moyetzticah',
#  'ay',
#  'ma',
#  'huel',
#  'xiquittacan',
#  'aquin',
#  'onechhualnacaztlaz',
#  'tiahcahuane',
#  'ic',
#  'ontlamantli',
#  'nitlanahuatia',
#  'inin',
#  'caltzintli',
#  'nicmacatiuh',
#  'nopiltzin',
#  'salvador',
#  'de',
#  'los',
#  'reyes',
#  'ihuan',
#  'nochpoch',
#  'bernardina',
#  'de',
#  'los',
#  'reyes',
#  'oncan',
#  'yezqueh',
#  'inehuan',
#  'auh',
#  'cencah',
#  'amehhuantin',
#  'anquimatih',
#  'in',
#  'tla',
#  'anquichololtihtin',
#  'ca',
#  'aocmo',
#  'nehhuatl',
#  'notlahtlacol',
#  'in',
#  'nocal',
#  'ixquich',
#  'ic',
#  'mani',
#  'ca',
#  'huel',
#  'nixcohyan',
#  'ye',
#  'tinechmocahuilia',
#  'in',
#  'nimonantzin',
#  'mocauhtzinoz',
#  'cristo',
#  'ihuan',
#  'mochintin',
#  'apóstoles',
#  'ca',
#  'yehhuatl',
#  'in',
#  'atlacatzintli',
#  'in',
#  'otechmonahuatilih',
#  'in',
#  'totemachtihcatzin',
#  'ca',
#  'yehhuatl',
#  'in',
#  'nomiquiz',
#  'yaoyotl',
#  'ic',
#  'nicpanahuiz',
#  'in',
#  'teyaoh',
#  'ic',
#  'nictlaniz',
#  'in',
#  'innemaquixtiliz',
#  'in',
#  'notlachihualhuan',
#  'xinechilhui',
#  'in',
#  'ac',
#  'tehhuatl',
#  'tlahtoanie',
#  'oc',
#  'cepa',
#  'mixpantzinco',
#  'otichualhuicaqueh',
#  'inin',
#  'tetlapololtiani',
#  'moquetztzinoz',
#  'cristo',
#  'auh',
#  'ca',
#  'zan',
#  'yehhuatl',
#  'inic',
#  'otechhualmotitlanih',
#  'in',
#  'tomextin',
#  'ca',
#  'ye',
#  'cualtzin',
#  'nopiltzintzine',
#  'notlahtoanie',
#  'in',
#  'quihtohtinemih',
#  'in',
#  'quiteilhuiah',
#  'inic',
#  'yehhuatl',
#  'in',
#  'mesías',
#  'ca',
#  'ye',
#  'oahcico',
#  'in',
#  'cahuitl',
#  'inic',
#  'anquimottilizqueh',
#  'in',
#  'amotemachtihcauh',
#  'immac',
#  'cahualoz',
#  'in',
#  'tlahtlacoanimeh',
#  'ma',
#  'xicmonochilican',
#  'in',
#  'telpochtli',
#  'ihuan',
#  'titemacaloh',
#  'macuilli',
#  'peso',
#  'ipampa',
#  'cirio',
#  'pascual',
#  '5',
#  'pesos',
#  'cencah',
#  'nictlazohcamati',
#  'in',
#  'motetlazohtlaliztzin',
#  'in',
#  'tigamaliel',
#  'ma',
#  'ximoyolchicauhtzino',
#  'ca',
#  'ahmo',
#  'huehcauh',
#  'in',
#  'onquiztihuitziz',
#  'in',
#  'motlaihiyohuiliztzin',
#  'in',
#  'zan',
#  'huel',
#  'iyoh',
#  'commotzacuiltihtiyah',
#  'inic',
#  'quimocuicapiquililih',
#  'in',
#  'tollan',
#  'cihuapilli',
#  'in',
#  'ichahuanantzin',
#  'in',
#  'cihuahuan',
#  'tlacatl',
#  'auh',
#  'ca',
#  'huel',
#  'nixpan',
#  'in',
#  'omochiuh',
#  'in',
#  'tlamahuizolli',
#  'ihuan',
#  'in',
#  'yehhuatzin',
#  'cuix',
#  'ahmo',
#  'mochi',
#  'tlacatl',
#  'in',
#  'quimotlazohtilia',
#  'in',
#  'ica',
#  'in',
#  'inecnomachiliztzin',
#  'ma',
#  'yehhuatzin',
#  'quimihtalhui',
#  'in',
#  'tlein',
#  'ipan',
#  'mochihuaz',
#  'in',
#  'cristo',
#  'ma',
#  'xicmottili',
#  'ma',
#  'niman',
#  'ihciuhca',
#  'xicmonequiltican',
#  'niman',
#  'ic',
#  'conanqueh',
#  'ce',
#  'huei',
#  'tiacauh',
#  'itoca',
#  'tlapaltecatl',
#  'opochtzin',
#  'coatlan',
#  'ichan',
#  'niman',
#  'ye',
#  'ic',
#  'quichihchihuah',
#  'conaquihqueh',
#  'in',
#  'quetzaltecolotl',
#  'in',
#  'amehhuantin',
#  'in',
#  'antestigos',
#  'macamo',
#  'iztlacatiliztli',
#  'itlah',
#  'xiquihtocan',
#  'izcatqui',
#  'in',
#  'namechnonahuatilia',
#  'totech',
#  'ommonequiz',
#  'niman',
#  'miquiztlatzontequililoz',
#  'inic',
#  'huel',
#  'neltiz',
#  'mochihuaz',
#  'in',
#  'tlahtohcanahuatili',
#  '“ahzo',
#  'acah',
#  'quiquixtih',
#  'in',
#  'macehualli',
#  'ahtel',
#  'motlatemoliz',
#  'auh',
#  'in',
#  'cencah',
#  'yehhuantin',
#  'in',
#  'mohueitlacanequinih',
#  'in',
#  'mopohuanimeh',
#  'ointlahueliltic',
#  'ma',
#  'ximonemilizcuepacan',
#  'auh',
#  'ca',
#  'tel',
#  'ca',
#  'ahmo',
#  'nocel',
#  'ca',
#  'oncan',
#  'notlan',
#  'mehuiltihtiyez',
#  'in',
#  'notlazohtahtzin',
#  'dios',
#  'ahzo',
#  'ca',
#  'ahmo',
#  'iyollo',
#  'ic',
#  'pachihuiz',
#  'auh',
#  'in',
#  'amehhuantin',
#  'in',
#  'ancristianosmeh',
#  'tleica',
#  'in',
#  'zan',
#  'iceltzin',
#  'anquimocahuiliah',
#  'in',
#  'inantzin',
#  'dios',
#  'in',
#  'ahmo',
#  'achihton',
#  'cahuitl',
#  'axcan',
#  'miércoles',
#  '9',
#  'de',
#  'diciembre',
#  'xiuhtlapohualli',
#  '1795',
#  'años',
#  'ninomachiyotia',
#  'ica',
#  'itlazohmahuiztocatzin',
#  'dios',
#  'tetahtzin',
#  'ihuan',
#  'dios',
#  'tepiltzin',
#  'ihuan',
#  'dios',
#  'espíritu',
#  'santo',
#  'onechmocnelilihtzinoh',
#  'in',
#  'tlahtoani',
#  'poncio',
#  'pilato',
#  'quen',
#  'quinemiltiah',
#  'in',
#  'temac',
#  'onictlaz',
#  'ma',
#  'nican',
#  'hualnecican',
#  'in',
#  'tlaneltilianih',
#  'testigos',
#  'in',
#  'judas',
#  'zan',
#  'caltenco',
#  'mocuepatiuh',
#  'tlahtoz',
#  'quimohuiquilizqueh',
#  'teilpiloyan',
#  'zatepan',
#  'calacohuaz',
#  'mochintin',
#  'in',
#  'apóstoles',
#  'ihuan',
#  'no',
#  'nicnequi',
#  'quinhuicazqueh',
#  'omentin',
#  'ichtequeh',
#  'teichtacamictianih',
#  'niman',
#  'ye',
#  'ic',
#  'hualquizah',
#  'in',
#  'tlalhuacapan',
#  'in',
#  'tlalhuacpan',
#  'ca',
#  'mehuiltihticateh',
#  'in',
#  'teopixcatlahtohqueh',
#  'ihuan',
#  'mehuiltihticah',
#  'in',
#  'huei',
#  'tlahtoani',
#  'presidenteh',
#  'ihuan',
#  'ye',
#  'oquinnonotzqueh',
#  'in',
#  'inicnihuan',
#  'in',
#  'quipolotoh',
#  'in',
#  'ihcuac',
#  'quitepotztocaqueh',
#  'tla',
#  'xiccaqui',
#  'noxocoyouh',
#  'motlancuaquetzaz',
#  'ixpan',
#  'cristo',
#  'in',
#  'tehhuantin',
#  'zan',
#  'toconchixticateh',
#  'in',
#  'amoteopixcatlanahuatiltzin',
#  'auh',
#  'niman',
#  'huel',
#  'ihcuac',
#  'in',
#  'o',
#  'tlatlahuizcalli',
#  'ehuac',
#  'in',
#  'o',
#  'tlatlalchipahuac',
#  'in',
#  'tezacoc',
#  'san',
#  'pedro',
#  'ihuan',
#  'san',
#  'juan',
#  'san',
#  'felipe',
#  'quimotemahmaquiliz',
#  'in',
#  'tehhuatl',
#  'ahmo',
#  'ticmimacaxilia',
#  'in',
#  'dios',
#  'ca',
#  'ye',
#  'cualli',
#  'tlahtoanie',
#  'ma',
#  'nicnotza',
#  'in',
#  'telpochtli',
#  'inic',
#  'nican',
#  'hualcalaquiz',
#  'xinechnanquili',
#  'cetl',
#  'ocatca',
#  'nochpochtzin',
#  'itoca',
#  'doña',
#  'ana',
#  'cortés',
#  'xiloyectzin',
#  'zan',
#  'icel',
#  'nopiltzin',
#  'ocatca',
#  'omach',
#  'cohcotztlalhuahqueh',
#  'auh',
#  'in',
#  'ye',
#  'ixquich',
#  'telpotzintli',
#  'in',
#  'cuexpaltzineh',
#  'in',
#  'cuexpaltzitzinehqueh',
#  'ihuan',
#  'in',
#  'tzotzocolehqueh',
#  'in',
#  'tepallamanih',
#  'in',
#  'iyahqueh',
#  'in',
#  'motenehuah',
#  'in',
#  'telpochiyahqueh',
#  'in',
#  'ce',
#  'ic',
#  'nemih',
#  'in',
#  'ce',
#  'cahcitinemih',
#  'in',
#  'ahnozo',
#  'ome',
#  'cahcitinemih',
#  'no',
#  'quintzacuayah',
#  'quimilhuiayah',
#  'auh',
#  'sabado',
#  'catca',
#  'huel',
#  'oc',
#  'yohuatzinco',
#  'quihualtepotztocaya',
#  'in',
#  'teoyotl',
#  'ihuan',
#  'in',
#  'inetititlaniz',
#  'in',
#  'tetennamiquiliztica',
#  'inic',
#  'temac',
#  'tictlazaz',
#  'in',
#  'ichpochtli',
#  'iconetzin',
#  'tlahtoanie',
#  'ca',
#  'ye',
#  'moyollohtzin',
#  'opachiuh',
#  ...]

# %%
reg_pairs = [word[i:i+2] for word in unreg_set for i in range(len(word) - 1)]

# %%
reg_pairs
# Out:
# ['ma',
#  'xi',
#  'in',
#  'ne',
#  'ec',
#  'ch',
#  'hm',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'ap',
#  'po',
#  'op',
#  'po',
#  'ol',
#  'lh',
#  'hu',
#  'ui',
#  'il',
#  'li',
#  'ni',
#  'it',
#  'tl',
#  'la',
#  'at',
#  'tl',
#  'la',
#  'ac',
#  'cu',
#  'ua',
#  'an',
#  'ni',
#  'ip',
#  'po',
#  'ol',
#  'cu',
#  'ui',
#  'ix',
#  'ti',
#  'ip',
#  'pi',
#  'il',
#  'lt',
#  'tz',
#  'zi',
#  'in',
#  'di',
#  'io',
#  'os',
#  'mo',
#  'on',
#  'ne',
#  'et',
#  'tl',
#  'la',
#  'am',
#  'ma',
#  'ac',
#  'ch',
#  'ht',
#  'ti',
#  'il',
#  'mo',
#  'oc',
#  'ch',
#  'hi',
#  'ih',
#  'hu',
#  'ua',
#  'as',
#  'yn',
#  'nn',
#  'ōp',
#  'pa',
#  'yl',
#  'lh',
#  'hu',
#  'ui',
#  'ic',
#  'ca',
#  'ac',
#  'au',
#  'uh',
#  'hh',
#  'hu',
#  'ui',
#  'in',
#  'ax',
#  'xc',
#  'ca',
#  'an',
#  'ma',
#  'oc',
#  'no',
#  'am',
#  'me',
#  'eh',
#  'hu',
#  'ua',
#  'an',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'nt',
#  'ti',
#  'xi',
#  'im',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'an',
#  'nt',
#  'tl',
#  'la',
#  'au',
#  'uh',
#  'ht',
#  'ti',
#  'il',
#  'li',
#  'ic',
#  'ca',
#  'an',
#  'oa',
#  'an',
#  'nq',
#  'qu',
#  'ui',
#  'ii',
#  'iy',
#  'yo',
#  'oh',
#  'hu',
#  'ui',
#  'iq',
#  'qu',
#  'ue',
#  'xo',
#  'ol',
#  'lo',
#  'ot',
#  'to',
#  'ot',
#  'to',
#  'on',
#  'au',
#  'uh',
#  'yn',
#  'ax',
#  'xc',
#  'ca',
#  'ca',
#  'yo',
#  'ni',
#  'ic',
#  'ct',
#  'tl',
#  'la',
#  'al',
#  'lc',
#  'ca',
#  'ah',
#  'hu',
#  'ui',
#  'yc',
#  'qu',
#  'ui',
#  'is',
#  'sa',
#  'az',
#  'yn',
#  'ca',
#  'an',
#  'nd',
#  'de',
#  'el',
#  'll',
#  'la',
#  'as',
#  'ca',
#  'ho',
#  'on',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hn',
#  'no',
#  'ot',
#  'ti',
#  'it',
#  'ti',
#  'il',
#  'li',
#  'no',
#  'ot',
#  'te',
#  'et',
#  'tl',
#  'la',
#  'as',
#  'so',
#  'ot',
#  'tl',
#  'la',
#  'al',
#  'li',
#  'it',
#  'tz',
#  'zi',
#  'in',
#  'yn',
#  'no',
#  'ot',
#  'te',
#  'et',
#  'tl',
#  'la',
#  'ac',
#  'co',
#  'ol',
#  'li',
#  'il',
#  'li',
#  'it',
#  'tz',
#  'zi',
#  'no',
#  'ot',
#  'tl',
#  'la',
#  'as',
#  'so',
#  'om',
#  'ma',
#  'ah',
#  'hu',
#  'ui',
#  'is',
#  'sc',
#  'co',
#  'on',
#  'ne',
#  'et',
#  'tz',
#  'zi',
#  'in',
#  'ca',
#  'yo',
#  'oq',
#  'qu',
#  'ui',
#  'qu',
#  'ui',
#  'im',
#  'mo',
#  'on',
#  'ne',
#  'eq',
#  'qu',
#  'ui',
#  'it',
#  'ti',
#  'ia',
#  'yn',
#  'se',
#  'en',
#  'nc',
#  'ca',
#  'ye',
#  'eh',
#  'hu',
#  'ua',
#  'at',
#  'tz',
#  'zi',
#  'in',
#  'yn',
#  'ti',
#  'ic',
#  'cm',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'ac',
#  'ca',
#  'am',
#  'ma',
#  'ac',
#  'ch',
#  'hi',
#  'il',
#  'lt',
#  'ti',
#  'it',
#  'tz',
#  'zi',
#  'in',
#  'nn',
#  'no',
#  'os',
#  'yn',
#  'mo',
#  'ot',
#  'tl',
#  'la',
#  'as',
#  'so',
#  'ot',
#  'ta',
#  'at',
#  'tz',
#  'zi',
#  'in',
#  'di',
#  'io',
#  'os',
#  'ca',
#  'mo',
#  'op',
#  'pa',
#  'aq',
#  'qu',
#  'ui',
#  'il',
#  'lt',
#  'ti',
#  'it',
#  'ti',
#  'ic',
#  'ca',
#  'in',
#  'mo',
#  'oh',
#  'hu',
#  'ue',
#  'ep',
#  'po',
#  'ol',
#  'lt',
#  'tz',
#  'zi',
#  'in',
#  'ih',
#  'hu',
#  'ua',
#  'an',
#  'in',
#  'mo',
#  'oc',
#  'cn',
#  'no',
#  'ot',
#  'tl',
#  'la',
#  'ac',
#  'ca',
#  'ah',
#  'hu',
#  'ua',
#  'an',
#  'pi',
#  'ip',
#  'pi',
#  'il',
#  'lt',
#  'to',
#  'ot',
#  'to',
#  'on',
#  'nt',
#  'ti',
#  'in',
#  'ca',
#  'pa',
#  'ac',
#  'ct',
#  'ti',
#  'in',
#  'ne',
#  'em',
#  'mi',
#  'ye',
#  'eh',
#  'hu',
#  'uā',
#  'āt',
#  'ti',
#  'qu',
#  'ui',
#  'it',
#  'to',
#  'os',
#  'sq',
#  'qu',
#  'ue',
#  'yn',
#  'tl',
#  'le',
#  'en',
#  'on',
#  'ni',
#  'it',
#  'te',
#  'em',
#  'ma',
#  'ac',
#  'ch',
#  'ht',
#  'ti',
#  'ia',
#  'ay',
#  'ya',
#  'ca',
#  'ne',
#  'el',
#  'li',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hi',
#  'il',
#  'lh',
#  'hu',
#  'ui',
#  'ia',
#  'ca',
#  'in',
#  'tl',
#  'la',
#  'ac',
#  'ca',
#  'at',
#  'te',
#  'ec',
#  'co',
#  'ol',
#  'lo',
#  'ot',
#  'tl',
#  'ca',
#  'oa',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hm',
#  'mi',
#  'in',
#  'nt',
#  'tl',
#  'la',
#  'an',
#  'ni',
#  'in',
#  'ny',
#  'yc',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hs',
#  'se',
#  'es',
#  'se',
#  'em',
#  'ma',
#  'an',
#  'na',
#  'as',
#  'in',
#  'iu',
#  'uh',
#  'hq',
#  'qu',
#  'ui',
#  'tr',
#  'ri',
#  'ig',
#  'go',
#  'mo',
#  'os',
#  'se',
#  'es',
#  'se',
#  'em',
#  'ma',
#  'an',
#  'na',
#  'mo',
#  'oc',
#  'ch',
#  'ha',
#  'ay',
#  'ya',
#  'ah',
#  'hu',
#  'ua',
#  'cu',
#  'ui',
#  'ix',
#  'am',
#  'mo',
#  'sa',
#  'an',
#  'on',
#  'ne',
#  'ep',
#  'po',
#  'ol',
#  'li',
#  'yn',
#  'ca',
#  'an',
#  'np',
#  'pa',
#  'mo',
#  'oc',
#  'ca',
#  'al',
#  'la',
#  'aq',
#  'qu',
#  'ui',
#  'it',
#  'ti',
#  'iu',
#  'uh',
#  'no',
#  'om',
#  'ma',
#  'at',
#  'ti',
#  'ic',
#  'ca',
#  'on',
#  'np',
#  'pa',
#  'an',
#  'nm',
#  'mo',
#  'oc',
#  'ca',
#  'al',
#  'la',
#  'aq',
#  'qu',
#  'ui',
#  'iz',
#  'zq',
#  'qu',
#  'ue',
#  'ye',
#  'es',
#  'se',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hi',
#  'il',
#  'lh',
#  'hu',
#  'ui',
#  'ia',
#  'in',
#  'ip',
#  'pi',
#  'il',
#  'lt',
#  'tz',
#  'zi',
#  'in',
#  'di',
#  'io',
#  'os',
#  'ca',
#  'ye',
#  'ec',
#  'ca',
#  'an',
#  'nc',
#  'co',
#  'op',
#  'pa',
#  'an',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'nc',
#  'co',
#  'me',
#  'eh',
#  'hu',
#  'ui',
#  'il',
#  'lt',
#  'ti',
#  'it',
#  'ti',
#  'ie',
#  'es',
#  'in',
#  'di',
#  'io',
#  'os',
#  'yn',
#  'āh',
#  'hu',
#  'ue',
#  'el',
#  'on',
#  'nm',
#  'mi',
#  'ic',
#  'cu',
#  'ua',
#  'an',
#  'ni',
#  'is',
#  'yn',
#  'cm',
#  'mc',
#  'au',
#  'uh',
#  'ye',
#  'in',
#  'iq',
#  'qu',
#  'ua',
#  'ac',
#  'yu',
#  'uh',
#  'ni',
#  'in',
#  'no',
#  'ot',
#  'tt',
#  'ta',
#  'ac',
#  'in',
#  'hu',
#  'ue',
#  'el',
#  'on',
#  'ni',
#  'in',
#  'no',
#  'oo',
#  'oh',
#  'hu',
#  'ui',
#  'ic',
#  'ca',
#  'an',
#  'na',
#  'aq',
#  'qu',
#  'ui',
#  'in',
#  'ao',
#  'oc',
#  'cc',
#  'cã',
#  'hu',
#  'ue',
#  'el',
#  'ni',
#  'im',
#  'ma',
#  'aq',
#  'qu',
#  'ui',
#  'iç',
#  'ça',
#  'az',
#  'ca',
#  'ye',
#  'ep',
#  'pp',
#  'pa',
#  'ni',
#  'im',
#  'mi',
#  'iq',
#  'qu',
#  'ui',
#  'iz',
#  'ni',
#  'ip',
#  'po',
#  'op',
#  'po',
#  'ol',
#  'li',
#  'ih',
#  'hu',
#  'ui',
#  'iz',
#  'in',
#  'ni',
#  'im',
#  'ma',
#  'an',
#  'ao',
#  'oc',
#  'ct',
#  'tl',
#  'le',
#  'on',
#  'nc',
#  'ca',
#  'at',
#  'tc',
#  'ca',
#  'no',
#  'op',
#  'pa',
#  'al',
#  'le',
#  'eh',
#  'hu',
#  'ui',
#  'il',
#  'lo',
#  'oc',
#  'ca',
#  'çã',
#  'ni',
#  'im',
#  'mã',
#  'iq',
#  'qu',
#  'ua',
#  'ac',
#  'çe',
#  'en',
#  'nm',
#  'mo',
#  'oc',
#  'ch',
#  'ic',
#  'ca',
#  'in',
#  'no',
#  'oy',
#  'yo',
#  'ol',
#  'll',
#  'lo',
#  'ni',
#  'ic',
#  'cn',
#  'no',
#  'ot',
#  'tz',
#  'za',
#  'tz',
#  'zi',
#  'il',
#  'li',
#  'il',
#  'li',
#  'iz',
#  'zç',
#  'çe',
#  'en',
#  'nq',
#  'qu',
#  'ui',
#  'iz',
#  'zc',
#  'ca',
#  'ai',
#  'ic',
#  'ch',
#  'hp',
#  'po',
#  'oc',
#  'ch',
#  'ht',
#  'tz',
#  'zi',
#  'in',
#  'nt',
#  'tl',
#  'li',
#  'il',
#  'lh',
#  'hu',
#  'ui',
#  'ic',
#  'ca',
#  'ac',
#  'çi',
#  'ih',
#  'hu',
#  'ua',
#  'ap',
#  'pi',
#  'il',
#  'll',
#  'li',
#  'to',
#  'ot',
#  'tl',
#  'la',
#  'aç',
#  'ço',
#  'on',
#  'na',
#  'an',
#  'nt',
#  'tz',
#  'zi',
#  'in',
#  'gu',
#  'ua',
#  'ad',
#  'da',
#  'al',
#  'lu',
#  'up',
#  'pe',
#  'in',
#  'ni',
#  'ic',
#  'ma',
#  'ne',
#  'ec',
#  'ch',
#  'hm',
#  'mo',
#  'oc',
#  'cn',
#  'no',
#  'oi',
#  'it',
#  'tt',
#  'ti',
#  'il',
#  'li',
#  'ma',
#  'ne',
#  'ec',
#  'ch',
#  'hm',
#  'mo',
#  'op',
#  'pa',
#  'al',
#  'le',
#  'eh',
#  'hu',
#  'ui',
#  'il',
#  'li',
#  'cr',
#  'ru',
#  'uz',
#  'zt',
#  'ti',
#  'it',
#  'te',
#  'ec',
#  'ch',
#  'qu',
#  'ui',
#  'im',
#  'ma',
#  'am',
#  'ma',
#  'as',
#  'so',
#  'oh',
#  'hu',
#  'ua',
#  'al',
#  'lt',
#  'ti',
#  'is',
#  'sq',
#  'qu',
#  'ue',
#  'au',
#  'uh',
#  'yn',
#  'ax',
#  'xc',
#  'ca',
#  'an',
#  'op',
#  'pa',
#  'na',
#  'am',
#  'me',
#  'ec',
#  'ch',
#  'hn',
#  'no',
#  'oh',
#  'hu',
#  'ui',
#  'iq',
#  'qu',
#  'ui',
#  'il',
#  'li',
#  'it',
#  'ti',
#  'iu',
#  'uh',
#  'yn',
#  'nt',
#  'tl',
#  'la',
#  'sa',
#  'an',
#  'mo',
#  'on',
#  'na',
#  'am',
#  'ma',
#  'ac',
#  'ca',
#  'an',
#  'ni',
#  'ām',
#  'mo',
#  'sa',
#  'an',
#  'ca',
#  'ax',
#  'xt',
#  'to',
#  'ol',
#  'lp',
#  'po',
#  'oh',
#  'hu',
#  'ua',
#  'al',
#  'li',
#  'pe',
#  'es',
#  'so',
#  'os',
#  'yp',
#  'pa',
#  'at',
#  'ti',
#  'iu',
#  'uh',
#  'oy',
#  'ye',
#  'es',
#  'sq',
#  'qu',
#  'ui',
#  'ia',
#  'au',
#  'uh',
#  'ca',
#  'am',
#  'mo',
#  'ye',
#  'eh',
#  'hu',
#  'ua',
#  'at',
#  'tl',
#  'mo',
#  'oc',
#  'ch',
#  'hi',
#  'ih',
#  'hu',
#  'ua',
#  'as',
#  'in',
#  'tl',
#  'le',
#  'en',
#  'ni',
#  'ic',
#  'cn',
#  'ne',
#  ...]

# %% [markdown]
# #### The 100 Most Common Pairs

# %%
reg_counts = Counter(reg_pairs)

# %%
reg_counts.most_common(100)
# Out:
# [('ui', 18441),
#  ('in', 17925),
#  ('qu', 17743),
#  ('tl', 17693),
#  ('ca', 17569),
#  ('hu', 14904),
#  ('an', 14623),
#  ('la', 13657),
#  ('ti', 13096),
#  ('ic', 12541),
#  ('mo', 10109),
#  ('li', 9962),
#  ('at', 9514),
#  ('ua', 9432),
#  ('yn', 9011),
#  ('ni', 8901),
#  ('il', 8729),
#  ('ma', 8683),
#  ('it', 8681),
#  ('ch', 8563),
#  ('ac', 8492),
#  ('tz', 8289),
#  ('ot', 7840),
#  ('te', 7705),
#  ('ue', 7466),
#  ('al', 6943),
#  ('oc', 6900),
#  ('to', 5980),
#  ('pa', 5898),
#  ('zi', 5814),
#  ('no', 5518),
#  ('uh', 5469),
#  ('ne', 5445),
#  ('on', 5193),
#  ('im', 4730),
#  ('co', 4567),
#  ('nt', 4484),
#  ('am', 4322),
#  ('ec', 4285),
#  ('ia', 4058),
#  ('is', 3861),
#  ('hi', 3817),
#  ('mi', 3791),
#  ('lt', 3701),
#  ('as', 3499),
#  ('el', 3480),
#  ('ol', 3437),
#  ('en', 3346),
#  ('au', 3336),
#  ('ah', 2922),
#  ('na', 2920),
#  ('iq', 2846),
#  ('ih', 2830),
#  ('nc', 2804),
#  ('xi', 2770),
#  ('cu', 2763),
#  ('ye', 2691),
#  ('ix', 2574),
#  ('om', 2519),
#  ('eh', 2453),
#  ('lo', 2304),
#  ('et', 2238),
#  ('ht', 2201),
#  ('oh', 2200),
#  ('aq', 2163),
#  ('po', 2136),
#  ('yo', 2133),
#  ('le', 2109),
#  ('pi', 2052),
#  ('oa', 1990),
#  ('os', 1963),
#  ('oq', 1916),
#  ('op', 1896),
#  ('iz', 1813),
#  ('iu', 1779),
#  ('me', 1761),
#  ('lh', 1704),
#  ('em', 1680),
#  ('ep', 1608),
#  ('eq', 1583),
#  ('se', 1551),
#  ('sa', 1524),
#  ('ap', 1516),
#  ('es', 1509),
#  ('io', 1508),
#  ('sq', 1467),
#  ('ct', 1444),
#  ('ll', 1435),
#  ('ta', 1328),
#  ('ie', 1328),
#  ('so', 1325),
#  ('ya', 1322),
#  ('ip', 1291),
#  ('ce', 1209),
#  ('ay', 1191),
#  ('cm', 1067),
#  ('st', 1056),
#  ('ey', 1052),
#  ('pe', 1023),
#  ('xc', 976)]

# %% [markdown]
# ### Training the Tokenizers

# %%
import translator.tokenization as tok

# %%
tok.create_vocab_path()

tok.prepare_vocab((unreg_non_test), "unregularized_to_tokenize")
tok.prepare_vocab((reg_non_test), "regularized_to_tokenize")

# %%
unreg_vocab_size = tok.get_tokenizer("unregularized_to_tokenize", "unregularized_bpe_tokenizer")
reg_vocab_size = tok.get_tokenizer("regularized_to_tokenize", "regularized_bpe_tokenizer")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
print("Unregularized tokenizer vocab size: " + str(unreg_vocab_size))
print("Regularized tokenizer vocab size: " + str(reg_vocab_size))
# Out:
# Unregularized tokenizer vocab size: 271
# Regularized tokenizer vocab size: 271

# %% [markdown]
# #### Testing the Tokenizers

# %%
unreg_tokenizer = tok.load_tokenizer("unregularized_bpe_tokenizer")
reg_tokenizer = tok.load_tokenizer("regularized_bpe_tokenizer")

# %%
example_unreg = unreg_tokenizer("nica timispopolosq.")["input_ids"]

print(example_unreg)
# Out:
# [224, 81, 76, 262, 224, 267, 80, 76, 86, 83, 82, 83, 82, 79, 82, 86, 84, 17]

# %%
example_unreg = unreg_tokenizer.decode(example_unreg)

print(example_unreg)
# Out:
#  nica timispopolosq.

# %%
example_reg = reg_tokenizer("nican timitzpohpolozqueh.")["input_ids"]

print(example_reg)
# Out:
# [224, 81, 76, 263, 81, 224, 267, 80, 76, 87, 93, 83, 82, 75, 83, 82, 79, 82, 93, 84, 88, 72, 75, 17]

# %%
example_reg = reg_tokenizer.decode(example_reg)

print(example_reg)
# Out:
#  nican timitzpohpolozqueh.

# %% [markdown]
# ## Backtranslation

# %%
import training as train
import translator as tran

# %%
train.train_transformer(reg_vocab_size, unreg_vocab_size,
                        "Backtranslation_Train", "Backtranslation_Val",
                        reg_tokenizer, unreg_tokenizer,
                        100, "backtranslator")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5193: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 1, Train loss: 2.355, Val loss: 1.687, Epoch time = 48.975s
# Epoch: 2, Train loss: 1.606, Val loss: 0.981, Epoch time = 47.047s
# Epoch: 3, Train loss: 1.173, Val loss: 0.752, Epoch time = 46.493s
# Epoch: 4, Train loss: 0.959, Val loss: 0.633, Epoch time = 45.720s
# Epoch: 5, Train loss: 0.833, Val loss: 0.575, Epoch time = 46.154s
# Epoch: 6, Train loss: 0.747, Val loss: 0.525, Epoch time = 46.061s
# Epoch: 7, Train loss: 0.678, Val loss: 0.473, Epoch time = 46.201s
# Epoch: 8, Train loss: 0.624, Val loss: 0.459, Epoch time = 47.081s
# Epoch: 9, Train loss: 0.578, Val loss: 0.443, Epoch time = 46.100s
# Epoch: 10, Train loss: 0.539, Val loss: 0.410, Epoch time = 45.926s
# Epoch: 11, Train loss: 0.501, Val loss: 0.375, Epoch time = 45.832s
# Epoch: 12, Train loss: 0.467, Val loss: 0.351, Epoch time = 46.162s
# Epoch: 13, Train loss: 0.439, Val loss: 0.347, Epoch time = 46.511s
# Epoch: 14, Train loss: 0.415, Val loss: 0.319, Epoch time = 46.890s
# Epoch: 15, Train loss: 0.391, Val loss: 0.315, Epoch time = 46.528s
# Epoch: 16, Train loss: 0.371, Val loss: 0.297, Epoch time = 46.100s
# Epoch: 17, Train loss: 0.351, Val loss: 0.294, Epoch time = 46.198s
# Epoch: 18, Train loss: 0.334, Val loss: 0.280, Epoch time = 47.262s
# Epoch: 19, Train loss: 0.320, Val loss: 0.274, Epoch time = 46.130s
# Epoch: 20, Train loss: 0.307, Val loss: 0.266, Epoch time = 46.259s
# Epoch: 21, Train loss: 0.297, Val loss: 0.258, Epoch time = 45.791s
# Epoch: 22, Train loss: 0.288, Val loss: 0.256, Epoch time = 46.279s
# Epoch: 23, Train loss: 0.278, Val loss: 0.248, Epoch time = 46.964s
# Epoch: 24, Train loss: 0.272, Val loss: 0.248, Epoch time = 46.015s
# Epoch: 25, Train loss: 0.265, Val loss: 0.244, Epoch time = 45.740s
# Epoch: 26, Train loss: 0.258, Val loss: 0.240, Epoch time = 45.959s
# Epoch: 27, Train loss: 0.253, Val loss: 0.236, Epoch time = 47.500s
# Epoch: 28, Train loss: 0.248, Val loss: 0.235, Epoch time = 46.102s
# Epoch: 29, Train loss: 0.244, Val loss: 0.234, Epoch time = 46.503s
# Epoch: 30, Train loss: 0.240, Val loss: 0.231, Epoch time = 46.164s
# Epoch: 31, Train loss: 0.236, Val loss: 0.229, Epoch time = 45.986s
# Epoch: 32, Train loss: 0.231, Val loss: 0.230, Epoch time = 46.061s
# Epoch: 33, Train loss: 0.229, Val loss: 0.227, Epoch time = 46.068s
# Epoch: 34, Train loss: 0.225, Val loss: 0.227, Epoch time = 46.286s
# Epoch: 35, Train loss: 0.221, Val loss: 0.224, Epoch time = 47.222s
# Epoch: 36, Train loss: 0.219, Val loss: 0.224, Epoch time = 46.079s
# Epoch: 37, Train loss: 0.215, Val loss: 0.223, Epoch time = 46.057s
# Epoch: 38, Train loss: 0.213, Val loss: 0.223, Epoch time = 46.369s
# Epoch: 39, Train loss: 0.211, Val loss: 0.224, Epoch time = 46.412s
# Epoch: 40, Train loss: 0.209, Val loss: 0.221, Epoch time = 46.234s
# Epoch: 41, Train loss: 0.206, Val loss: 0.220, Epoch time = 46.228s
# Epoch: 42, Train loss: 0.203, Val loss: 0.218, Epoch time = 47.246s
# Epoch: 43, Train loss: 0.201, Val loss: 0.218, Epoch time = 46.550s
# Epoch: 44, Train loss: 0.199, Val loss: 0.218, Epoch time = 46.156s
# Epoch: 45, Train loss: 0.197, Val loss: 0.216, Epoch time = 46.214s
# Epoch: 46, Train loss: 0.197, Val loss: 0.217, Epoch time = 47.103s
# Epoch: 47, Train loss: 0.193, Val loss: 0.216, Epoch time = 46.517s
# Epoch: 48, Train loss: 0.192, Val loss: 0.218, Epoch time = 46.117s
# Epoch: 49, Train loss: 0.189, Val loss: 0.218, Epoch time = 45.947s
# Epoch: 50, Train loss: 0.187, Val loss: 0.216, Epoch time = 47.442s
# Epoch: 51, Train loss: 0.186, Val loss: 0.215, Epoch time = 45.736s
# Epoch: 52, Train loss: 0.185, Val loss: 0.217, Epoch time = 46.075s
# Epoch: 53, Train loss: 0.182, Val loss: 0.215, Epoch time = 46.055s
# Epoch: 54, Train loss: 0.181, Val loss: 0.214, Epoch time = 45.819s
# Epoch: 55, Train loss: 0.180, Val loss: 0.215, Epoch time = 46.013s
# Epoch: 56, Train loss: 0.177, Val loss: 0.216, Epoch time = 46.058s
# Epoch: 57, Train loss: 0.178, Val loss: 0.216, Epoch time = 46.504s
# Epoch: 58, Train loss: 0.175, Val loss: 0.216, Epoch time = 47.852s
# Epoch: 59, Train loss: 0.174, Val loss: 0.216, Epoch time = 46.600s
# Epoch: 60, Train loss: 0.172, Val loss: 0.216, Epoch time = 46.114s
# Epoch: 61, Train loss: 0.172, Val loss: 0.216, Epoch time = 46.613s
# Epoch: 62, Train loss: 0.170, Val loss: 0.217, Epoch time = 47.173s
# Epoch: 63, Train loss: 0.168, Val loss: 0.216, Epoch time = 46.286s
# Epoch: 64, Train loss: 0.167, Val loss: 0.217, Epoch time = 46.187s
# Epoch: 65, Train loss: 0.166, Val loss: 0.216, Epoch time = 46.267s
# Epoch: 66, Train loss: 0.165, Val loss: 0.217, Epoch time = 46.126s
# Epoch: 67, Train loss: 0.163, Val loss: 0.217, Epoch time = 46.436s
# Epoch: 68, Train loss: 0.162, Val loss: 0.218, Epoch time = 47.020s
# Epoch: 69, Train loss: 0.161, Val loss: 0.217, Epoch time = 46.066s
# Epoch: 70, Train loss: 0.159, Val loss: 0.221, Epoch time = 46.507s
# Epoch: 71, Train loss: 0.159, Val loss: 0.218, Epoch time = 46.212s
# Epoch: 72, Train loss: 0.158, Val loss: 0.220, Epoch time = 45.764s
# Epoch: 73, Train loss: 0.156, Val loss: 0.220, Epoch time = 45.621s
# Epoch: 74, Train loss: 0.156, Val loss: 0.219, Epoch time = 46.320s
# Epoch: 75, Train loss: 0.155, Val loss: 0.222, Epoch time = 47.282s
# Epoch: 76, Train loss: 0.153, Val loss: 0.221, Epoch time = 46.152s
# Epoch: 77, Train loss: 0.153, Val loss: 0.219, Epoch time = 45.963s
# Epoch: 78, Train loss: 0.151, Val loss: 0.220, Epoch time = 46.200s
# Epoch: 79, Train loss: 0.151, Val loss: 0.223, Epoch time = 46.142s
# Epoch: 80, Train loss: 0.149, Val loss: 0.222, Epoch time = 46.301s
# Epoch: 81, Train loss: 0.148, Val loss: 0.221, Epoch time = 46.526s
# Epoch: 82, Train loss: 0.147, Val loss: 0.224, Epoch time = 47.127s
# Epoch: 83, Train loss: 0.146, Val loss: 0.223, Epoch time = 46.117s
# Epoch: 84, Train loss: 0.146, Val loss: 0.225, Epoch time = 47.494s
# Epoch: 85, Train loss: 0.144, Val loss: 0.226, Epoch time = 46.318s
# Epoch: 86, Train loss: 0.144, Val loss: 0.226, Epoch time = 45.924s
# Epoch: 87, Train loss: 0.143, Val loss: 0.227, Epoch time = 46.053s
# Epoch: 88, Train loss: 0.143, Val loss: 0.224, Epoch time = 47.067s
# Epoch: 89, Train loss: 0.141, Val loss: 0.225, Epoch time = 46.261s
# Epoch: 90, Train loss: 0.140, Val loss: 0.227, Epoch time = 45.797s
# Epoch: 91, Train loss: 0.140, Val loss: 0.226, Epoch time = 46.462s
# Epoch: 92, Train loss: 0.139, Val loss: 0.227, Epoch time = 46.216s
# Epoch: 93, Train loss: 0.138, Val loss: 0.226, Epoch time = 46.037s
# Epoch: 94, Train loss: 0.136, Val loss: 0.230, Epoch time = 45.984s
# Epoch: 95, Train loss: 0.137, Val loss: 0.230, Epoch time = 46.017s
# Epoch: 96, Train loss: 0.136, Val loss: 0.228, Epoch time = 46.537s
# Epoch: 97, Train loss: 0.135, Val loss: 0.228, Epoch time = 47.239s
# Epoch: 98, Train loss: 0.134, Val loss: 0.228, Epoch time = 45.968s
# Epoch: 99, Train loss: 0.133, Val loss: 0.230, Epoch time = 45.760s
# Epoch: 100, Train loss: 0.132, Val loss: 0.232, Epoch time = 45.805s

# %%
backtranslator = tran.load_trained_transformer(reg_vocab_size, unreg_vocab_size, "backtranslator")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /content/training.py:206: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   transformer.load_state_dict(torch.load(SAVED_MODEL_PATH + file_name + ".pt",

# %%
back_translations, full_set = tran.back_translate(backtranslator, "To Backtranslate",
                                                  reg_tokenizer, unreg_tokenizer)

# %%
back_translations
# Out:
#                                           Unregularized  \
# 0     iehica in tlaxcallan amo tlaçotli catca in qua...
# 1                                             yn sentli
# 2                                                chilli
# 3                                                   etl
# 4                         yhuan ocsequi tetech monequi.
# ...                                                 ...
# 4729                                        queni motas
# 4730             yeica in miec ipatiuh tlapoaltepoztli.
# 4731                        tonesetlalilis yn timochtin
# 4732                  yn timexica yhuan yn timichhuaque
# 4733  ynic tictomaca yn totlatequipanolis xpanoyotic...
#
#                                             Regularized
# 0     yehica in tlaxcallan ahmo tlazohtli catca in q...
# 1                                             in centli
# 2                                                chilli
# 3                                                   etl
# 4                        ihuan oc cequi tetech monequi.
# ...                                                 ...
# 4729                                      quenin mottaz
# 4730         yehica in miyec ipatiuh tlapohualtepoztli.
# 4731                       tonecentlaliliz in timochtin
# 4732              in timexihcah ihuan in timichhuahqueh
# 4733  inic tictomacah in totlatequipanoliz cristiano...
#
# [4734 rows x 2 columns]

# %%
full_set.tail(4734)
# Out:
#                                           Unregularized  \
# 0     iehica in tlaxcallan amo tlaçotli catca in qua...
# 1                                             yn sentli
# 2                                                chilli
# 3                                                   etl
# 4                         yhuan ocsequi tetech monequi.
# ...                                                 ...
# 4729                                        queni motas
# 4730             yeica in miec ipatiuh tlapoaltepoztli.
# 4731                        tonesetlalilis yn timochtin
# 4732                  yn timexica yhuan yn timichhuaque
# 4733  ynic tictomaca yn totlatequipanolis xpanoyotic...
#
#                                             Regularized
# 0     yehica in tlaxcallan ahmo tlazohtli catca in q...
# 1                                             in centli
# 2                                                chilli
# 3                                                   etl
# 4                        ihuan oc cequi tetech monequi.
# ...                                                 ...
# 4729                                      quenin mottaz
# 4730         yehica in miyec ipatiuh tlapohualtepoztli.
# 4731                       tonecentlaliliz in timochtin
# 4732              in timexihcah ihuan in timichhuahqueh
# 4733  inic tictomacah in totlatequipanoliz cristiano...
#
# [4734 rows x 2 columns]

# %% [markdown]
# ## Normalization Training

# %%
train.train_transformer(unreg_vocab_size, reg_vocab_size,
                        "Combined Training", "Val",
                        unreg_tokenizer, reg_tokenizer,
                        100, "normalizer")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py:5193: UserWarning: Support for mismatched key_padding_mask and attn_mask is deprecated. Use same type for both instead.
#   warnings.warn(
# Epoch: 1, Train loss: 2.237, Val loss: 1.545, Epoch time = 55.281s
# Epoch: 2, Train loss: 1.437, Val loss: 0.873, Epoch time = 52.898s
# Epoch: 3, Train loss: 1.014, Val loss: 0.683, Epoch time = 53.036s
# Epoch: 4, Train loss: 0.816, Val loss: 0.574, Epoch time = 53.285s
# Epoch: 5, Train loss: 0.699, Val loss: 0.505, Epoch time = 53.902s
# Epoch: 6, Train loss: 0.614, Val loss: 0.504, Epoch time = 53.289s
# Epoch: 7, Train loss: 0.547, Val loss: 0.408, Epoch time = 53.278s
# Epoch: 8, Train loss: 0.492, Val loss: 0.347, Epoch time = 53.719s
# Epoch: 9, Train loss: 0.445, Val loss: 0.310, Epoch time = 53.190s
# Epoch: 10, Train loss: 0.401, Val loss: 0.282, Epoch time = 53.790s
# Epoch: 11, Train loss: 0.362, Val loss: 0.261, Epoch time = 53.200s
# Epoch: 12, Train loss: 0.324, Val loss: 0.248, Epoch time = 53.660s
# Epoch: 13, Train loss: 0.295, Val loss: 0.235, Epoch time = 53.399s
# Epoch: 14, Train loss: 0.269, Val loss: 0.225, Epoch time = 53.628s
# Epoch: 15, Train loss: 0.249, Val loss: 0.212, Epoch time = 53.264s
# Epoch: 16, Train loss: 0.229, Val loss: 0.200, Epoch time = 53.127s
# Epoch: 17, Train loss: 0.215, Val loss: 0.194, Epoch time = 53.122s
# Epoch: 18, Train loss: 0.203, Val loss: 0.187, Epoch time = 53.075s
# Epoch: 19, Train loss: 0.191, Val loss: 0.181, Epoch time = 52.938s
# Epoch: 20, Train loss: 0.182, Val loss: 0.177, Epoch time = 52.791s
# Epoch: 21, Train loss: 0.174, Val loss: 0.169, Epoch time = 53.178s
# Epoch: 22, Train loss: 0.166, Val loss: 0.169, Epoch time = 53.038s
# Epoch: 23, Train loss: 0.158, Val loss: 0.163, Epoch time = 53.512s
# Epoch: 24, Train loss: 0.153, Val loss: 0.161, Epoch time = 53.398s
# Epoch: 25, Train loss: 0.147, Val loss: 0.157, Epoch time = 53.397s
# Epoch: 26, Train loss: 0.143, Val loss: 0.158, Epoch time = 53.615s
# Epoch: 27, Train loss: 0.138, Val loss: 0.152, Epoch time = 53.594s
# Epoch: 28, Train loss: 0.133, Val loss: 0.152, Epoch time = 53.278s
# Epoch: 29, Train loss: 0.130, Val loss: 0.148, Epoch time = 53.529s
# Epoch: 30, Train loss: 0.126, Val loss: 0.146, Epoch time = 53.414s
# Epoch: 31, Train loss: 0.123, Val loss: 0.144, Epoch time = 53.252s
# Epoch: 32, Train loss: 0.119, Val loss: 0.144, Epoch time = 53.153s
# Epoch: 33, Train loss: 0.115, Val loss: 0.140, Epoch time = 53.296s
# Epoch: 34, Train loss: 0.113, Val loss: 0.142, Epoch time = 53.040s
# Epoch: 35, Train loss: 0.111, Val loss: 0.142, Epoch time = 53.025s
# Epoch: 36, Train loss: 0.108, Val loss: 0.137, Epoch time = 53.586s
# Epoch: 37, Train loss: 0.105, Val loss: 0.137, Epoch time = 53.600s
# Epoch: 38, Train loss: 0.104, Val loss: 0.136, Epoch time = 53.142s
# Epoch: 39, Train loss: 0.102, Val loss: 0.137, Epoch time = 53.503s
# Epoch: 40, Train loss: 0.098, Val loss: 0.137, Epoch time = 53.634s
# Epoch: 41, Train loss: 0.097, Val loss: 0.136, Epoch time = 53.764s
# Epoch: 42, Train loss: 0.096, Val loss: 0.135, Epoch time = 53.598s
# Epoch: 43, Train loss: 0.093, Val loss: 0.133, Epoch time = 53.541s
# Epoch: 44, Train loss: 0.092, Val loss: 0.134, Epoch time = 53.499s
# Epoch: 45, Train loss: 0.090, Val loss: 0.135, Epoch time = 53.794s
# Epoch: 46, Train loss: 0.087, Val loss: 0.135, Epoch time = 53.714s
# Epoch: 47, Train loss: 0.087, Val loss: 0.133, Epoch time = 53.287s
# Epoch: 48, Train loss: 0.085, Val loss: 0.135, Epoch time = 53.493s
# Epoch: 49, Train loss: 0.083, Val loss: 0.134, Epoch time = 53.772s
# Epoch: 50, Train loss: 0.083, Val loss: 0.132, Epoch time = 54.257s
# Epoch: 51, Train loss: 0.081, Val loss: 0.130, Epoch time = 54.323s
# Epoch: 52, Train loss: 0.080, Val loss: 0.131, Epoch time = 53.085s
# Epoch: 53, Train loss: 0.078, Val loss: 0.133, Epoch time = 53.552s
# Epoch: 54, Train loss: 0.076, Val loss: 0.133, Epoch time = 53.534s
# Epoch: 55, Train loss: 0.075, Val loss: 0.131, Epoch time = 54.034s
# Epoch: 56, Train loss: 0.075, Val loss: 0.132, Epoch time = 53.543s
# Epoch: 57, Train loss: 0.074, Val loss: 0.130, Epoch time = 53.233s
# Epoch: 58, Train loss: 0.072, Val loss: 0.132, Epoch time = 53.503s
# Epoch: 59, Train loss: 0.070, Val loss: 0.132, Epoch time = 53.661s
# Epoch: 60, Train loss: 0.071, Val loss: 0.131, Epoch time = 53.650s
# Epoch: 61, Train loss: 0.070, Val loss: 0.130, Epoch time = 53.345s
# Epoch: 62, Train loss: 0.069, Val loss: 0.133, Epoch time = 53.695s
# Epoch: 63, Train loss: 0.067, Val loss: 0.131, Epoch time = 53.010s
# Epoch: 64, Train loss: 0.066, Val loss: 0.129, Epoch time = 53.130s
# Epoch: 65, Train loss: 0.066, Val loss: 0.133, Epoch time = 53.380s
# Epoch: 66, Train loss: 0.065, Val loss: 0.132, Epoch time = 53.335s
# Epoch: 67, Train loss: 0.064, Val loss: 0.131, Epoch time = 53.523s
# Epoch: 68, Train loss: 0.063, Val loss: 0.132, Epoch time = 53.134s
# Epoch: 69, Train loss: 0.062, Val loss: 0.133, Epoch time = 53.355s
# Epoch: 70, Train loss: 0.061, Val loss: 0.131, Epoch time = 53.452s
# Epoch: 71, Train loss: 0.061, Val loss: 0.130, Epoch time = 53.216s
# Epoch: 72, Train loss: 0.060, Val loss: 0.133, Epoch time = 53.287s
# Epoch: 73, Train loss: 0.059, Val loss: 0.135, Epoch time = 53.104s
# Epoch: 74, Train loss: 0.058, Val loss: 0.130, Epoch time = 53.309s
# Epoch: 75, Train loss: 0.058, Val loss: 0.137, Epoch time = 53.031s
# Epoch: 76, Train loss: 0.057, Val loss: 0.133, Epoch time = 53.678s
# Epoch: 77, Train loss: 0.056, Val loss: 0.133, Epoch time = 53.475s
# Epoch: 78, Train loss: 0.055, Val loss: 0.133, Epoch time = 53.255s
# Epoch: 79, Train loss: 0.055, Val loss: 0.133, Epoch time = 53.151s
# Epoch: 80, Train loss: 0.055, Val loss: 0.133, Epoch time = 53.130s
# Epoch: 81, Train loss: 0.053, Val loss: 0.135, Epoch time = 53.415s
# Epoch: 82, Train loss: 0.054, Val loss: 0.133, Epoch time = 53.193s
# Epoch: 83, Train loss: 0.052, Val loss: 0.133, Epoch time = 53.396s
# Epoch: 84, Train loss: 0.052, Val loss: 0.135, Epoch time = 53.610s
# Epoch: 85, Train loss: 0.051, Val loss: 0.133, Epoch time = 53.883s
# Epoch: 86, Train loss: 0.051, Val loss: 0.133, Epoch time = 53.440s
# Epoch: 87, Train loss: 0.051, Val loss: 0.133, Epoch time = 53.158s
# Epoch: 88, Train loss: 0.050, Val loss: 0.133, Epoch time = 53.339s
# Epoch: 89, Train loss: 0.048, Val loss: 0.135, Epoch time = 53.304s
# Epoch: 90, Train loss: 0.049, Val loss: 0.135, Epoch time = 53.482s
# Epoch: 91, Train loss: 0.048, Val loss: 0.134, Epoch time = 53.571s
# Epoch: 92, Train loss: 0.048, Val loss: 0.137, Epoch time = 53.572s
# Epoch: 93, Train loss: 0.048, Val loss: 0.135, Epoch time = 53.530s
# Epoch: 94, Train loss: 0.047, Val loss: 0.138, Epoch time = 53.594s
# Epoch: 95, Train loss: 0.046, Val loss: 0.138, Epoch time = 53.525s
# Epoch: 96, Train loss: 0.046, Val loss: 0.140, Epoch time = 53.277s
# Epoch: 97, Train loss: 0.045, Val loss: 0.137, Epoch time = 53.139s
# Epoch: 98, Train loss: 0.045, Val loss: 0.141, Epoch time = 53.896s
# Epoch: 99, Train loss: 0.045, Val loss: 0.136, Epoch time = 53.536s
# Epoch: 100, Train loss: 0.044, Val loss: 0.135, Epoch time = 53.621s

# %%
normalizer = tran.load_trained_transformer(unreg_vocab_size, reg_vocab_size, "normalizer")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /content/training.py:208: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   transformer.load_state_dict(torch.load(SAVED_MODEL_PATH + file_name + ".pt",

# %% [markdown]
# ## Testing the Normalizer

# %%
tran.translate_test(normalizer, "Test", unreg_tokenizer, reg_tokenizer)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Input: xicmotlatzontequililican ynic polihuis yn iteystlacahuilis!
# Predicted: xicmotlatzontequililican inic polihuiz in iteiztlacahuiliz!
# Expected: xicmotlatzontequililican inic polihuiz in iteiztlacahuiliz!
# Character Error Rate: 0.0
#
#
# Input: inic navi vevetecatl.
# Predicted: inic nahui huehuehtecatl.
# Expected: inic nahui huehuetecatl.
# Character Error Rate: 0.0416666679084301
#
#
# Input: onexmotlasotili
# Predicted: onechmotlazohtilih
# Expected: onechmotlazohtilih
# Character Error Rate: 0.0
#
#
# Input: onechmouapahuili
# Predicted: onechmohuapahuilih
# Expected: onechmohuapahuilih
# Character Error Rate: 0.0
#
#
# Input: onechmonextillili ynn itetlasotlalitzin.
# Predicted: onechmonextililih in itetlazohtlaliztzin.
# Expected: onechmonextilih in itetlazohtlaliztzin.
# Character Error Rate: 0.05128205195069313
#
#
# Input: ca ye huecauh nechixticate.
# Predicted: ca ye huehcauh nechixticateh.
# Expected: ca ye huehcauh nechchixticateh.
# Character Error Rate: 0.06451612710952759
#
#
# Input: ca ie ixquich cavitl in cenca tiquittaznequi
# Predicted: ca ye ixquich cahuitl in cencah tiquittaznequih
# Expected: ca ye ixquich cahuitl in cencah tiquittaznequih
# Character Error Rate: 0.0
#
#
# Input: in ixco titlachiaznequi.
# Predicted: in ixco titlachiyaznequih.
# Expected: in ixco titlachiyaznequih.
# Character Error Rate: 0.0
#
#
# Input: hualmotemohuis xpo.
# Predicted: hualmotemohuiz cristo.
# Expected: hualmotemohuiz cristo.
# Character Error Rate: 0.0
#
#
# Input: auh yn mayeque quitequipanoque y noçihuamotzin yn doña juana.
# Predicted: auh in mayequeh quitequipanohqueh in nocihuamotzin in doña juana.
# Expected: auh in mayequeh quitequipanohqueh in nocihuamontzin in doña juana.
# Character Error Rate: 0.01515151560306549
#
#
# Input: ximoquetza
# Predicted: ximoquetza
# Expected: ximoquetza
# Character Error Rate: 0.0
#
#
# Input: nocnic
# Predicted: nocniuh
# Expected: nocnic
# Character Error Rate: 0.3333333432674408
#
#
# Input: yollomicatolli
# Predicted: yollohmiccatolli
# Expected: yollohmiccatontli
# Character Error Rate: 0.11764705926179886
#
#
# Input: teca mocacayahuani.
# Predicted: teca mocahcayahuani.
# Expected: teca mocahcayahuani.
# Character Error Rate: 0.0
#
#
# Input: ma xihualtemo.
# Predicted: ma xihualtemo.
# Expected: ma xihualtemo.
# Character Error Rate: 0.0
#
#
# Input: yn ca huel nicnopil ahueliloc.
# Predicted: in ca huel nicnopil ahhueliloc.
# Expected: in ca huel nicnopil tlahueliloc.
# Character Error Rate: 0.09375
#
#
# Input: ynca yn clabos ytech sasalolos
# Predicted: inca in clavos itech zazaloloz
# Expected: ica in clavos itech zahzaloloz
# Character Error Rate: 0.06666667014360428
#
#
# Input: yn iuh chihualo yn aquique tlatlacohuanime
# Predicted: in iuh chihualo in aquihqueh tlahtlacoanimeh
# Expected: in iuh chihualo in aquihqueh tlahtlacoanimeh
# Character Error Rate: 0.0
#
#
# Input: yehica ca miyequinti oqūinechico
# Predicted: yehica ca miaquintin oquinechicoh
# Expected: ye ica ca miaquintin oquinnechicoh
# Character Error Rate: 0.05882352963089943
#
#
# Input: oquinsentlali yn mocuiltonohua tlaca yhuā in motolinia tlaca.
# Predicted: oquincentlalih in mocuiltonoah tlacah ihuan in motoliniah tlacah.
# Expected: oquincentlalih in mocuiltonoah tlacah ihuan in motoliniah tlacah.
# Character Error Rate: 0.0
#
#
# Input: oanquimocnelilique
# Predicted: oanquimocnelilihqueh
# Expected: oanquimocnelilihqueh
# Character Error Rate: 0.0
#
#
# Input: auh oanquimicnelique in iz monoltitoque in tenanhuan in tetahuan in oquinmocaquilili in tlacatl in totecuiyo in inchoquiz in intlaocol
# Predicted: auh oanquimicnelihqueh in iz monoltihtohqueh in tenanhuan in tetahhuan in oquimmocaquililih in tlacatl in totecuiyo in inchoquiz in intlaocol
# Expected: auh oanquimicnelihqueh in iz monoltihtoqueh in tenanhuan in tetahhuan in oquimmocaquililih in tlacatl in totecuiyo in inchoquiz in intlaocol
# Character Error Rate: 0.0071428571827709675
#
#
# Input: inic axcan quitimaloa quimomacehuia in iteoyotzin inic oquinmocetilili in tonantzin xanta yclexia in intlacazcaltil in intlacahuapahual in iz ca in ichpochtzintli in conetzintli
# Predicted: inic axcan quitimaloa quimomahcehuiah in iteoyotzin inic oquimmocetililih in tonantzin xanta iclexia in intlacazcaltil in intlacahuapahual in iz ca in iz ichpochitzintlitintli
# Expected: inic axcan quitimaloah quimomahcehuiah in iteoyotzin inic oquimmocetililih in tonantzin xanta iclexia in intlacazcaltil in intlacahuapahual in iz cah in ichpochtzintli in conetzintli
# Character Error Rate: 0.08241758495569229
#
#
# Input: auh in icnoquauhtli in icnoocelotl.
# Predicted: auh in icnocuauhtli in icnoocelotl.
# Expected: auh in icnocuauhtli in icnoocelotl.
# Character Error Rate: 0.0
#
#
# Input: ye yc noyolo pachihui yn teocuitlatl yn oannechmomaquilique.
# Predicted: ye ic noyollo pachihui in teocuitlatl in oannechmomaquilihqueh.
# Expected: ye ic noyollo pachihui in teocuitlatl in oannechmomaquilihqueh.
# Character Error Rate: 0.0
#
#
# Input: auh amo quinec;
# Predicted: auh ahmo quinec;
# Expected: auh ahmo quinec;
# Character Error Rate: 0.0
#
#
# Input: calaquisque jodiosme nochitin.
# Predicted: calaquizqueh judíosmeh nochintin.
# Expected: calaquizqueh judíosmeh mochintin.
# Character Error Rate: 0.03030303120613098
#
#
# Input: ma ysiuhca xicmonemililica yn itlatzotequililoca yn tetlapololtiani xpo.
# Predicted: ma ihciuhca xicmonemililican in itlatzontequililoca in tetlapololtiani cristo.
# Expected: ma ihciuhca xicmonemililican in itlatzontequililoca in tetlapololtiani cristo.
# Character Error Rate: 0.0
#
#
# Input: yexpa motlancuaquetzatz.
# Predicted: yexpa motlancuaquetzatz.
# Expected: yexpan motlancuaquetzaz.
# Character Error Rate: 0.0833333358168602
#
#
# Input: quinoallalochtocaque
# Predicted: quinhuallalochtocaqueh
# Expected: quinhuallalochtocaqueh
# Character Error Rate: 0.0
#
#
# Input: quintepachotivi
# Predicted: quintepachotihuih
# Expected: quintepachotihuih
# Character Error Rate: 0.0
#
#
# Input: atlan quintepeoaco in españoles.
# Predicted: atlan quintepehuacoh in españoles.
# Expected: atlan quintepehuacoh in españoles.
# Character Error Rate: 0.0
#
#
# Input: notlasonātzine
# Predicted: notlazohnantzine
# Expected: notlazohnantzine
# Character Error Rate: 0.0
#
#
# Input: macamo senca nopāpa ximochoquiliuhtzinno.
# Predicted: macamo cencah nopampa ximochoquilihtzino.
# Expected: macamo cencah nopampa ximochoquilihtzino.
# Character Error Rate: 0.0
#
#
# Input: o nothecuiyotzin
# Predicted: o notecuiyotzin
# Expected: o notecuiyotzin
# Character Error Rate: 0.0
#
#
# Input: macamo momiquili in notlasoconetzin
# Predicted: macamo momiquili in notlazohconetzin
# Expected: macamo momiquili in notlazohconetzin
# Character Error Rate: 0.0
#
#
# Input: jesus.
# Predicted: jesús.
# Expected: jesús.
# Character Error Rate: 0.0
#
#
# Input: ma xihualmohuicacan.
# Predicted: ma xihualmohuicacan.
# Expected: ma xihualmohuicacan.
# Character Error Rate: 0.0
#
#
# Input: auh in o yuh conmotlatlauhtili izçenca quitlaçocamati
# Predicted: auh in o iuh commotlatlauhtilih in cencah quitlazohcamatih
# Expected: auh in o iuh commotlatlauhtilih in cencah quitlazohcamati
# Character Error Rate: 0.017543859779834747
#
#
# Input: in iteicneliltzin
# Predicted: in iteicneliltzin
# Expected: in iteicneliltzin
# Character Error Rate: 0.0
#
#
# Input: hualmocuep in ichan ça icxipan.
# Predicted: hualmocuep in ichan za icxipan.
# Expected: hualmocuep in ichan za icxipan.
# Character Error Rate: 0.0
#
#
# Input: hualmocueptzinos in campa mocochitia in yei apostoles.
# Predicted: hualmocueptzinoz in campa mocochitia in yeyi apóstoles.
# Expected: hualmocueptzinoz in campa mocochitiah in yeintin apóstoles.
# Character Error Rate: 0.08474576473236084
#
#
# Input: miec in tlapictli oquitzacuilti
# Predicted: miyec in tlapictli oquitzacuiltih
# Expected: miyac in tlapictli oquitzacuiltih
# Character Error Rate: 0.03030303120613098
#
#
# Input: in amo nelli
# Predicted: in ahmo nelli
# Expected: in ahmo nelli
# Character Error Rate: 0.0
#
#
# Input: in çan tlatolchichioalli.”
# Predicted: in zan tlahtolchihchihualli.”
# Expected: in zan tlahtolchihchihualli.”
# Character Error Rate: 0.0
#
#
# Input: çan tequitl ontemictitiquizque in tlaliztacapan
# Predicted: zan tequitl ontemictihtiquizqueh in tlaliztacapan
# Expected: zan tequitl ontemictihtiquizqueh in tlaliztacapan
# Character Error Rate: 0.0
#
#
# Input: yiztacalla;
# Predicted: iiztacallah;
# Expected: iztaccallah;
# Character Error Rate: 0.1666666716337204
#
#
# Input: nican titofirmatia
# Predicted: nican titofirmatiah
# Expected: nican titofirmatiah
# Character Error Rate: 0.0
#
#
# Input: magdalena bárbola
# Predicted: magdalena bárbola
# Expected: magdalena bárbola
# Character Error Rate: 0.0
#
#
# Input: baltasar lorenzo
# Predicted: baltasar lorenzo
# Expected: baltasar lorenzo
# Character Error Rate: 0.0
#
#
# Input: pedro de mendoza
# Predicted: pedro de mendoza
# Expected: pedro de mendoza
# Character Error Rate: 0.0
#
#
# Input: mariana.
# Predicted: mariana.
# Expected: mariana.
# Character Error Rate: 0.0
#
#
# Input: ye nehuatl yn ye huecauh yn ānechchixtinenemi.
# Predicted: ye nehhuatl in ye huehcauh in annechchixtinehnemih.
# Expected: ye nehhuatl in ye huehcauh in annechchixtinehnemih.
# Character Error Rate: 0.0
#
#
# Input: nican ipan altepetl mexico çeme caxtiltecapipiltin
# Predicted: nican ipan altepetl mexihco ceme caxtiltecapipiltin
# Expected: nican ipan altepetl mexihco cemeh caxtiltecapipiltin
# Character Error Rate: 0.01923076994717121
#
#
# Input: itoca don antonio carauajal
# Predicted: itoca don antonio caravajal
# Expected: itoca don antonio caravajal
# Character Error Rate: 0.0
#
#
# Input: quihuicac oc ce telpocatzin
# Predicted: quihuicac oc ce telpocatzin
# Expected: quihuicac oc ce telpocatzin
# Character Error Rate: 0.0
#
#
# Input: ihuanyolqui
# Predicted: ihuanyolqui
# Expected: ihuanyolqui
# Character Error Rate: 0.0
#
#
# Input: ompa ya in tollantzinco.
# Predicted: ompa yah in tollantzinco.
# Expected: ompa ya in tollantzinco.
# Character Error Rate: 0.0416666679084301
#
#
# Input: mochiti judios tlanãquilisque.
# Predicted: mochintin judíos tlananquilizqueh.
# Expected: mochintin judíos tlananquilizqueh.
# Character Error Rate: 0.0
#
#
# Input: ma tihuian
# Predicted: ma tihuian
# Expected: ma tihuian
# Character Error Rate: 0.0
#
#
# Input: ma ticmotiliti yn nocenteconetzin.
# Predicted: ma ticmottilitih in nocenteconetzin.
# Expected: ma ticmottilitih in nocenteconetzin.
# Character Error Rate: 0.0
#
#
# Input: nima quimototopehuilisque y xspto.
# Predicted: niman quimotohtopehuilizqueh in cristo.
# Expected: niman quimotohtopehuilizqueh in cristo.
# Character Error Rate: 0.0
#
#
# Input: telpochtle
# Predicted: telpochtle
# Expected: telpochtle
# Character Error Rate: 0.0
#
#
# Input: ca mitzmonochilia yn teopixcatlatoque.
# Predicted: ca mitzmonochiliah in teopixcatlahtohqueh.
# Expected: ca mitzmonochiliah in teopixcatlahtohqueh.
# Character Error Rate: 0.0
#
#
# Input: auh yn isquich y¯ nochantlatqui onicpiaya
# Predicted: auh in ixquich in nochantlatqui onicpiyaya
# Expected: auh in ixquich in nochantlatqui onicpiyaya
# Character Error Rate: 0.0
#
#
# Input: y¯ puertas cerraduras mochi niccēcahua
# Predicted: in puertas cerraduras mochi niccencahua
# Expected: in puertas cerraduras mochi niccencahua
# Character Error Rate: 0.0
#
#
# Input: aocmo tley niccuiz
# Predicted: aocmo tlein niccuiz
# Expected: aocmo tlein niccuiz
# Character Error Rate: 0.0
#
#
# Input: ça isquich ascā ypan ce xihuitl y¯ nocālalpā ocatca oc nipiscaz.
# Predicted: za ixquich axcan ipan ce xihuitl in nocallalpan ocatca oc nipixcaz.
# Expected: za ixquich axcan ipan ce xihuitl in nocallalpan ocatca oc nipixcaz.
# Character Error Rate: 0.0
#
#
# Input: vncan ie no ceppa motetemmā in iauiotl
# Predicted: oncan ye no ceppa motetemman in yaoyotl
# Expected: oncan ye no ceppa motehtemman in yaoyotl
# Character Error Rate: 0.02500000037252903
#
#
# Input: çan vncan acito.
# Predicted: zan oncan ahcitoh.
# Expected: zan oncan ahcito.
# Character Error Rate: 0.05882352963089943
#
#
# Input: ynic ce tlacatl
# Predicted: inic ce tlacatl
# Expected: inic ce tlacatl
# Character Error Rate: 0.0
#
#
# Input: notlal nicpatilti çihuapilli doña juana xochmilco omatzaqualli.
# Predicted: notlal nicpatilti cihuapilli doña juana xochmilco omatzacualli.
# Expected: notlal nicpatiltih cihuapilli doña juana xochmilco omatzaqualli.
# Character Error Rate: 0.03125
#
#
# Input: tzatzis oquichcuanaca yexpa.
# Predicted: tzahtziz oquichcuanacah yexpa.
# Expected: tzahtziz oquichcuanaca yexpan.
# Character Error Rate: 0.06666667014360428
#
#
# Input: yhuan ca y onicmat yn tleyn quinmotequipachilhuia yn tlatoque.
# Predicted: ihuan ca in onicmat in tlein quimmotequipachilhuia in tlahtohqueh.
# Expected: ihuan ca in onicmat in tlein quimmotequipachilhuia in tlahtohqueh.
# Character Error Rate: 0.0
#
#
# Input: ma niauh
# Predicted: ma niyauh
# Expected: ma niyauh
# Character Error Rate: 0.0
#
#
# Input: ma niquimitati y jodiosme
# Predicted: ma niquimittati in judíosmeh
# Expected: ma niquimittati in judíosmeh
# Character Error Rate: 0.0
#
#
# Input: yn tlatoque
# Predicted: in tlahtohqueh
# Expected: in tlahtohqueh
# Character Error Rate: 0.0
#
#
# Input: yn pontifises
# Predicted: in pontífices
# Expected: in pontífices
# Character Error Rate: 0.0
#
#
# Input: y saserdotes.
# Predicted: in sacerdotes.
# Expected: in sacerdotes.
# Character Error Rate: 0.0
#
#
# Input: campa in timohuicatzinohua in ye thitechmocahuilitzinohua?
# Predicted: campa in timohuicatzinoa in ye titechmocahuilihtzinoa?
# Expected: campa in timohuicatzinoa in ye titechmocahuilihtzinoa?
# Character Error Rate: 0.0
#
#
# Input: otoconmocaquilti yn ixquich ytlachihual ynin teyxcuepani
# Predicted: otocommocaquiltih in ixquich itlachihual inin teixcuepani
# Expected: otocommocaquiltih in ixquich itlachihual inin teixcuepani
# Character Error Rate: 0.0
#
#
# Input: ynic tetlapololtitinemi.
# Predicted: inic tetlapololtihtinemi.
# Expected: inic tetlapololtihtinemi.
# Character Error Rate: 0.0
#
#
# Input: cuix āmo seca tehpinahuisque?
# Predicted: cuix ahmo cencah techpinahuizqueh?
# Expected: cuix ahmo cencah techpinahuizqueh?
# Character Error Rate: 0.0
#
#
# Input: ca in yehuatl in motenehua xpto
# Predicted: ca in yehhuatl in motenehua cristo
# Expected: ca in yehhuatl in motenehua cristo
# Character Error Rate: 0.0
#
#
# Input: ca senca miec tlamantli quichihua tlamahuisoli.
# Predicted: ca cencah miyec tlamantli quichihua tlamahuizolli.
# Expected: ca cencah miac tlamantli quichihua tlamahuizolli.
# Character Error Rate: 0.040816325694322586
#
#
# Input: yhuā acmo onpa tictemas yn altepecaxaco ynpāpa ca miquispatiotl.
# Predicted: ihuan aocmo ompa tictemaz in altepecajaco ipampa ca miquizpatiyotl.
# Expected: ihuan aocmo ompa tictemaz in altepecajaco ipampa ca miquizpatiyotl.
# Character Error Rate: 0.0
#
#
# Input: āmochinti xiquitoca.
# Predicted: ammochintin xiquihtocan.
# Expected: ammochintin xiquihtocan.
# Character Error Rate: 0.0
#
#
# Input: ca nonahuac moyetztiez yn notlazotatzin
# Predicted: ca nonahuac moyetztiyez in notlazohtahtzin
# Expected: ca nonahuac moyetztiyez in notlazohtahtzin
# Character Error Rate: 0.0
#
#
# Input: dios.
# Predicted: dios.
# Expected: dios.
# Character Error Rate: 0.0
#
#
# Input: xichualquixtican yn quauhnepanoli
# Predicted: xichualquixtican in cuauhnepanolli
# Expected: xichualquixtican in cuauhnepanolli
# Character Error Rate: 0.0
#
#
# Input: crus
# Predicted: cruz
# Expected: cruz
# Character Error Rate: 0.0
#
#
# Input: ye oquisencauhque
# Predicted: ye oquicencauhqueh
# Expected: ye oquicencauhqueh
# Character Error Rate: 0.0
#
#
# Input: nima axcan ticneltilizque yn moteotenahuatiltzin.
# Predicted: niman axcan ticneltilizqueh in moteotenahuatiltzin.
# Expected: niman axcan ticneltilizqueh in moteotenahuatiltzin.
# Character Error Rate: 0.0
#
#
# Input: ac nel noso nechpatis?
# Predicted: ac nel nozo nechpahtiz?
# Expected: ac nel nozo nechpahtiz?
# Character Error Rate: 0.0
#
#
# Input: san ic tiquitas
# Predicted: zan ic tiquittaz
# Expected: zan ic tiquittaz
# Character Error Rate: 0.0
#
#
# Input: yn aqui nicmacas yn paltic tlaxcali.
# Predicted: in aquin nicmacaz in paltic tlaxcalli.
# Expected: in aquin nicmacaz in paltic tlaxcalli.
# Character Error Rate: 0.0
#
#
# Input: ca nican catqui yn atl ticmitlania
# Predicted: ca nican catqui in atl ticmihtlania
# Expected: ca nican catqui in atl ticmihtlania
# Character Error Rate: 0.0
#
#
# Input: noteotzinne
# Predicted: noteotzine
# Expected: noteotzine
# Character Error Rate: 0.0
#
#
# Input: notlatocatzinne.
# Predicted: notlahtohcatzine.
# Expected: notlahtohcatzine.
# Character Error Rate: 0.0
#
#
# Input: auh queni ninotlapalos inic nicnopohuililis ca huel theyolpatzmicti?
# Predicted: auh quenin ninotlahpaloz inic nicnopohuililiz ca huel teyolpatzmictih?
# Expected: auh quenin ninotlahpaloz inic nicnopohuililiz ca huel teyolpatzmictih?
# Character Error Rate: 0.0
#
#
# Input: necoc in tlaiecoloc vtli ipan yoan atlan in acalchimaltica.
# Predicted: necoc in tlayecoloc ohtli ipan ihuan atlan in acalchimaltica.
# Expected: necoc in tlayecoloc ohtli ipan ihuan atlan in acalchimaltica.
# Character Error Rate: 0.0
#
#
# Input: ca yehuatl mochihuas yn motlanequilitzi
# Predicted: ca yehhuatl mochihuaz in motlanequiliztzin
# Expected: ca yehhuatl mochihuaz in motlanequiliztzin
# Character Error Rate: 0.0
#
#
# Input: ca tinotlasotatzi.
# Predicted: ca tinotlazohtahtzin.
# Expected: ca tinotlazohtahtzin.
# Character Error Rate: 0.0
#
#
# Input: nicmaca yn notelpoch don lorenzo de guzmán
# Predicted: nicmaca in notelpoch don lorenzo de guzmán
# Expected: nicmaca in notelpoch don lorenzo de guzmán
# Character Error Rate: 0.0
#
#
# Input: quicuiz.
# Predicted: quicuiz.
# Expected: quicuiz.
# Character Error Rate: 0.0
#
#
# Input: ca yehuatl yn tictemotinemi.
# Predicted: ca yehhuatl in tictemohtinemih.
# Expected: ca yehhuatl in tictemohtinemih.
# Character Error Rate: 0.0
#
#
# Input: ca huell itech monequi yn miquistli ypanpa quitotinemi,
# Predicted: ca huel itech monequi in miquiztli ipampa quihtohtinemi,
# Expected: ca huel itech monequi in miquiztli ipampa quihtohtinemi,
# Character Error Rate: 0.0
#
#
# Input: huel nelli niquitoa yc tonehua
# Predicted: huel nelli niquihtoa ic tonehua
# Expected: huel nelli niquihtoa ic tonehua
# Character Error Rate: 0.0
#
#
# Input: chichinaca
# Predicted: chichinaca
# Expected: chichinaca
# Character Error Rate: 0.0
#
#
# Input: yn nixi
# Predicted: in nix
# Expected: in nix
# Character Error Rate: 0.0
#
#
# Input: yn noyolo.
# Predicted: in noyollo.
# Expected: in noyollo.
# Character Error Rate: 0.0
#
#
# Input: ca yetihue
# Predicted: ca yetihueh
# Expected: ca yetihuih
# Character Error Rate: 0.09090909361839294
#
#
# Input: ynic tictocaquistililitihue yn totemachticatzin
# Predicted: inic tictocaquiztililihtihuih in totemachtihcatzin
# Expected: inic tictocaquiztililitihuih in totemachtihcatzin
# Character Error Rate: 0.020408162847161293
#
#
# Input: ynic senca oticmaseuhque yn momahuisyotzin
# Predicted: inic cencah oticmahceuhqueh in momahuizzotzin
# Expected: inic cencah oticmahceuhqueh in momahuizzotzin
# Character Error Rate: 0.0
#
#
# Input: mahuistlacatzitlen.
# Predicted: mahuiztlacatzintle.
# Expected: mahuiztlacatzintle.
# Character Error Rate: 0.0
#
#
# Input: ihuan toguardián
# Predicted: ihuan toguardián
# Expected: ihuan toguardián
# Character Error Rate: 0.0
#
#
# Input: imahuiztocatzin fray melchor
# Predicted: imahuiztocatzin fray melchor
# Expected: imahuiztocatzin fray melchor
# Character Error Rate: 0.0
#
#
# Input: nican techpachoticate santa iglesia
# Predicted: nican techpachohticateh santa iglesia
# Expected: nican techpachohticateh santa iglesia
# Character Error Rate: 0.0
#
#
# Input: ihuan fray andres meriena
# Predicted: ihuan fray andres meriena
# Expected: ihuan fray andrés meriena
# Character Error Rate: 0.03999999910593033
#
#
# Input: president.
# Predicted: president.
# Expected: presidente.
# Character Error Rate: 0.09090909361839294
#
#
# Input: tlatos tlanahuac jodas.
# Predicted: tlahtoz tlanahuac judas.
# Expected: tlahtoz tlanahuac judas.
# Character Error Rate: 0.0
#
#
# Input: huel ye yyocahui.
# Predicted: huel ye ihiyocahuih.
# Expected: huel ye ihiyocahua.
# Character Error Rate: 0.10526315867900848
#
#
# Input: inic macuilli capitulo
# Predicted: inic macuilli capítulo
# Expected: inic macuilli capítulo
# Character Error Rate: 0.0
#
#
# Input: vncan mitoa in tlein muchiuh in iquac ititlanoan motecuçoma in vmpa callacque in iacalco don hernando cortes.
# Predicted: oncan mihtoa in tlein mochiuh in ihcuac ititlanohuan moteuczoma in ompa calacqueh in yacalco don hernando cortes.
# Expected: oncan mihtoa in tlein mochiuh in ihcuac ititlanhuan moteuczoma in ompa calacqueh in iacalco don hernando cortés.
# Character Error Rate: 0.02678571455180645
#
#
# Input: auh intla itla ic onimitzcualani
# Predicted: auh in tla itlah ic onimitzcualanih
# Expected: auh in tla itlah ic onimitzcualani
# Character Error Rate: 0.029411764815449715
#
#
# Input: ca nican mocxitlan tinechpia.
# Predicted: ca nican mocxitlan tinechpiya.
# Expected: ca nican mocxitlan tinechpiya.
# Character Error Rate: 0.0
#
#
# Input: çan ie no ivi in tpuzmitl
# Predicted: zan ye no ihui in tpozmitl
# Expected: zan ye no ihui in tepozmitl
# Character Error Rate: 0.03703703731298447
#
#
# Input: in aquin vel quimottilia
# Predicted: in aquin huel quimottilia
# Expected: in aquin huel quimottiliah
# Character Error Rate: 0.03846153989434242
#
#
# Input: aocmo quica;
# Predicted: aocmo quicah;
# Expected: aocmo quiza;
# Character Error Rate: 0.1666666716337204
#
#
# Input: auh in yehuatl cenca quimahuiço in quenin imach hualhuico
# Predicted: auh in yehhuatl cencah quimahuizoh in quenin imach hualhuico
# Expected: auh in yehhuatl cencah quimahuizoh in quenin imach hualhuico
# Character Error Rate: 0.0
#
#
# Input: ihuan çenca mahuiztililo
# Predicted: ihuan cencah mahuiztililo
# Expected: ihuan cencah mahuiztililo
# Character Error Rate: 0.0
#
#
# Input: quitlatlani in imach tleica in yuhqui chihualo
# Predicted: quitlahtlanih in imach tleica in iuhqui chihualo
# Expected: quitlahtlanih in imach tleica in iuhqui chihualo
# Character Error Rate: 0.0
#
#
# Input: in çenca mahuiztililo.
# Predicted: in cencah mahuiztililo.
# Expected: in cencah mahuiztililo.
# Character Error Rate: 0.0
#
#
# Input: ca huel axcan nimitzçetelchihua yn tinonechichihual.
# Predicted: ca huel axcan nimitzcetelchihua in tinonechihchihual.
# Expected: ca huel axcan nimitzcentelchihua in tinonechihchihual.
# Character Error Rate: 0.018518518656492233
#
#
# Input: auh in ommicoac cholollan
# Predicted: auh in ommicohuac cholollan
# Expected: auh in ommicohuac cholollan
# Character Error Rate: 0.0
#
#
# Input: nimā oalpeuhque in ie ic vitze mexico
# Predicted: niman hualpeuhqueh in ye ic huitzeh mexihco
# Expected: niman hualpeuhqueh in ye ic huitzeh mexihco
# Character Error Rate: 0.0
#
#
# Input: ololiuhtivitze
# Predicted: ololiuhtihuitzeh
# Expected: ololiuhtihuitzeh
# Character Error Rate: 0.0
#
#
# Input: tepeuhtivitze
# Predicted: tepeuhtihuitzeh
# Expected: tepeuhtihuitzeh
# Character Error Rate: 0.0
#
#
# Input: teuhtli quiquetztivitze.
# Predicted: teuhtli quiquetztihuitzeh.
# Expected: teuhtli quiquetztihuitzeh.
# Character Error Rate: 0.0
#
#
# Input: huel nesqui yn ixquich ytlatlacol.
# Predicted: huel nezqui in ixquich itlahtlacol.
# Expected: huel nezqui in ixquich itlahtlacol.
# Character Error Rate: 0.0
#
#
# Input: ca nosenyolocacopa ynic nicnoselilitzinos.
# Predicted: ca nocenyollohcacopa inic nicnocelilihtzinoz.
# Expected: ca nocenyollohcacopa inic nicnocelilihtzinoz.
# Character Error Rate: 0.0
#
#
# Input: ahu in amehuanti anquichihua yquima san tianquisco yn ipan atlamati
# Predicted: auh in amehhuantin anquichihuah iquimmah zan tianquizco in ipan atlamatih
# Expected: auh in amehhuantin anquichihuah iuhquimmah zan tianquizco in ipan antlamatih
# Character Error Rate: 0.03947368264198303
#
#
# Input: ocann atiamiqui
# Predicted: occan atiamiquih
# Expected: oncan antiamiquih
# Character Error Rate: 0.11764705926179886
#
#
# Input: yn ocann atlanamacatoque
# Predicted: in oncan atlanamacatohqueh
# Expected: in oncan antlanamacatoqueh
# Character Error Rate: 0.07692307978868484
#
#
# Input: yn ocan teca anmahuiltitoque.
# Predicted: in oncan tecah ammahuiltitoqueh.
# Expected: in oncan teca ammahuiltitoqueh.
# Character Error Rate: 0.032258063554763794
#
#
# Input: yhūa yhua ye miyec yteycnoitalis
# Predicted: ihuan ihuan ye miyec iteicnoittaliz
# Expected: ihuan ye miac iteicnoittaliz
# Character Error Rate: 0.2857142984867096
#
#
# Input: yn itetlasotlalis.
# Predicted: in itetlazohtlaliz.
# Expected: in itetlazohtlaliz.
# Character Error Rate: 0.0
#
#
# Input: ca ye onictlatzacuiltin.
# Predicted: ca ye onictlatzacuiltin.
# Expected: ca ye onictlatzacuiltih.
# Character Error Rate: 0.0416666679084301
#
#
# Input: quin quemanian onpa tias.
# Predicted: quin quemmaniyan ompa tiyaz.
# Expected: quin quemmaniyan ompa tiyaz.
# Character Error Rate: 0.0
#
#
# Input: auh ynic moteonequi
# Predicted: auh inic moteonequi
# Expected: auh inic moteonequi
# Character Error Rate: 0.0
#
#
# Input: quen aquita?
# Predicted: quen anquittah?
# Expected: quen anquittah?
# Character Error Rate: 0.0
#
#
# Input: ma ximochicauhtzinno
# Predicted: ma ximochicauhtzino
# Expected: ma ximochicauhtzino
# Character Error Rate: 0.0
#
#
# Input: tlasosihuapilli.
# Predicted: tlazohcihuapilli.
# Expected: tlazohcihuapilli.
# Character Error Rate: 0.0
#
#
# Input: ma vel ximochichioacā.”
# Predicted: ma huel ximochihchihuacan.”
# Expected: ma huel ximochihchihuacan.”
# Character Error Rate: 0.0
#
#
# Input: no ihuan oncan conmottitili in tlalmantzintli in oncan moquetzaz teocaltzintli
# Predicted: no ihuan oncan commottitilih in tlalmantzintli in oncan moquetzaz teohcaltzintli
# Expected: no ihuan oncan commottitilih in tlalmantzintli in oncan moquetzaz teohcaltzintli
# Character Error Rate: 0.0
#
#
# Input: ihuan in oncan ca ic çen quihualmihuali inic quittaz tlatohuani obispo in quimotitlanilili xochitl in ineltica
# Predicted: ihuan in oncan ca ic cen quihualmihualih inic quittaz tlahtoani obispo in quimotitlanililih xochitl in ineltica
# Expected: ihuan in oncan ca ic cen quihualmihualih inic quittaz tlahtoani obispo in quimotitlanililih xochitl in ineltica
# Character Error Rate: 0.0
#
#
# Input: ihuan in inezca
# Predicted: ihuan in inezcah
# Expected: ihuan in inezca
# Character Error Rate: 0.06666667014360428
#
#
# Input: itlanequiliztzin
# Predicted: itlanequiliztzin
# Expected: itlanequiliztzin
# Character Error Rate: 0.0
#
#
# Input: ic mochihuaz iteocaltzin.
# Predicted: ic mochihuaz iteohcaltzin.
# Expected: ic mochihuaz iteohcaltzin.
# Character Error Rate: 0.0
#
#
# Input: auh itech motlali in iuan bernardino
# Predicted: auh itech motlalih in juan bernardino
# Expected: auh itech motlalih in juan bernardino
# Character Error Rate: 0.0
#
#
# Input: auh in ye huellanauhtoc
# Predicted: auh in ye huellanauhtoc
# Expected: auh in ye huellanauhtoc
# Character Error Rate: 0.0
#
#
# Input: quimocochittili in ilhuicac çihuapilli.
# Predicted: quimocochittilih in ilhuicac cihuapilli.
# Expected: quimocochittilih in ilhuicac cihuapilli.
# Character Error Rate: 0.0
#
#
# Input: inic vntetl tetzavitl muchiuh
# Predicted: inic ontetl tetzahuitl mochiuh
# Expected: inic ontetl tetzahuitl mochiuh
# Character Error Rate: 0.0
#
#
# Input: nican mexico.
# Predicted: nican mexihco.
# Expected: nican mexihco.
# Character Error Rate: 0.0
#
#
# Input: nocontepotztoca in teoyotl
# Predicted: nocontepotztoca in teoyotl
# Expected: nocontepotztoca in teoyotl
# Character Error Rate: 0.0
#
#
# Input: in techmomaquilia
# Predicted: in techmomaquilia
# Expected: in techmomaquiliah
# Character Error Rate: 0.0555555559694767
#
#
# Input: in techmomachtilia in ixiptlahuan in tlacatl in totecuiyo
# Predicted: in techmomachtilia in ixiptlahuan in tlacatl in totecuiyo
# Expected: in techmomachtiliah in ixiptlahuan in tlacatl in totecuiyo
# Character Error Rate: 0.017241379246115685
#
#
# Input: in toteopixcahuan.”
# Predicted: in toteopixcahuan.”
# Expected: in toteopixcahuan.”
# Character Error Rate: 0.0
#
#
# Input: senca mahuistic ynic tlasenpanahuia yn itlasoxayacatzin yn notlasoconetzin.
# Predicted: cencah mahuiztic inic tlacempanahuia in itlazohxayacatzin in notlazohconetzin.
# Expected: cencah mahuiztic inic tlacempanahuia in itlazohxayacatzin in notlazohconetzin.
# Character Error Rate: 0.0
#
#
# Input: yn aquin nictenamiquis
# Predicted: in aquin nictenamiquiz
# Expected: in aquin nictennamiquiz
# Character Error Rate: 0.043478261679410934
#
#
# Input: yehuatli xicanacan.
# Predicted: yehhuatl xicanacan.
# Expected: yehhuatli xicanacan.
# Character Error Rate: 0.05000000074505806
#
#
# Input: onenemisque yn s. juan yhuan s. yacobo.
# Predicted: onehnemizqueh in san juan ihuan san jacobo.
# Expected: onnehnemizqueh in san juan ihuan san jacobo.
# Character Error Rate: 0.022727273404598236
#
#
# Input: ca neli amotequitilia
# Predicted: ca nelli amotequitilia
# Expected: ca nelli ammotequitiliah
# Character Error Rate: 0.0833333358168602
#
#
# Input: anmotlacotilia.
# Predicted: ammotlacohtiliah.
# Expected: ammotlacohtiliah.
# Character Error Rate: 0.0
#
#
# Input: ma oc nimitznotlalcahuili in nimocnomaçehual.”
# Predicted: ma oc nimitznotlalcahuili in nimocnomacehual.”
# Expected: ma oc nimitznotlalcahuili in nimocnomacehual.”
# Character Error Rate: 0.0
#
#
# Input: nima tlacuilos.
# Predicted: niman tlahcuiloz.
# Expected: niman tlahcuiloz.
# Character Error Rate: 0.0
#
#
# Input: hualmoquixtis y xspo yhuann apustoles.
# Predicted: hualmoquixtiz in cristo ihuan apóstoles.
# Expected: hualmoquixtiz in cristo ihuan apóstoles.
# Character Error Rate: 0.0
#
#
# Input: vncan vel caxavaque in mexica in tiacaoan.
# Predicted: oncan huel caxahuaqueh in mexihcah in tiacahuan.
# Expected: oncan huel caxahuaqueh in mexihcah in tiacahuan.
# Character Error Rate: 0.0
#
#
# Input: ca conmati y noyonllo ca ye ytla ypantzinco omochiuh yn notlasoconetzin.
# Predicted: ca commati in noyolloh ca ye itlah ipantzinco omochiuh in notlazohconetzin.
# Expected: ca commati in noyollo ca ye itlah ipantzinco omochiuh in notlazohconetzin.
# Character Error Rate: 0.013513513840734959
#
#
# Input: auh niman moquetztehuac;
# Predicted: auh niman moquetztehuac;
# Expected: auh niman moquetztehuac;
# Character Error Rate: 0.0
#
#
# Input: auh ca nōtli nixpan omocuep.
# Predicted: auh ca nontli nixpan omocuep.
# Expected: auh ca nontli nixpan omocuep.
# Character Error Rate: 0.0
#
#
# Input: nicanatiuh yn cuauhnepanoli crus.
# Predicted: nicanatiuh in cuauhnepanolli cruz.
# Expected: nicanatiuh in cuauhnepanolli cruz.
# Character Error Rate: 0.0
#
#
# Input: “amo nican niccaquiz.
# Predicted: “ahmo nican niccaquiz.
# Expected: “ahmo nican niccaquiz.
# Character Error Rate: 0.0
#
#
# Input: ytla tilpiloz
# Predicted: in tla tilpiloz
# Expected: in tla tilpiloz
# Character Error Rate: 0.0
#
#
# Input: yn saso tleyn mopantzinco mochihuas
# Predicted: in zazo tlein mopantzinco mochihuaz
# Expected: in zazo tlein mopantzinco mochihuaz
# Character Error Rate: 0.0
#
#
# Input: ma mohuantzinco niquiyohuis.
# Predicted: ma mohuantzinco niquihiyohuiz.
# Expected: ma mohuantzinco niquihiyohuiz.
# Character Error Rate: 0.0
#
#
# Input: quinhualmotilis s.ta mr.a.
# Predicted: quinhualmottiliz santa mría.
# Expected: quihualmottiliz santa maría.
# Character Error Rate: 0.0714285746216774
#
#
# Input: ynmanel axca otlayecteneque
# Predicted: in ma nel axcan otlayecteneuh
# Expected: in ma nel axcan otlayecteneuhqueh
# Character Error Rate: 0.12121212482452393
#
#
# Input: san itlanequilisticatzinco y notlasothatzin
# Predicted: zan itlanequilizticatzinco in notlazohtahtzin
# Expected: zan itlanequilizticatzinco in notlazohtahtzin
# Character Error Rate: 0.0
#
#
# Input: dios.
# Predicted: dios.
# Expected: dios.
# Character Error Rate: 0.0
#
#
# Input: cuix achitzin ticmomacehuitzino in itechicahualiztzin in tlacatl in totecuiyo?
# Predicted: cuix achihtzin ticmomahcehuihtzinoh in itechicahualiztzin in tlacatl in totecuiyo?
# Expected: cuix achihtzin ticmomahcehuihtzinoh in itechicahualiztzin in tlacatl in totecuiyo?
# Character Error Rate: 0.0
#
#
# Input: ma ximopapaquiltitie in titlatohuani poncio pilato.
# Predicted: ma ximopahpaquiltihtiye in titlahtoani poncio pilato.
# Expected: ma ximopahpaquiltihtiye in titlahtoani poncio pilato.
# Character Error Rate: 0.0
#
#
# Input: cuix huel hualcalaquis?
# Predicted: cuix huel hualcalaquiz?
# Expected: cuix huel hualcalaquiz?
# Character Error Rate: 0.0
#
#
# Input: niman yasque ychan pilato.
# Predicted: niman yazqueh ichan pilato.
# Expected: niman yazqueh ichan pilato.
# Character Error Rate: 0.0
#
#
# Input: mache nican timoscotica.
# Predicted: mache nican timozcohticah.
# Expected: macheh nican timozcohticah.
# Character Error Rate: 0.03703703731298447
#
#
# Input: niman quimohuilisque yn xpo ychan pilato.
# Predicted: niman quimohuilizqueh in cristo ichan pilato.
# Expected: niman quimohuiquilizqueh in cristo ichan pilato.
# Character Error Rate: 0.0625
#
#
# Input: ca ocac ocse thotlathocauh
# Predicted: ca oc ac oc ce totlahtohcauh
# Expected: ca aoc ac oc ce totlahtohcauh
# Character Error Rate: 0.03448275849223137
#
#
# Input: ca san isel in huei enperador thiverio sesar.
# Predicted: ca zan icel in huei emperador tiverio césar.
# Expected: ca zan icel in huei emperador tiberio césar.
# Character Error Rate: 0.022727273404598236
#
#
# Input: ma noso cana ninopiloti
# Predicted: ma nozo canah ninopiloti
# Expected: ma nozo cana ninopiloti
# Character Error Rate: 0.043478261679410934
#
#
# Input: y nihueytlahueliloc.
# Predicted: in nihueitlahueliloc.
# Expected: in nihueitlahueliloc.
# Character Error Rate: 0.0
#
#
# Input: auh naxcan
# Predicted: auh in axcan
# Expected: auh in axcan
# Character Error Rate: 0.0
#
#
# Input: notlasonatzinne
# Predicted: notlazohnantzine
# Expected: notlazohnantzine
# Character Error Rate: 0.0
#
#
# Input: ma ximoyolalitzinno.
# Predicted: ma ximoyollalihtzino.
# Expected: ma ximoyollalihtzino.
# Character Error Rate: 0.0
#
#
# Input: ca yn pipiltotonti ynic teyectenehua
# Predicted: ca in pipiltotontin inic teyectenehuah
# Expected: ca in pipiltotontin inic teyectenehuah
# Character Error Rate: 0.0
#
#
# Input: ynic temahuistilia
# Predicted: inic temahuiztilia
# Expected: inic temahuiztiliah
# Character Error Rate: 0.05263157933950424
#
#
# Input: oc achi huel moneltocasque ypanpa yn semanahuac ytech pehua ynic temahuistilia
# Predicted: oc achi huel moneltocazqueh ipampa in cemanahuac itech pehua inic temahuiztilia
# Expected: oc achi huel moneltocazqueh ipampa cemanahuac intech pehua inic temahuiztiliah
# Character Error Rate: 0.06410256773233414
#
#
# Input: ynic teyectenehua
# Predicted: inic teyectenehua
# Expected: inic teyectenehuah
# Character Error Rate: 0.0555555559694767
#
#
# Input: ye yca ayemo ometitica ynnyolo?
# Predicted: ye ica ayamo ometitica inyollo?
# Expected: ye ica ayamo ometihticah in inyollo?
# Character Error Rate: 0.1388888955116272
#
#
# Input: sihuapile
# Predicted: cihuapille
# Expected: cihuapille
# Character Error Rate: 0.0
#
#
# Input: ma ixquich in mochoquitzin ma xicmothilitzino yn motlasomahuissenteconetzin.
# Predicted: ma ixquich in mochoquihtzin ma xicmottilihtzino in motlazohmahuizenteconetzin.
# Expected: ma ixquich in mochoquiztzin ma xicmottilihtzino in motlazohmahuizcenteconetzin.
# Character Error Rate: 0.025316456332802773
#
#
# Input: cuix ytla amotetzinco monequi?
# Predicted: cuix itlah amotechtzinco monequi?
# Expected: cuix itlah amotechtzinco monequi?
# Character Error Rate: 0.0
#
#
# Input: conmunamiquilis xpo.
# Predicted: commonamiquiliz cristo.
# Expected: comonnamiquiliz cristo.
# Character Error Rate: 0.08695652335882187
#
#
# Input: yn axcan ca y oticneltilique
# Predicted: in axcan ca in oticneltilihqueh
# Expected: in axcan ca in oticneltilihqueh
# Character Error Rate: 0.0
#
#
# Input: ynic oticmecahuitecque.
# Predicted: inic oticmecahuitecqueh.
# Expected: inic oticmecahuitecqueh.
# Character Error Rate: 0.0
#
#
# Input: cuix neli omic yn xpo
# Predicted: cuix nelli omic in cristo
# Expected: cuix nelli omic in cristo
# Character Error Rate: 0.0
#
#
# Input: yn intlatocauh yn jodios?
# Predicted: in intlahtohcauh in judíos?
# Expected: in intlahtohcauh in judíos?
# Character Error Rate: 0.0
#
#
# Input: inic quitelchiuhque
# Predicted: inic quitelchiuhqueh
# Expected: inic quitelchiuhqueh
# Character Error Rate: 0.0
#
#
# Input: inic quiiyaque in tlateotoquiliztli
# Predicted: inic quiyahqueh in tlateotoquiliztli
# Expected: inic quihiyaqueh in tlateotoquiliztli
# Character Error Rate: 0.0810810774564743
#
#
# Input: inic omotlapololtitinemico in tlalticpac
# Predicted: inic omotlapololtihtinemicoh in tlalticpac
# Expected: inic omotlapololtihtinemicoh in tlalticpac
# Character Error Rate: 0.0
#
#
# Input: in tlayohuayan in mixtecomac ic oquinnemiti in tlacatecolotl.
# Predicted: in tlayohuayan in mixtecomac ic oquinnemitih in tlacatecolotl.
# Expected: in tlayohuayan in mixtecomac ic oquinnemitih in tlacatecolotl.
# Character Error Rate: 0.0
#
#
# Input: yexcanpa tlanahuatis
# Predicted: yexcampa tlanahuatiz
# Expected: yexcampa tlanahuatiz
# Character Error Rate: 0.0
#
#
# Input: tzatzitz
# Predicted: tzahtzitz
# Expected: tzahtziz
# Character Error Rate: 0.125
#
#
# Input: ynic quipohuas yn tlatocatlanahuatili.
# Predicted: inic quipohuaz in tlahtohcatlanahuatilli.
# Expected: inic quipohuaz in tlahtohcatlanahuatilli.
# Character Error Rate: 0.0
#
#
# Input: amo timitzinximati.
# Predicted: ahmo timitziximatih.
# Expected: ahmo timitziximatih.
# Character Error Rate: 0.0
#
#
# Input: macamo xicmocahuilican
# Predicted: macamo xicmocahuilican
# Expected: macamo xicmocahuilican
# Character Error Rate: 0.0
#
#
# Input: ca senca motlacolsotlahualtitzinohua yn sa yseltzi.
# Predicted: ca cencah motlaocolzotlahualtihtzinoa in zan iceltzin.
# Expected: ca cencah motlaocolzotlahualtihtzinoa in zan iceltzin.
# Character Error Rate: 0.0
#
#
# Input: huel tentemis yn imapiltzalan y notzontzin
# Predicted: huel tentemiz in imapiltzalan in notzontzin
# Expected: huel tehtemiz in immapiltzalan in notzontzin
# Character Error Rate: 0.04545454680919647
#
#
# Input: yhuan y nocpac tepostica tlamalintli
# Predicted: ihuan in nocpac tepoztica tlamalintli
# Expected: ihuan in nocpac tepoztica tlamalintli
# Character Error Rate: 0.0
#
#
# Input: yn xocohuetzyahuali
# Predicted: in xocohuetzyahualli
# Expected: in xocohuitzyahualli
# Character Error Rate: 0.05000000074505806
#
#
# Input: nechimanilisque.
# Predicted: nechimanilizqueh.
# Expected: nechmanilizqueh.
# Character Error Rate: 0.0625
#
#
# Input: huel iuhqui xictlali
# Predicted: huel iuhqui xictlali
# Expected: huel iuhqui xictlali
# Character Error Rate: 0.0
#
#
# Input: huel iuhqui xicicuilo
# Predicted: huel iuhqui xicihcuilo
# Expected: huel iuhqui xiquihcuilo
# Character Error Rate: 0.08695652335882187
#
#
# Input: escrivano.
# Predicted: escribano.
# Expected: escribanoh.
# Character Error Rate: 0.09090909361839294
#
#
# Input: ahu in axcan
# Predicted: auh in axcan
# Expected: auh in axcan
# Character Error Rate: 0.0
#
#
# Input: ma tehūatzin xiquinmomaquixtilitzinno yn motetlacolitzin ynic mochipa semicac mitzmolnamiquilitzinnosque."
# Predicted: ma tehhuatzin xiquimmomaquixtilihtzino in motetlaocolihtzin inic mochipa cemihcac mitzmolnamiquilihtzinozqueh."
# Expected: ma tehhuatzin xiquimmomaquixtilihtzino in motetlaocoliztzin inic mochipa cemihcac mitzmolnamiquilihtzinozqueh."
# Character Error Rate: 0.009009009227156639
#
#
# Input: ma niquinmaca yn inteocuitl.
# Predicted: ma niquimmaca in inteocuitl.
# Expected: ma niquimmaca in inteocuitl.
# Character Error Rate: 0.0
#
#
# Input: otoconmitalhui
# Predicted: otocommihtalhuih
# Expected: otocommihtalhuih
# Character Error Rate: 0.0
#
#
# Input: macihui izçan nican
# Predicted: macihui in zan nican
# Expected: macihui in zan nican
# Character Error Rate: 0.0
#
#
# Input: ca achi onanticatqui.
# Predicted: ca achi onanticatqui.
# Expected: ca achi onanticatqui.
# Character Error Rate: 0.0
#
#
# Input: quitoaia
# Predicted: quihtoayah
# Expected: quihtoayah
# Character Error Rate: 0.0
#
#
# Input: “oquihiovi intlacatl in tlacuchcalcatl in itzquauhtzin
# Predicted: “oquihiyohuih intlacatl in tlacochcalcatl in itzcuauhtzin
# Expected: “oquihiyohuih in tlacatl in tlacochcalcatl in itzcuauhtzin
# Character Error Rate: 0.017241379246115685
#
#
# Input: ca ivan otlaihiovi yoā omotolini in motecuçoma.
# Predicted: ca ihuan otlaihiyohui ihuan omotolinih in moteuczoma.
# Expected: ca ihuan otlaihiyohuih ihuan omotolinih in moteuczoma.
# Character Error Rate: 0.018518518656492233
#
#
# Input: auh capa yn timohuicatzinos
# Predicted: auh capa in timohuicatzinoz
# Expected: auh campa in timohuicatzinoz
# Character Error Rate: 0.0357142873108387
#
#
# Input: yn ye titechmonahuatilitzinen?
# Predicted: in ye titechmonahuatilihtzine?
# Expected: in ye titechmonahuatilihtzinoh?
# Character Error Rate: 0.06451612710952759
#
#
# Input: ca çan ixquich tzocotzin ic timitztonepechtequilila ic ticpachoa in momatzin in mocxitzin
# Predicted: ca zan ixquich tzocotzin ic timitztonepechtequililah ic ticpachoah in momatzin in mocxitzin
# Expected: ca zan ixquich tzocotzin ic timitztonepechtequililiah ic ticpachoah in momatzin in mocxitzin
# Character Error Rate: 0.010869565419852734
#
#
# Input: tlacatle
# Predicted: tlacatle
# Expected: tlacatle
# Character Error Rate: 0.0
#
#
# Input: totecuiyoe.
# Predicted: totecuiyoe.
# Expected: totecuiyoe.
# Character Error Rate: 0.0
#
#
# Input: “cuix nomaçehual in ye niccaqui?
# Predicted: “cuix nomacehual in ye niccaqui?
# Expected: “cuix nomahcehual in ye niccaqui?
# Character Error Rate: 0.03030303120613098
#
#
# Input: ye onoconpohuili yn telpochtli yn çenpoali onmatlactli tlatemantli theocuitlatl.
# Predicted: ye onocompohuilih in telpochtli in cempohualli ommahtlactli tlatemantli teocuitlatl.
# Expected: ye onocompohuilih in telpochtli in cempohualli ommatlactli tlatemantli teocuitlatl.
# Character Error Rate: 0.012048192322254181
#
#
# Input: yn tehuantin pipiltin
# Predicted: in tehhuantin pipiltin
# Expected: in tehhuantin pipiltin
# Character Error Rate: 0.0
#
#
# Input: don toribio cortés
# Predicted: don toribio cortés
# Expected: don toribio cortés
# Character Error Rate: 0.0
#
#
# Input: gobernador
# Predicted: gobernador
# Expected: gobernador
# Character Error Rate: 0.0
#
#
# Input: yhuan tehuãtin alcaldes
# Predicted: ihuan tehhuantin alcaldes
# Expected: ihuan tehhuantin alcaldes
# Character Error Rate: 0.0
#
#
# Input: regidores nican villa santa maría de la asunción quauhnahuac:
# Predicted: regidores nican villa santa maría de la asunción cuauhnahuac:
# Expected: regidores nican villa santa maría de la asunción cuauhnahuac:
# Character Error Rate: 0.0
#
#
# Input: aço otimitztotzonteconehuilique.
# Predicted: ahzo otimitztotzonteconehuilihqueh.
# Expected: ahzo otimitztotzonteconehuilihqueh.
# Character Error Rate: 0.0
#
#
# Input: çan tlapouhtiuh in itzontecon
# Predicted: zan tlapouhtiuh in itzontecon
# Expected: zan tlapouhtiuh in itzontecon
# Character Error Rate: 0.0
#
#
# Input: neztiuh inic otomitl.
# Predicted: neztiuh inic otomitl.
# Expected: neztiuh inic otomitl.
# Character Error Rate: 0.0
#
#
# Input: auh ytla yoqui nicnotequitis
# Predicted: auh itlah iuhqui nicnotequitiz
# Expected: auh in tla iuhqui nicnotequitiz
# Character Error Rate: 0.09677419066429138
#
#
# Input: anca neli onotlahueliltic.
# Predicted: anca nelli onotlahueliltic.
# Expected: anca nelli onotlahueliltic.
# Character Error Rate: 0.0
#
#
# Input: moch cōmotechtique.
# Predicted: moch commotechtihqueh.
# Expected: moch commotechtihqueh;
# Character Error Rate: 0.04545454680919647
#
#
# Input: tte
# Predicted: totecuiyoe
# Expected: totecuiyoe
# Character Error Rate: 0.0
#
#
# Input: ca nitlachiasnequi.
# Predicted: ca nitlachiyaznequi.
# Expected: ca nitlachiyaznequi.
# Character Error Rate: 0.0
#
#
# Input: quimacasque atl
# Predicted: quimacazqueh atl
# Expected: quimacazqueh atl
# Character Error Rate: 0.0
#
#
# Input: momatequis.
# Predicted: momatequiz.
# Expected: momatequiz.
# Character Error Rate: 0.0
#
#
# Input: havic quitlatlaztivitz.
# Predicted: ahhuic quitlatlaztihuitz.
# Expected: ahhuic quitlatlaztihuitz.
# Character Error Rate: 0.0
#
#
# Input: neltiz notlatol.
# Predicted: neltiz notlahtol.
# Expected: neltiz notlahtol.
# Character Error Rate: 0.0
#
#
# Input: nican caquilia yn corona.
# Predicted: nican caquilia in coronah.
# Expected: nican caquiliah in coronah.
# Character Error Rate: 0.03703703731298447
#
#
# Input: quimitalhuilia yn tlacatlatoani rey erodes
# Predicted: quimihtalhuiliah in tlacatlahtoani rey herodes
# Expected: quimihtalhuilia in tlacatlahtoani rey herodes
# Character Error Rate: 0.02222222276031971
#
#
# Input: "ma occepa xicuepancan yxpantzinco yn precidente poncio pilato
# Predicted: "ma oc ceppa xicuepancan ixpantzinco in presidenteh poncio pilato
# Expected: "ma oc cepa xiccuepacan ixpantzinco in presidenteh poncio pilato
# Character Error Rate: 0.046875
#
#
# Input: ca ye in onechmotitlanili.
# Predicted: ca ye in onechmotitlanilih.
# Expected: ca ye in onechmotitlanilih.
# Character Error Rate: 0.0
#
#
# Input: xitotoca
# Predicted: xitotoca
# Expected: xitotoca
# Character Error Rate: 0.0
#
#
# Input: xinenemi.
# Predicted: xinehnemi.
# Expected: xinehnemi.
# Character Error Rate: 0.0
#
#
# Input: hualquisas gamalier.
# Predicted: hualquizaz gamaliel.
# Expected: hualquizaz gamaliel.
# Character Error Rate: 0.0
#
#
# Input: auh in calli tzitzintla cacic
# Predicted: auh in calli tzitzintla cahcic
# Expected: auh in calli tzihtzintlan cahcic
# Character Error Rate: 0.0625
#
#
# Input: auh capapachiuh
# Predicted: auh capahpachiuh
# Expected: auh capahpachiuh
# Character Error Rate: 0.0
#
#
# Input: xixitin in calli.
# Predicted: xixitin in calli.
# Expected: xihxitin in calli.
# Character Error Rate: 0.0555555559694767
#
#
# Input: nixpan oquito huel ye quin
# Predicted: nixpan oquihtoh huel ye quin
# Expected: nixpan oquihtoh huel ye quin
# Character Error Rate: 0.0
#
#
# Input: huel achitonca
# Predicted: huel achihtonca
# Expected: huel achitonca
# Character Error Rate: 0.0714285746216774
#
#
# Input: onechmacac yn itlátol
# Predicted: onechmacac in itlahtol
# Expected: onechmacac in itlahtol
# Character Error Rate: 0.0
#
#
# Input: ynic nehuatl nicchihuaz
# Predicted: inic nehhuatl nicchihuaz
# Expected: inic nehuatl nicchihuaz
# Character Error Rate: 0.043478261679410934
#
#
# Input: nictzonquixtiz
# Predicted: nictzonquixtiz
# Expected: nictzonquixtiz
# Character Error Rate: 0.0
#
#
# Input: yn tlen ye huecauh noyolotitlan yetinemi.
# Predicted: in tlein ye huehcauh noyollotitlan yetinemi.
# Expected: in tlein ye huehcauh noyollohtitlan yetinemi.
# Character Error Rate: 0.02222222276031971
#
#
# Input: onechmocnelili yn onechhualmihualili
# Predicted: onechmocnelilih in onechhualmihualilih
# Expected: onechmocnelilih in onechhualmihualilih
# Character Error Rate: 0.0
#
#
# Input: sa nican nixpan nontli omocuepaco.
# Predicted: za nican nixpan nontli omocuepaco.
# Expected: zan nican nixpan nontli omocuepaco.
# Character Error Rate: 0.02857142873108387
#
#
# Input: ma xitechilhui.
# Predicted: ma xitechilhui.
# Expected: ma xitechilhui.
# Character Error Rate: 0.0
#
#
# Input: motlaquauhquetza.
# Predicted: motlacuauhquetza.
# Expected: motlacuauhquetza.
# Character Error Rate: 0.0
#
#
# Input: ma yoqui mochihua
# Predicted: ma iuhqui mochihua
# Expected: ma iuhqui mochihua
# Character Error Rate: 0.0
#
#
# Input: tlatohuanie
# Predicted: tlahtoanie
# Expected: tlahtoanie
# Character Error Rate: 0.0
#
#
# Input: ma tiquinmimictica ychteque.
# Predicted: ma tiquimmimictica ichtequeh.
# Expected: ma tiquimmihmictican ichtecqueh.
# Character Error Rate: 0.09375
#
#
# Input: ma timitztoyacanilitihuian yn titoteycnelicatzin
# Predicted: ma timitztoyacanilihtihuian in titoteicnelicatzin
# Expected: ma timitztoyacanilihtihuian in titoteicnelicatzin
# Character Error Rate: 0.0
#
#
# Input: yn san moseltzin nenli titechmocnoytilis yn mostla huiptla.
# Predicted: in zan moceltzin nelli titechmocnoittiliz in moztla huiptla.
# Expected: in zan moceltzin nelli titechmocnoittiliz in moztla huiptla.
# Character Error Rate: 0.0
#
#
# Input: ma ximochicauhtzinno
# Predicted: ma ximochicauhtzino
# Expected: ma ximochicauhtzino
# Character Error Rate: 0.0
#
#
# Input: notlasonātzine.
# Predicted: notlazohnantzine.
# Expected: notlazohnantzine.
# Character Error Rate: 0.0
#
#
# Input: auh aocā vel mochiuhque;
# Predicted: auh aoccan huel mochiuhqueh;
# Expected: auh aoc can huel mochiuhqueh;
# Character Error Rate: 0.03448275849223137
#
#
# Input: senca quimotlayyohuiltilia?
# Predicted: cencah quimotlaihiyohuiltilia?
# Expected: cencah quimotlaihiyohuiltiliah.
# Character Error Rate: 0.06451612710952759
#
#
# Input: cuix noce itla itemoxtzin ieecatzin mopantzinco quihualmihualiznequi?
# Predicted: cuix noceh itlah itemoxtzin iehecatzin mopantzinco quihualmihualiznequi?
# Expected: cuix noceh itlah itemoxtzin iehecatzin mopantzinco quihualmihualiznequi?
# Character Error Rate: 0.0
#
#
# Input: ocsequi ycatzico mahuiltisque.
# Predicted: oc cequi icatzinco mahuiltizqueh.
# Expected: oc cequintin icatzinco mahuiltizqueh.
# Character Error Rate: 0.10810811072587967
#
#
# Input: ca ompa tonitztihui yn ihuicopa yn altepetli yn jerosalen.
# Predicted: ca ompa tonitztihuih in ihuicopa in altepetl in jerusalén.
# Expected: ca ompa tonitztihuih in ihuicopa in altepetl in jerusalén.
# Character Error Rate: 0.0
#
#
# Input: in tiacavan in acaltica tlaecoa;
# Predicted: in tiacahuan in acaltica tlaecoa;
# Expected: in tiacahuan in acaltica tlayecoah;
# Character Error Rate: 0.05714285746216774
#
#
# Input: ac omitzlhui?
# Predicted: ac omitzilhuih?
# Expected: ac omitzilhuih?
# Character Error Rate: 0.0
#
#
# Input: ynic onechalmihualitzino
# Predicted: inic onechalmihualihtzinoh
# Expected: inic onechhualmihualihtzinoh
# Character Error Rate: 0.0714285746216774
#
#
# Input: ynic onitlacatico yn tlalticpac ynic momaquixtisq yn c.mc tlatlacohuanime,
# Predicted: inic onitlacatico in tlalticpac inic momaquixtizqueh in cemanahuac tlahtlacoanimeh,
# Expected: inic onitlacatico in tlalticpac inic momaquixtizqueh in cemanahuac tlahtlacoanimeh,
# Character Error Rate: 0.0
#
#
# Input: conmonamiquilico in inacaztlan tepetl
# Predicted: commonamiquilicoh in inacaztlan tepetl
# Expected: commonamiquilico in inacaztlan tepetl
# ...
# Character Error Rate: 0.025641025975346565
#
#
# Input: yn ma tiqualehuacan.
# Predicted: in ma tichualehuahcan.
# Expected: in ma tichualehuacan.
# Character Error Rate: 0.0476190485060215
#
#
# Input: ça imix
# Predicted: za imix
# Expected: za imix
# Character Error Rate: 0.0
#
#
# Input: intequiuh
# Predicted: intequiuh
# Expected: intequiuh
# Character Error Rate: 0.0
#
#
# Input: ça tepipia in mexica.
# Predicted: za tepipiya in mexihcah.
# Expected: za tepipiyah in mexihcah.
# Character Error Rate: 0.03999999910593033
#
#
# Input: calaquisque mochinti jodiosme.
# Predicted: calaquizqueh mochintin judíosmeh.
# Expected: calaquizqueh mochintin judíosmeh.
# Character Error Rate: 0.0
#
#
# Input: ynhua niquitohua oc se pedasito
# Predicted: inhuan niquihtoa oc ce pedacito
# Expected: ihuan niquihtoa oc ce pedacito
# Character Error Rate: 0.03333333507180214
#
#
# Input: sano ysalica yni sular
# Predicted: zanno izalhuica inin sular
# Expected: zan no izaliuhcauh inin solar
# Character Error Rate: 0.2068965584039688
#
#
# Input: niccahuiliti nosubrina
# Predicted: niccahuilitiuh nosobrina
# Expected: niccahuilitiuh nosobrina
# Character Error Rate: 0.0
#
#
# Input: matiana maría;
# Predicted: matiana maría;
# Expected: matiana maría;
# Character Error Rate: 0.0
#
#
# Input: auh in españoles novian nemi in tlatemoa in calpulco
# Predicted: auh in españoles nohuiyan nemih in tlatemoah in calpolco
# Expected: auh in españoles nohuiyan nemih in tlatemoah in calpolco
# Character Error Rate: 0.0
#
#
# Input: novian ontlaxiltiviin tlatemoa
# Predicted: nohuiyan ontlahxiltihuih in tlatemoah
# Expected: nohuiyan ontlahxiltihuih in tlatemoah
# Character Error Rate: 0.0
#
#
# Input: in açaca vmpa minaia.
# Predicted: in ahzacah ompa minaya.
# Expected: in ahzacah ompa minayah.
# Character Error Rate: 0.0416666679084301
#
#
# Input: auh in pani
# Predicted: auh in pani
# Expected: auh in pani
# Character Error Rate: 0.0
#
#
# Input: itlapachiuhcatzin ilhuicaxoxiuhqui
# Predicted: itlapachiuhcatzin ilhuicaxoxiuhqui
# Expected: itlapachiuhcatzin ilhuicaxoxouhqui
# Character Error Rate: 0.029411764815449715
#
#
# Input: huel iquapantzinco onhualehua
# Predicted: huel ihcuapantzinco onhualehua
# Expected: huel icuapantzinco onhualehua
# Character Error Rate: 0.03448275849223137
#
#
# Input: atle ic quitlapachoa in ixayacatzin.
# Predicted: ahtle ic quitlapachoa in ixayacatzin.
# Expected: ahtle ic quitlapachoa in ixayacatzin.
# Character Error Rate: 0.0
#
#
# Input: auh y¯tla oc quezquitetl missa nopa¯ mihtoz
# Predicted: auh in tla oc quezquitetl misa nopan mihtoz
# Expected: auh in tla oc quezquitetl misa nopan mihtoz
# Character Error Rate: 0.0
#
#
# Input: çan yehuatl ytech ninocauhtiuh y¯ çihuapilli nonamic doña bárbara;
# Predicted: zan yehhuatl itech ninocauhtiuh in cihuapilli nonamic doña bárbara;
# Expected: zan yehhuatl itech ninocauhtiuh in cihuapilli nonamic doña bárbara;
# Character Error Rate: 0.0
#
#
# Input: lunes
# Predicted: lunes
# Expected: lunes
# Character Error Rate: 0.0
#
#
# Input: yc 20 días del mes de junio de 1575 años.
# Predicted: ic 20 días del mes de junio de 157 años.
# Expected: ic 20 días del mes de junio de 1575 años.
# Character Error Rate: 0.024390242993831635
#
#
# Input: auh ma nias
# Predicted: auh ma niyaz
# Expected: auh ma niyaz
# Character Error Rate: 0.0
#
#
# Input: ma xinechmomaquilitzino yn motheotechihualistzin inpanpa ca tinonantzin
# Predicted: ma xinechmomaquilihtzino in moteotechihualiztzin impampa ca tinonantzin
# Expected: ma xinechmomaquilihtzino in moteochihualiztzin ipampa ca tinonantzin
# Character Error Rate: 0.04411764815449715
#
#
# Input: ca otinechmotlacatililitzino yn tlalticpac.
# Predicted: ca otinechmotlacatililihtzinoh in tlalticpac.
# Expected: ca otinechmotlacatililihtzinoh in tlalticpac.
# Character Error Rate: 0.0
#
#
# Input: mochpochmiquili in içihuauh.
# Predicted: mochpochmiquilih in icihuauh.
# Expected: mochpochmiquilih in icihuauh.
# Character Error Rate: 0.0
#
#
# Input: auh tle onechcuili?
# Predicted: auh tleh onechcuilih?
# Expected: auh tle onechcuilih?
# Character Error Rate: 0.05000000074505806
#
#
# Input: huel iuh nimitzyta ca huel timotequipachotihuitz.
# Predicted: huel iuh nimitzitta ca huel timotequipachohtihuitz.
# Expected: huel iuh nimitzitta ca huel timotequipachotihuitz.
# Character Error Rate: 0.019999999552965164
#
#
# Input: notlasopilhuane
# Predicted: notlazohpilhuane
# Expected: notlazohpilhuane
# Character Error Rate: 0.0
#
#
# Input: ynin bino ca nessotzin.
# Predicted: inin vinoh ca nezzotzin.
# Expected: inin vinoh ca nezzotzin.
# Character Error Rate: 0.0
#
#
# Input: tleyca
# Predicted: tleica
# Expected: tleica
# Character Error Rate: 0.0
#
#
# Input: tleypanpa?
# Predicted: tleipampa?
# Expected: tleipampa?
# Character Error Rate: 0.0
#
#
# Input: ahu inin
# Predicted: auh inin
# Expected: auh inin
# Character Error Rate: 0.0
#
#
# Input: cuix san ic nicahuas?
# Predicted: cuix zan ic niccahuaz?
# Expected: cuix zan ic niccahuaz?
# Character Error Rate: 0.0
#
#
# Input: ca noçenyolocacopa
# Predicted: ca nocenyollohcacopa
# Expected: ca nocenyollohcacopa
# Character Error Rate: 0.0
#
#
# Input: yn aiac nechcuitlahuiltia.
# Predicted: in ayac nechcuitlahuiltia.
# Expected: in ayac nechcuitlahuiltia.
# Character Error Rate: 0.0
#
#
# Input: çanno iuhqui inic tlacuilolli
# Predicted: zanno iuhqui inic tlahcuilolli
# Expected: zan no iuhqui inic tlahcuilolli
# Character Error Rate: 0.032258063554763794
#
#
# Input: tlaezicuilolli.
# Predicted: tlaecihcuilolli.
# Expected: tlaezihcuilolli.
# Character Error Rate: 0.0625
#
#
# Input: quenmach yn amo pachihui yn iyollo?
# Predicted: quemmach in ahmo pachihui in iyolloh?
# Expected: quemmach in ahmo pachihui in inyollo?
# Character Error Rate: 0.054054055362939835
#
#
# Input: yn imixpã y notestigohuan
# Predicted: in imixpan in notestigohuan
# Expected: in imixpan in notestigohuan
# Character Error Rate: 0.0
#
#
# Input: y nahuintin pipiltin yn ollac huehuetque
# Predicted: in nahuintin pipiltin in ollac huehuetqueh
# Expected: in nahuintin pipiltin in ollac huehuetqueh
# Character Error Rate: 0.0
#
#
# Input: chiquaçen tlacatl
# Predicted: chicuace tlacatl
# Expected: chicuace tlacatl
# Character Error Rate: 0.0
#
#
# Input: juan tlapaltecatl ollac
# Predicted: juan tlapaltecatl ollac
# Expected: juan tlapaltecatl olac
# Character Error Rate: 0.04545454680919647
#
#
# Input: francisco tlapaltecatl tlapallan
# Predicted: francisco tlapaltecatl tlapallan
# Expected: francisco tlapaltecatl tlapallan
# Character Error Rate: 0.0
#
#
# Input: don miguel garcía analco
# Predicted: don miguel garcía analco
# Expected: don miguel garcía analco
# Character Error Rate: 0.0
#
#
# Input: toribio sánchez calnahuac
# Predicted: toribio sánchez calnahuac
# Expected: toribio sánchez calnahuac
# Character Error Rate: 0.0
#
#
# Input: felipe ollacatl ollac
# Predicted: felipe ollacatl ollac
# Expected: felipe olacatl olac
# Character Error Rate: 0.10526315867900848
#
#
# Input: miguel analcatl analco
# Predicted: miguel analcatl analco
# Expected: miguel analcatl analco
# Character Error Rate: 0.0
#
#
# Input: francisco tocalpanecatl yxtlahuacã
# Predicted: francisco tocalpanecatl ixtlahuahcan
# Expected: francisco tocalpanecatl ixtlahuacan
# Character Error Rate: 0.02857142873108387
#
#
# Input: pedro chiapanecatl huaxtla
# Predicted: pedro chiyapanecatl huaxtlah
# Expected: pedro chiyampanecatl huaxtlan
# Character Error Rate: 0.06896551698446274
#
#
# Input: francisco huitznahuatl otlan.
# Predicted: francisco huitznahuatl otlan.
# Expected: francisco huitznahuatl ohtlan.
# Character Error Rate: 0.03333333507180214
#
#
# Input: in otozceuhque in otontlanque
# Predicted: in otozceuhqueh in otontlanqueh
# Expected: in otonceuhqueh in otontlanqueh
# Character Error Rate: 0.032258063554763794
#
#
# Input: oc yehuan intech tonaz intech tlathuiz
# Predicted: oc yehhuan intech tonaz intech tlathuiz
# Expected: oc yehhuan intech tonaz intech tlathuiz
# Character Error Rate: 0.0
#
#
# Input: canel ye inic toncate
# Predicted: canel yeh inic toncateh
# Expected: canel yeh inic toncateh
# Character Error Rate: 0.0
#
#
# Input: canel ya inic tictotlatolchialilico in tlacatl in totecuiyo in ilhuicahua
# Predicted: canel yah inic tictotlahtolchiyalilicoh in tlacatl in totecuiyo in ilhuicahuah
# Expected: canel yeh inic tictotlahtolchiyalilicoh in tlacatl in totecuiyo in ilhuicahuah
# Character Error Rate: 0.012820512987673283
#
#
# Input: tlalticpaque
# Predicted: tlalticpaqueh
# Expected: tlalticpaqueh
# Character Error Rate: 0.0
#
#
# Input: mictlane.
# Predicted: mictlaneh.
# Expected: mictlaneh.
# Character Error Rate: 0.0
#
#
# Input: ca yn izqui çemicac cahuitl
# Predicted: ca in izqui cemihcac cahuitl
# Expected: ca in izqui cemihcac cahuitl
# Character Error Rate: 0.0
#
#
# Input: âyc huelitiz yn tinechmocxipaquiliz.
# Predicted: aic huelitiz in tinechmocxipaquiliz.
# Expected: aic huelitiz in tinechmocxipaquiliz.
# Character Error Rate: 0.0
#
#
# Input: auh ma no in iquac yehuatl quittatiuh
# Predicted: auh ma no in ihcuac yehhuatl quittatiuh
# Expected: auh ma no in ihcuac yehhuatl quittatiuh
# Character Error Rate: 0.0
#
#
# Input: ma huel moch ic quixpãtiz
# Predicted: ma huel moch ic quixpantiz
# Expected: ma huel moch ic quixpantiz
# Character Error Rate: 0.0
#
#
# Input: quinonotzaz in tlein oquittac
# Predicted: quinonotzaz in tlein oquittac
# Expected: quinonotzaz in tlein oquittac
# Character Error Rate: 0.0
#
#
# Input: ihuan in quenin tlamahuiçoltica oquimopatili
# Predicted: ihuan in quenin tlamahuizoltica oquimopahtilih
# Expected: ihuan in quenin tlamahuizoltica oquimopahtilih
# Character Error Rate: 0.0
#
#
# Input: auh ma huel yuh quimotocayotiliz
# Predicted: auh ma huel iuh quimotocayotiliz
# Expected: auh ma huel iuh quimotocayotiliz
# Character Error Rate: 0.0
#
#
# Input: ma huel yuh motocayotitzinoz izçenquizcaichpochtzintli
# Predicted: ma huel iuh motocayotihtzinoz in cenquizcaichpochtzintli
# Expected: ma huel iuh motocayotihtzinoz in cenquizcaichpochtzintli
# Character Error Rate: 0.0
#
#
# Input: santa maria de guadalupe
# Predicted: santa maría de guadalupe
# Expected: santa maría de guadalupe
# Character Error Rate: 0.0
#
#
# Input: in itlaçoixiptlatzin.
# Predicted: in itlazohixiptlatzin.
# Expected: in itlazohixiptlatzin.
# Character Error Rate: 0.0
#
#
# Input: huel ihui in onehuac
# Predicted: huel ihui in onehuac
# Expected: huel ihui in onehuac
# Character Error Rate: 0.0
#
#
# Input: motlaloa
# Predicted: motlaloah
# Expected: motlaloa
# Character Error Rate: 0.125
#
#
# Input: atlauhtla
# Predicted: atlauhtla
# Expected: atlauhtlah
# Character Error Rate: 0.10000000149011612
#
#
# Input: tepexic
# Predicted: tepexihc
# Expected: tepexic
# Character Error Rate: 0.1428571492433548
#
#
# Input: texcalla
# Predicted: texcallah
# Expected: texcallah
# Character Error Rate: 0.0
#
#
# Input: in oc nen ixquich itlapal ic quitititzaya freno.
# Predicted: in oc nen ixquich itlahpal ic quitititzayah freno.
# Expected: in oc nen ixquich itlahpal ic quitititzaya freno.
# Character Error Rate: 0.020408162847161293
#
#
# Input: ilhuice yehuatzin in itechpatzinco tontlatotihui in nican tepeyacac quimixquechili in iyeyantzin
# Predicted: ilhuiceh yehhuatzin in itechpatzinco tontlahtohtihuih in nican tepeyacac quimixquechilih in iyeyantzin
# Expected: ilhuiceh yehhuatzin in itechpatzinco tontlahtohtihuih in nican tepeyacac quimixquechilih in iyeyantzin
# Character Error Rate: 0.0
#
#
# Input: ihuan quimotemaquili in ixiptlatzin huei tlamahuiçoltica
# Predicted: ihuan quimotemaquilih in ixiptlahtzin huei tlamahuizoltica
# Expected: ihuan quimotemaquilih in ixiptlatzin huei tlamahuizoltica
# Character Error Rate: 0.017543859779834747
#
#
# Input: in amo aca tlalticpac tlacatl tlacuilocatzintli
# Predicted: in ahmo acah tlalticpac tlacatl tlahcuilocatzintli
# Expected: in ahmo acah tlalticpac tlacatl tlahcuilohcatzintli
# Character Error Rate: 0.019607843831181526
#
#
# Input: oquimochihuili
# Predicted: oquimochihuilih
# Expected: oquimochihuilih
# Character Error Rate: 0.0
#
#
# Input: oquimotlapalaquili.
# Predicted: oquimotlahpalaquilih.
# Expected: oquimotlapalaquilih.
# Character Error Rate: 0.05000000074505806
#
#
# Input: quenami yolopoliuhqui
# Predicted: quenamih yollohpoliuhqui
# Expected: quenamih yolopoliuhqui
# Character Error Rate: 0.09090909361839294
#
#
# Input: ycnotl?
# Predicted: icnotl?
# Expected: icnotl?
# Character Error Rate: 0.0
#
#
# Input: nimixnahuiatia ypaltzinco yn tto dios
# Predicted: nimixnahuiatia ipaltzinco in totecuiyo dios
# Expected: nimitznahuatia ipaltzinco in totecuioyo dios
# Character Error Rate: 0.09090909361839294
#
#
# Input: ma xinechylhui
# Predicted: ma xinechilhui
# Expected: ma xinechilhui
# Character Error Rate: 0.0
#
#
# Input: cuix ye tehuatl yn tiypiltzin ȳ dios?
# Predicted: cuix ye tehhuatl in tipiltzin in dios?
# Expected: cuix ye tehhuatl in tipiltzin in dios?
# Character Error Rate: 0.0
#
#
# Input: muchi anquinextizque
# Predicted: mochi anquinextizqueh
# Expected: mochi anquinextizqueh
# Character Error Rate: 0.0
#
#
# Input: ca vel quitemoa in totecuiovan.”
# Predicted: ca huel quitemoah in totecuiyohuan.”
# Expected: ca huel quitemoah in totecuiyohuan.”
# Character Error Rate: 0.0
#
#
# Input: quimoquechpanoltilisq cruz.
# Predicted: quimoquechpanoltilizqueh cruz.
# Expected: quimoquechpanoltilizqueh cruz.
# Character Error Rate: 0.0
#
#
# Input: yntlacamo tontotocas
# Predicted: intlacamo tontotocaz
# Expected: intlacamo tontotocaz
# Character Error Rate: 0.0
#
#
# Input: nica timispopolosq.
# Predicted: nican timitzpohpolozqueh.
# Expected: nican timitzpohpolozqueh.
# Character Error Rate: 0.0
#
#
# Input: pilatitlan quitetecas yn atzitli.
# Predicted: pilatitlan quitetecaz in atzintli.
# Expected: pilatitlan quitehtecaz in atzintli.
# Character Error Rate: 0.02857142873108387
#
#
# Input: auh niquitohua y notlanequilis y maría tiacapan nicmacatiuh chiquaçen pss
# Predicted: auh niquihtoa in notlanequiliz in maría tiacapan nicmacatiuh chicuace pesos
# Expected: auh niquihtoa in notlanequiliz in maría tiacapan nicmacatiuh chicuace pesos
# Character Error Rate: 0.0
#
#
# Input: yhuan çentetl caso
# Predicted: ihuan centetl cazo
# Expected: ihuan centetl cazo
# Character Error Rate: 0.0
#
#
# Input: yhuã çe metlatl.
# Predicted: ihuan ce metlatl.
# Expected: ihuan ce metlatl.
# Character Error Rate: 0.0
#
#
# Input: ma ihuian ma yocoxca xonmohuicatihuian xonmoyacantihuian;
# Predicted: ma ihuiyan ma iocoxca xommohuicatihuiyan xommoyacantihuiyan;
# Expected: ma ihuiyan ma yocoxca xommohuicatihuiyan xommoyacantihuiyan;
# Character Error Rate: 0.01666666753590107
#
#
# Input: quihualteytitis.
# Predicted: quihualteittitiz.
# Expected: quihualteittitiz.
# Character Error Rate: 0.0
#
#
# Input: yc xiquilpican yn tetlapololtiani.
# Predicted: ic xiquilpican in tetlapololtiani.
# Expected: ic xiquilpican in tetlapololtiani.
# Character Error Rate: 0.0
#
#
# Input: tleyn oquic nitlasotlas y temachtianic?
# Predicted: tlein oquic nitlazohtlaz in temachtiani?
# Expected: tlein oquic nictlazohtlaz in temachtiani?
# Character Error Rate: 0.024390242993831635
#
#
# Input: aso ca moyonllopachihuis.
# Predicted: ahzo ca moyollohpachihuiz.
# Expected: ahzo ca moyollohpachihuiz.
# Character Error Rate: 0.0
#
#
# Input: quetzalaztatzontli
# Predicted: quetzalaztatzontli
# Expected: quetzalaztatzontli
# Character Error Rate: 0.0
#
#
# Input: çā moca quetzalli
# Predicted: zan moca quetzalli
# Expected: zan moca quetzalli
# Character Error Rate: 0.0
#
#
# Input: motquitica quetzalli
# Predicted: motquitica quetzalli
# Expected: motquitica quetzalli
# Character Error Rate: 0.0
#
#
# Input: iuhquin xoxoquivi
# Predicted: iuhqui xoxoquihui
# Expected: iuhqui xoxoquihui
# Character Error Rate: 0.0
#
#
# Input: xoxoquiuhtimani;
# Predicted: xoxoquiuhtimani;
# Expected: xoxoquiuhtimani;
# Character Error Rate: 0.0
#
#
# Input: yn aqui nictenamiquilis ynn ixayac
# Predicted: in aquin nictenamiquiliz in ixayac
# Expected: in aquin nictennamiquiliz in ixayac
# Character Error Rate: 0.02857142873108387
#
#
# Input: yehuatl ancanasque.
# Predicted: yehhuatl ancanazqueh.
# Expected: yehhuatl ancanazqueh.
# Character Error Rate: 0.0
#
#
# Input: oc quiticinochilito
# Predicted: oc quiticinochilitoh
# Expected: oc quiticinochilito
# Character Error Rate: 0.05263157933950424
#
#
# Input: oc ipan tlato
# Predicted: oc ipan tlahtoh
# Expected: oc ipan tlahtoh
# Character Error Rate: 0.0
#
#
# Input: yece aocmo inman;
# Predicted: yeceh aocmo imman;
# Expected: yeceh aocmo imman;
# Character Error Rate: 0.0
#
#
# Input: ca nican can yn s.ta crus
# Predicted: ca nican cah in santa cruz
# Expected: ca nican cah in santa cruz
# Character Error Rate: 0.0
#
#
# Input: notlasotemachticatzin.
# Predicted: notlazohtemachtihcatzin.
# Expected: notlazohtemachtihcatzin.
# Character Error Rate: 0.0
#
#
# The average character error rate is 0.02149462199734121
